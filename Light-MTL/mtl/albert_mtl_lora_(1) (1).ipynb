# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip -q install -U transformers datasets evaluate accelerate scikit-learn scipy pandas peft sentencepiece
# !mkdir -p /content/drive/MyDrive/mtl_runs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 62.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 17.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 7.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 53.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 22.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 78.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 11.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.2 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.2 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.2 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.2 which is incompatible.
# db-dtypes 1.5.1 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.2 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.2 which is incompatible.

# %%
# %%writefile /content/drive/MyDrive/mtl_runs/albert_mtl_lora.py
import os
import json
import time
import shutil
import random
from pathlib import Path
from itertools import cycle

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModel,
    DataCollatorWithPadding,
    get_linear_schedule_with_warmup,
)
from peft import LoraConfig, get_peft_model, TaskType
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from scipy.stats import pearsonr, spearmanr


# =========================================================
# Config
# =========================================================
MODEL_NAME = "albert-base-v2"
SETTING = "centralized_mtl_lora"
TASKS = ["sst2", "qqp", "stsb"]

BATCH_SIZE = 16
LR = 2e-5
WEIGHT_DECAY = 0.01
WARMUP_RATIO = 0.1
MAX_LENGTH = 256
NUM_WORKERS = 2
EARLY_STOPPING_PATIENCE = 3
KEEP_LAST_K_CHECKPOINTS = 2
SEED = 42

LORA_R = 8
LORA_ALPHA = 16
LORA_DROPOUT = 0.1
LORA_TARGET_MODULES = ["query", "key", "value"]

BASE_DIR = Path("/content/drive/MyDrive/mtl_runs")
RUN_NAME = "albert_mtl_lora_sst2_qqp_stsb"
RUN_DIR = BASE_DIR / RUN_NAME

CHECKPOINT_DIR = RUN_DIR / "checkpoints"
BEST_MODEL_DIR = RUN_DIR / "best_model"
FINAL_MODEL_DIR = RUN_DIR / "final_model"
LOG_CSV_PATH = RUN_DIR / "history.csv"
LOG_JSON_PATH = RUN_DIR / "history.json"
STATE_PATH = RUN_DIR / "training_state.json"


def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def ensure_dirs():
    RUN_DIR.mkdir(parents=True, exist_ok=True)
    CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
    BEST_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    FINAL_MODEL_DIR.mkdir(parents=True, exist_ok=True)


def save_json(obj, path):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False)


def save_history(history):
    pd.DataFrame(history).to_csv(LOG_CSV_PATH, index=False)
    save_json(history, LOG_JSON_PATH)


def cleanup_old_checkpoints(keep_k=2):
    ckpts = [p for p in CHECKPOINT_DIR.iterdir() if p.is_dir() and p.name.startswith("epoch_")]
    ckpts = sorted(ckpts, key=lambda x: int(x.name.split("_")[-1]))
    while len(ckpts) > keep_k:
        oldest = ckpts.pop(0)
        shutil.rmtree(oldest, ignore_errors=True)


def get_latest_checkpoint():
    if not CHECKPOINT_DIR.exists():
        return None
    ckpts = [p for p in CHECKPOINT_DIR.iterdir() if p.is_dir() and p.name.startswith("epoch_")]
    if not ckpts:
        return None
    ckpts = sorted(ckpts, key=lambda x: int(x.name.split("_")[-1]))
    return ckpts[-1]


def count_parameters(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return trainable_params, total_params


def safe_float(x):
    if x is None:
        return None
    try:
        if isinstance(x, (float, int, np.floating, np.integer)):
            if np.isnan(x) or np.isinf(x):
                return None
        return float(x)
    except Exception:
        return None


class AlbertMTL(nn.Module):
    def __init__(self, model_name, use_lora=True):
        super().__init__()
        self.encoder = AutoModel.from_pretrained(model_name)

        if use_lora:
            lora_config = LoraConfig(
                task_type=TaskType.FEATURE_EXTRACTION,
                r=LORA_R,
                lora_alpha=LORA_ALPHA,
                lora_dropout=LORA_DROPOUT,
                target_modules=LORA_TARGET_MODULES,
                bias="none",
            )
            self.encoder = get_peft_model(self.encoder, lora_config)

        hidden_size = self.encoder.config.hidden_size
        classifier_dropout = 0.1

        self.dropout = nn.Dropout(classifier_dropout)
        self.sst2_head = nn.Linear(hidden_size, 2)
        self.qqp_head = nn.Linear(hidden_size, 2)
        self.stsb_head = nn.Linear(hidden_size, 1)

    def encode(self, input_ids, attention_mask, token_type_ids=None):
        outputs = self.encoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
        )
        pooled = outputs.last_hidden_state[:, 0]
        return self.dropout(pooled)

    def forward(self, task_name, input_ids, attention_mask, token_type_ids=None, labels=None):
        features = self.encode(input_ids, attention_mask, token_type_ids)

        if task_name == "sst2":
            logits = self.sst2_head(features)
            loss = None
            if labels is not None:
                loss = nn.CrossEntropyLoss()(logits, labels.long())
            return {"loss": loss, "logits": logits}

        elif task_name == "qqp":
            logits = self.qqp_head(features)
            loss = None
            if labels is not None:
                loss = nn.CrossEntropyLoss()(logits, labels.long())
            return {"loss": loss, "logits": logits}

        elif task_name == "stsb":
            logits = self.stsb_head(features).squeeze(-1)
            loss = None
            if labels is not None:
                loss = nn.MSELoss()(logits, labels.float())
            return {"loss": loss, "logits": logits}

        else:
            raise ValueError(f"Unsupported task: {task_name}")


def save_model_bundle(model, tokenizer, save_dir, extra_info=None):
    save_dir = Path(save_dir)
    if save_dir.exists():
        shutil.rmtree(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    torch.save(model.state_dict(), save_dir / "pytorch_model.bin")
    tokenizer.save_pretrained(save_dir)

    payload = {
        "model_name": MODEL_NAME,
        "setting": SETTING,
        "tasks": TASKS,
        "lora": {
            "enabled": True,
            "r": LORA_R,
            "alpha": LORA_ALPHA,
            "dropout": LORA_DROPOUT,
            "target_modules": LORA_TARGET_MODULES,
        },
    }
    if extra_info is not None:
        payload["extra_info"] = extra_info
    save_json(payload, save_dir / "mtl_config.json")


def get_task_specs():
    return {
        "sst2": {
            "task_type": "classification",
            "dataset_loader": ("glue", "sst2"),
            "text_cols": ("sentence", None),
            "label_col": "label",
        },
        "qqp": {
            "task_type": "classification",
            "dataset_loader": ("glue", "qqp"),
            "text_cols": ("question1", "question2"),
            "label_col": "label",
        },
        "stsb": {
            "task_type": "regression",
            "dataset_loader": ("glue", "stsb"),
            "text_cols": ("sentence1", "sentence2"),
            "label_col": "label",
        },
    }


def preprocess_dataset(task_name, tokenizer, max_length):
    specs = get_task_specs()[task_name]
    dataset_name, subset_name = specs["dataset_loader"]
    raw = load_dataset(dataset_name, subset_name)

    text_a, text_b = specs["text_cols"]
    label_col = specs["label_col"]
    task_type = specs["task_type"]

    def preprocess_fn(examples):
        if text_b is None:
            enc = tokenizer(examples[text_a], truncation=True, max_length=max_length)
        else:
            enc = tokenizer(examples[text_a], examples[text_b], truncation=True, max_length=max_length)

        if task_type == "classification":
            enc["labels"] = examples[label_col]
        else:
            enc["labels"] = [float(x) for x in examples[label_col]]
        return enc

    encoded = raw.map(preprocess_fn, batched=True, remove_columns=raw["train"].column_names)

    if "validation" in encoded:
        val_split = "validation"
    elif "validation_matched" in encoded:
        val_split = "validation_matched"
    else:
        raise ValueError(f"No validation split for task {task_name}")

    return encoded["train"], encoded[val_split]


@torch.no_grad()
def evaluate_task(model, dataloader, device, task_name):
    model.eval()

    total_loss = 0.0
    all_preds = []
    all_labels = []

    for batch in dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}

        outputs = model(
            task_name=task_name,
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            token_type_ids=batch.get("token_type_ids", None),
            labels=batch["labels"],
        )
        loss = outputs["loss"]
        logits = outputs["logits"]

        total_loss += loss.item()

        if task_name in ["sst2", "qqp"]:
            preds = torch.argmax(logits, dim=-1)
            all_preds.extend(preds.detach().cpu().numpy().tolist())
            all_labels.extend(batch["labels"].detach().cpu().numpy().tolist())
        else:
            all_preds.extend(logits.detach().cpu().numpy().tolist())
            all_labels.extend(batch["labels"].detach().cpu().numpy().tolist())

    eval_loss = total_loss / max(len(dataloader), 1)

    if task_name in ["sst2", "qqp"]:
        return {
            "eval_loss": eval_loss,
            "accuracy": accuracy_score(all_labels, all_preds),
            "macro_f1": f1_score(all_labels, all_preds, average="macro", zero_division=0),
            "precision": precision_score(all_labels, all_preds, average="macro", zero_division=0),
            "recall": recall_score(all_labels, all_preds, average="macro", zero_division=0),
            "pearson": None,
            "spearman": None,
        }

    pearson = 0.0
    spearman = 0.0
    if len(set(all_labels)) > 1 and len(set(all_preds)) > 1:
        pearson = float(pearsonr(all_labels, all_preds)[0])
        spearman = float(spearmanr(all_labels, all_preds)[0])

    return {
        "eval_loss": eval_loss,
        "accuracy": None,
        "macro_f1": None,
        "precision": None,
        "recall": None,
        "pearson": pearson,
        "spearman": spearman,
    }


def compute_overall_metric(metrics_by_task):
    sst2_score = metrics_by_task["sst2"]["accuracy"]
    qqp_score = metrics_by_task["qqp"]["accuracy"]
    stsb_score = (metrics_by_task["stsb"]["pearson"] + metrics_by_task["stsb"]["spearman"]) / 2.0
    return float((sst2_score + qqp_score + stsb_score) / 3.0)


def save_checkpoint(epoch, model, tokenizer, optimizer, scheduler, history, best_metric_so_far, patience_counter):
    ckpt_dir = CHECKPOINT_DIR / f"epoch_{epoch}"
    ckpt_dir.mkdir(parents=True, exist_ok=True)

    torch.save(model.state_dict(), ckpt_dir / "model_state.pt")
    torch.save(
        {
            "epoch": epoch,
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict(),
            "best_metric_so_far": best_metric_so_far,
            "patience_counter": patience_counter,
            "history": history,
        },
        ckpt_dir / "trainer_state.pt",
    )
    tokenizer.save_pretrained(ckpt_dir)

    save_json(
        {
            "epoch": epoch,
            "best_metric_so_far": best_metric_so_far,
            "patience_counter": patience_counter,
            "history_length": len(history),
        },
        STATE_PATH,
    )
    cleanup_old_checkpoints(KEEP_LAST_K_CHECKPOINTS)


def main():
    set_seed(SEED)
    ensure_dirs()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("=" * 100)
    print(f"MODEL_NAME: {MODEL_NAME}")
    print(f"SETTING   : {SETTING}")
    print(f"TASKS     : {TASKS}")
    print(f"DEVICE    : {device}")
    print(f"RUN_DIR   : {RUN_DIR}")
    print("Training will continue until early stopping patience=3 is met.")
    print("No fixed max_epochs is used.")
    print("=" * 100)

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True)

    train_datasets = {}
    val_datasets = {}
    train_loaders = {}
    val_loaders = {}

    for task_name in TASKS:
        train_ds, val_ds = preprocess_dataset(task_name, tokenizer, MAX_LENGTH)
        train_datasets[task_name] = train_ds
        val_datasets[task_name] = val_ds

    collator = DataCollatorWithPadding(tokenizer=tokenizer)

    for task_name in TASKS:
        train_loaders[task_name] = DataLoader(
            train_datasets[task_name],
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collator,
            num_workers=NUM_WORKERS,
            pin_memory=True,
        )
        val_loaders[task_name] = DataLoader(
            val_datasets[task_name],
            batch_size=BATCH_SIZE,
            shuffle=False,
            collate_fn=collator,
            num_workers=NUM_WORKERS,
            pin_memory=True,
        )

    model = AlbertMTL(MODEL_NAME, use_lora=True).to(device)

    trainable_params, total_params = count_parameters(model)
    print(f"Trainable params: {trainable_params:,}")
    print(f"Total params    : {total_params:,}")

    for task_name in TASKS:
        print(
            f"{task_name} -> train: {len(train_datasets[task_name])}, "
            f"validation: {len(val_datasets[task_name])}, "
            f"train_batches: {len(train_loaders[task_name])}, "
            f"val_batches: {len(val_loaders[task_name])}"
        )

    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    max_train_batches = max(len(train_loaders[t]) for t in TASKS)
    steps_per_epoch = max_train_batches * len(TASKS)
    warmup_steps = max(1, int(steps_per_epoch * WARMUP_RATIO))
    scheduler = get_linear_schedule_with_warmup(
        optimizer=optimizer,
        num_warmup_steps=warmup_steps,
        num_training_steps=10**12,
    )

    history = []
    start_epoch = 1
    best_metric_so_far = -float("inf")
    patience_counter = 0

    latest_ckpt = get_latest_checkpoint()
    if latest_ckpt is not None:
        print(f"Resuming from checkpoint: {latest_ckpt}")
        model.load_state_dict(torch.load(latest_ckpt / "model_state.pt", map_location=device))

        trainer_state = torch.load(latest_ckpt / "trainer_state.pt", map_location=device)
        optimizer.load_state_dict(trainer_state["optimizer_state_dict"])
        scheduler.load_state_dict(trainer_state["scheduler_state_dict"])
        history = trainer_state.get("history", [])
        best_metric_so_far = trainer_state.get("best_metric_so_far", -float("inf"))
        patience_counter = trainer_state.get("patience_counter", 0)
        start_epoch = trainer_state.get("epoch", 0) + 1

    epoch = start_epoch
    while True:
        model.train()
        epoch_start_time = time.time()

        task_iterators = {task_name: cycle(train_loaders[task_name]) for task_name in TASKS}
        running_task_loss = {task_name: 0.0 for task_name in TASKS}
        running_task_steps = {task_name: 0 for task_name in TASKS}

        print("\n" + "=" * 100)
        print(f"Epoch {epoch} started")
        print("=" * 100)

        for shared_step in range(1, max_train_batches + 1):
            for task_name in TASKS:
                batch = next(task_iterators[task_name])
                batch = {k: v.to(device) for k, v in batch.items()}

                optimizer.zero_grad()
                outputs = model(
                    task_name=task_name,
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    token_type_ids=batch.get("token_type_ids", None),
                    labels=batch["labels"],
                )
                loss = outputs["loss"]
                loss.backward()
                optimizer.step()
                scheduler.step()

                running_task_loss[task_name] += loss.item()
                running_task_steps[task_name] += 1

            if shared_step % 50 == 0 or shared_step == max_train_batches:
                msg = [f"Epoch {epoch} | Shared Step {shared_step}/{max_train_batches}"]
                for task_name in TASKS:
                    avg_loss = running_task_loss[task_name] / max(running_task_steps[task_name], 1)
                    msg.append(f"{task_name}_loss={avg_loss:.6f}")
                print(" | ".join(msg))

        train_loss_sst2 = running_task_loss["sst2"] / max(running_task_steps["sst2"], 1)
        train_loss_qqp = running_task_loss["qqp"] / max(running_task_steps["qqp"], 1)
        train_loss_stsb = running_task_loss["stsb"] / max(running_task_steps["stsb"], 1)
        train_loss_overall = float((train_loss_sst2 + train_loss_qqp + train_loss_stsb) / 3.0)

        metrics_by_task = {}
        for task_name in TASKS:
            metrics_by_task[task_name] = evaluate_task(model, val_loaders[task_name], device, task_name)

        overall_metric = compute_overall_metric(metrics_by_task)
        is_new_best = overall_metric > best_metric_so_far

        if is_new_best:
            best_metric_so_far = overall_metric
            patience_counter = 0
            save_model_bundle(
                model,
                tokenizer,
                BEST_MODEL_DIR,
                extra_info={"epoch": epoch, "best_metric_so_far": best_metric_so_far},
            )
        else:
            patience_counter += 1

        row = {
            "epoch": epoch,
            "train_loss_overall": safe_float(train_loss_overall),
            "train_loss_sst2": safe_float(train_loss_sst2),
            "train_loss_qqp": safe_float(train_loss_qqp),
            "train_loss_stsb": safe_float(train_loss_stsb),

            "sst2_eval_loss": safe_float(metrics_by_task["sst2"]["eval_loss"]),
            "sst2_accuracy": safe_float(metrics_by_task["sst2"]["accuracy"]),
            "sst2_macro_f1": safe_float(metrics_by_task["sst2"]["macro_f1"]),
            "sst2_precision": safe_float(metrics_by_task["sst2"]["precision"]),
            "sst2_recall": safe_float(metrics_by_task["sst2"]["recall"]),

            "qqp_eval_loss": safe_float(metrics_by_task["qqp"]["eval_loss"]),
            "qqp_accuracy": safe_float(metrics_by_task["qqp"]["accuracy"]),
            "qqp_macro_f1": safe_float(metrics_by_task["qqp"]["macro_f1"]),
            "qqp_precision": safe_float(metrics_by_task["qqp"]["precision"]),
            "qqp_recall": safe_float(metrics_by_task["qqp"]["recall"]),

            "stsb_eval_loss": safe_float(metrics_by_task["stsb"]["eval_loss"]),
            "stsb_pearson": safe_float(metrics_by_task["stsb"]["pearson"]),
            "stsb_spearman": safe_float(metrics_by_task["stsb"]["spearman"]),

            "overall_score": safe_float(overall_metric),
            "time_per_epoch": safe_float(time.time() - epoch_start_time),
            "trainable_params": int(trainable_params),
            "total_params": int(total_params),
            "model_name": MODEL_NAME,
            "dataset_name": "sst2+qqp+stsb",
            "setting": SETTING,
            "best_metric_so_far": safe_float(best_metric_so_far),
            "patience_counter": int(patience_counter),
            "is_new_best": bool(is_new_best),
            "lora_r": LORA_R,
            "lora_alpha": LORA_ALPHA,
            "lora_dropout": LORA_DROPOUT,
        }

        history.append(row)
        save_history(history)

        save_checkpoint(
            epoch=epoch,
            model=model,
            tokenizer=tokenizer,
            optimizer=optimizer,
            scheduler=scheduler,
            history=history,
            best_metric_so_far=best_metric_so_far,
            patience_counter=patience_counter,
        )

        print("\nValidation results:")
        print(json.dumps(row, indent=2, ensure_ascii=False, default=str))

        if patience_counter >= EARLY_STOPPING_PATIENCE:
            print("\nEarly stopping triggered.")
            print(f"Overall validation score did not improve for {EARLY_STOPPING_PATIENCE} consecutive epochs.")
            break

        epoch += 1

    save_model_bundle(
        model,
        tokenizer,
        FINAL_MODEL_DIR,
        extra_info={"final_epoch": epoch, "best_metric_so_far": best_metric_so_far},
    )
    save_history(history)

    print("\nTraining completed.")
    print(f"History CSV : {LOG_CSV_PATH}")
    print(f"History JSON: {LOG_JSON_PATH}")
    print(f"Best model  : {BEST_MODEL_DIR}")
    print(f"Final model : {FINAL_MODEL_DIR}")
    print(f"Checkpoints : {CHECKPOINT_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Overwriting /content/drive/MyDrive/mtl_runs/albert_mtl_lora.py

# %%
# !python /content/drive/MyDrive/mtl_runs/albert_mtl_lora.py
# Out:
# ====================================================================================================
# MODEL_NAME: albert-base-v2
# SETTING   : centralized_mtl_lora
# TASKS     : ['sst2', 'qqp', 'stsb']
# DEVICE    : cuda
# RUN_DIR   : /content/drive/MyDrive/mtl_runs/albert_mtl_lora_sst2_qqp_stsb
# Training will continue until early stopping patience=3 is met.
# No fixed max_epochs is used.
# ====================================================================================================
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# config.json: 100% 684/684 [00:00<00:00, 2.03MB/s]
# tokenizer_config.json: 100% 25.0/25.0 [00:00<00:00, 103kB/s]
# spiece.model: 100% 760k/760k [00:00<00:00, 2.58MB/s]
# tokenizer.json: 1.31MB [00:00, 4.85MB/s]
# README.md: 35.3kB [00:00, 73.6MB/s]
# sst2/train-00000-of-00001.parquet: 100% 3.11M/3.11M [00:01<00:00, 2.05MB/s]
# sst2/validation-00000-of-00001.parquet: 100% 72.8k/72.8k [00:00<00:00, 336kB/s]
# sst2/test-00000-of-00001.parquet: 100% 148k/148k [00:00<00:00, 698kB/s]
# Generating train split: 100% 67349/67349 [00:00<00:00, 941641.79 examples/s]
# Generating validation split: 100% 872/872 [00:00<00:00, 327521.54 examples/s]
# Generating test split: 100% 1821/1821 [00:00<00:00, 540119.34 examples/s]
# Map: 100% 67349/67349 [00:05<00:00, 12733.14 examples/s]
# Map: 100% 872/872 [00:00<00:00, 4466.19 examples/s]
# Map: 100% 1821/1821 [00:00<00:00, 4645.01 examples/s]
# qqp/train-00000-of-00001.parquet: 100% 33.6M/33.6M [00:00<00:00, 55.0MB/s]
# qqp/validation-00000-of-00001.parquet: 100% 3.73M/3.73M [00:00<00:00, 9.05MB/s]
# qqp/test-00000-of-00001.parquet: 100% 36.7M/36.7M [00:00<00:00, 89.5MB/s]
# Generating train split: 100% 363846/363846 [00:00<00:00, 914838.62 examples/s]
# Generating validation split: 100% 40430/40430 [00:00<00:00, 820724.87 examples/s]
# Generating test split: 100% 390965/390965 [00:00<00:00, 949894.73 examples/s]
# Map: 100% 363846/363846 [01:11<00:00, 5100.24 examples/s]
# Map: 100% 40430/40430 [00:05<00:00, 7001.50 examples/s]
# Map: 100% 390965/390965 [01:07<00:00, 5762.22 examples/s]
# stsb/train-00000-of-00001.parquet: 100% 502k/502k [00:00<00:00, 824kB/s]
# stsb/validation-00000-of-00001.parquet: 100% 151k/151k [00:00<00:00, 714kB/s]
# stsb/test-00000-of-00001.parquet: 100% 114k/114k [00:00<00:00, 278kB/s]
# Generating train split: 100% 5749/5749 [00:00<00:00, 735019.62 examples/s]
# Generating validation split: 100% 1500/1500 [00:00<00:00, 441970.92 examples/s]
# Generating test split: 100% 1379/1379 [00:00<00:00, 483647.90 examples/s]
# Map: 100% 5749/5749 [00:00<00:00, 7589.34 examples/s]
# Map: 100% 1500/1500 [00:00<00:00, 6682.69 examples/s]
# Map: 100% 1379/1379 [00:00<00:00, 7746.83 examples/s]
# model.safetensors: 100% 47.4M/47.4M [00:00<00:00, 77.4MB/s]
# Loading weights: 100% 25/25 [00:00<00:00, 2943.12it/s, Materializing param=pooler.weight]
# AlbertModel LOAD REPORT from: albert-base-v2
# Key                          | Status     |  |
# -----------------------------+------------+--+-
# predictions.dense.weight     | UNEXPECTED |  |
# predictions.LayerNorm.bias   | UNEXPECTED |  |
# predictions.dense.bias       | UNEXPECTED |  |
# predictions.decoder.bias     | UNEXPECTED |  |
# predictions.LayerNorm.weight | UNEXPECTED |  |
# predictions.bias             | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Trainable params: 40,709
# Total params    : 11,724,293
# sst2 -> train: 67349, validation: 872, train_batches: 4210, val_batches: 55
# qqp -> train: 363846, validation: 40430, train_batches: 22741, val_batches: 2527
# stsb -> train: 5749, validation: 1500, train_batches: 360, val_batches: 94
# Resuming from checkpoint: /content/drive/MyDrive/mtl_runs/albert_mtl_lora_sst2_qqp_stsb/checkpoints/epoch_10
#
# ====================================================================================================
# Epoch 11 started
# ====================================================================================================
# Epoch 11 | Shared Step 50/22741 | sst2_loss=0.109357 | qqp_loss=0.340996 | stsb_loss=0.038862
# Epoch 11 | Shared Step 100/22741 | sst2_loss=0.104791 | qqp_loss=0.342210 | stsb_loss=0.038283
# Epoch 11 | Shared Step 150/22741 | sst2_loss=0.102469 | qqp_loss=0.322363 | stsb_loss=0.039610
# Epoch 11 | Shared Step 200/22741 | sst2_loss=0.105968 | qqp_loss=0.319624 | stsb_loss=0.039277
# Epoch 11 | Shared Step 250/22741 | sst2_loss=0.100620 | qqp_loss=0.323811 | stsb_loss=0.039134
# Epoch 11 | Shared Step 300/22741 | sst2_loss=0.101493 | qqp_loss=0.324028 | stsb_loss=0.039068
# Epoch 11 | Shared Step 350/22741 | sst2_loss=0.102376 | qqp_loss=0.320070 | stsb_loss=0.039168
# Epoch 11 | Shared Step 400/22741 | sst2_loss=0.101442 | qqp_loss=0.314641 | stsb_loss=0.040032
# Epoch 11 | Shared Step 450/22741 | sst2_loss=0.103164 | qqp_loss=0.315761 | stsb_loss=0.040126
# Epoch 11 | Shared Step 500/22741 | sst2_loss=0.100939 | qqp_loss=0.319175 | stsb_loss=0.040235
# Epoch 11 | Shared Step 550/22741 | sst2_loss=0.101783 | qqp_loss=0.317748 | stsb_loss=0.040140
# Epoch 11 | Shared Step 600/22741 | sst2_loss=0.101146 | qqp_loss=0.315827 | stsb_loss=0.040055
# Epoch 11 | Shared Step 650/22741 | sst2_loss=0.102016 | qqp_loss=0.313983 | stsb_loss=0.040193
# Epoch 11 | Shared Step 700/22741 | sst2_loss=0.102283 | qqp_loss=0.315961 | stsb_loss=0.040331
# Epoch 11 | Shared Step 750/22741 | sst2_loss=0.104272 | qqp_loss=0.317398 | stsb_loss=0.040200
# Epoch 11 | Shared Step 800/22741 | sst2_loss=0.103229 | qqp_loss=0.315504 | stsb_loss=0.040030
# Epoch 11 | Shared Step 850/22741 | sst2_loss=0.103928 | qqp_loss=0.315602 | stsb_loss=0.040091
# Epoch 11 | Shared Step 900/22741 | sst2_loss=0.104498 | qqp_loss=0.314071 | stsb_loss=0.040210
# Epoch 11 | Shared Step 950/22741 | sst2_loss=0.104220 | qqp_loss=0.313945 | stsb_loss=0.040220
# Epoch 11 | Shared Step 1000/22741 | sst2_loss=0.105135 | qqp_loss=0.313271 | stsb_loss=0.040369
# Epoch 11 | Shared Step 1050/22741 | sst2_loss=0.106245 | qqp_loss=0.312868 | stsb_loss=0.040440
# Epoch 11 | Shared Step 1100/22741 | sst2_loss=0.104756 | qqp_loss=0.312372 | stsb_loss=0.040415
# Epoch 11 | Shared Step 1150/22741 | sst2_loss=0.105280 | qqp_loss=0.311022 | stsb_loss=0.040580
# Epoch 11 | Shared Step 1200/22741 | sst2_loss=0.105022 | qqp_loss=0.312419 | stsb_loss=0.040506
# Epoch 11 | Shared Step 1250/22741 | sst2_loss=0.105488 | qqp_loss=0.311122 | stsb_loss=0.040381
# Epoch 11 | Shared Step 1300/22741 | sst2_loss=0.105952 | qqp_loss=0.310553 | stsb_loss=0.040406
# Epoch 11 | Shared Step 1350/22741 | sst2_loss=0.105957 | qqp_loss=0.311597 | stsb_loss=0.040579
# Epoch 11 | Shared Step 1400/22741 | sst2_loss=0.105663 | qqp_loss=0.312474 | stsb_loss=0.040553
# Epoch 11 | Shared Step 1450/22741 | sst2_loss=0.104614 | qqp_loss=0.312448 | stsb_loss=0.040454
# Epoch 11 | Shared Step 1500/22741 | sst2_loss=0.103881 | qqp_loss=0.313569 | stsb_loss=0.040393
# Epoch 11 | Shared Step 1550/22741 | sst2_loss=0.103352 | qqp_loss=0.314612 | stsb_loss=0.040437
# Epoch 11 | Shared Step 1600/22741 | sst2_loss=0.102569 | qqp_loss=0.314428 | stsb_loss=0.040281
# Epoch 11 | Shared Step 1650/22741 | sst2_loss=0.101812 | qqp_loss=0.314911 | stsb_loss=0.040414
# Epoch 11 | Shared Step 1700/22741 | sst2_loss=0.102256 | qqp_loss=0.313695 | stsb_loss=0.040346
# Epoch 11 | Shared Step 1750/22741 | sst2_loss=0.103775 | qqp_loss=0.313218 | stsb_loss=0.040342
# Epoch 11 | Shared Step 1800/22741 | sst2_loss=0.103594 | qqp_loss=0.312532 | stsb_loss=0.040336
# Epoch 11 | Shared Step 1850/22741 | sst2_loss=0.103713 | qqp_loss=0.311705 | stsb_loss=0.040335
# Epoch 11 | Shared Step 1900/22741 | sst2_loss=0.104035 | qqp_loss=0.311586 | stsb_loss=0.040317
# Epoch 11 | Shared Step 1950/22741 | sst2_loss=0.103704 | qqp_loss=0.311419 | stsb_loss=0.040363
# Epoch 11 | Shared Step 2000/22741 | sst2_loss=0.103223 | qqp_loss=0.311505 | stsb_loss=0.040398
# Epoch 11 | Shared Step 2050/22741 | sst2_loss=0.103505 | qqp_loss=0.311768 | stsb_loss=0.040408
# Epoch 11 | Shared Step 2100/22741 | sst2_loss=0.103181 | qqp_loss=0.312070 | stsb_loss=0.040315
# Epoch 11 | Shared Step 2150/22741 | sst2_loss=0.102736 | qqp_loss=0.313079 | stsb_loss=0.040253
# Epoch 11 | Shared Step 2200/22741 | sst2_loss=0.101915 | qqp_loss=0.313775 | stsb_loss=0.040300
# Epoch 11 | Shared Step 2250/22741 | sst2_loss=0.101740 | qqp_loss=0.313688 | stsb_loss=0.040373
# Epoch 11 | Shared Step 2300/22741 | sst2_loss=0.102052 | qqp_loss=0.312993 | stsb_loss=0.040323
# Epoch 11 | Shared Step 2350/22741 | sst2_loss=0.102672 | qqp_loss=0.313000 | stsb_loss=0.040309
# Epoch 11 | Shared Step 2400/22741 | sst2_loss=0.103802 | qqp_loss=0.313608 | stsb_loss=0.040414
# Epoch 11 | Shared Step 2450/22741 | sst2_loss=0.104219 | qqp_loss=0.313990 | stsb_loss=0.040446
# Epoch 11 | Shared Step 2500/22741 | sst2_loss=0.104709 | qqp_loss=0.313799 | stsb_loss=0.040421
# Epoch 11 | Shared Step 2550/22741 | sst2_loss=0.105173 | qqp_loss=0.313519 | stsb_loss=0.040404
# Epoch 11 | Shared Step 2600/22741 | sst2_loss=0.104871 | qqp_loss=0.313834 | stsb_loss=0.040355
# Epoch 11 | Shared Step 2650/22741 | sst2_loss=0.105171 | qqp_loss=0.313980 | stsb_loss=0.040303
# Epoch 11 | Shared Step 2700/22741 | sst2_loss=0.105241 | qqp_loss=0.313742 | stsb_loss=0.040304
# Epoch 11 | Shared Step 2750/22741 | sst2_loss=0.104917 | qqp_loss=0.313641 | stsb_loss=0.040325
# Epoch 11 | Shared Step 2800/22741 | sst2_loss=0.104705 | qqp_loss=0.313777 | stsb_loss=0.040325
# Epoch 11 | Shared Step 2850/22741 | sst2_loss=0.104949 | qqp_loss=0.313854 | stsb_loss=0.040341
# Epoch 11 | Shared Step 2900/22741 | sst2_loss=0.105279 | qqp_loss=0.313880 | stsb_loss=0.040320
# Epoch 11 | Shared Step 2950/22741 | sst2_loss=0.105157 | qqp_loss=0.313590 | stsb_loss=0.040297
# Epoch 11 | Shared Step 3000/22741 | sst2_loss=0.105166 | qqp_loss=0.314233 | stsb_loss=0.040332
# Epoch 11 | Shared Step 3050/22741 | sst2_loss=0.105137 | qqp_loss=0.314432 | stsb_loss=0.040387
# Epoch 11 | Shared Step 3100/22741 | sst2_loss=0.104982 | qqp_loss=0.314620 | stsb_loss=0.040368
# Epoch 11 | Shared Step 3150/22741 | sst2_loss=0.104785 | qqp_loss=0.314555 | stsb_loss=0.040367
# Epoch 11 | Shared Step 3200/22741 | sst2_loss=0.104967 | qqp_loss=0.314673 | stsb_loss=0.040398
# Epoch 11 | Shared Step 3250/22741 | sst2_loss=0.105216 | qqp_loss=0.314531 | stsb_loss=0.040414
# Epoch 11 | Shared Step 3300/22741 | sst2_loss=0.105288 | qqp_loss=0.314260 | stsb_loss=0.040424
# Epoch 11 | Shared Step 3350/22741 | sst2_loss=0.105375 | qqp_loss=0.314047 | stsb_loss=0.040410
# Epoch 11 | Shared Step 3400/22741 | sst2_loss=0.105602 | qqp_loss=0.313978 | stsb_loss=0.040410
# Epoch 11 | Shared Step 3450/22741 | sst2_loss=0.105703 | qqp_loss=0.314016 | stsb_loss=0.040417
# Epoch 11 | Shared Step 3500/22741 | sst2_loss=0.106053 | qqp_loss=0.314107 | stsb_loss=0.040386
# Epoch 11 | Shared Step 3550/22741 | sst2_loss=0.106507 | qqp_loss=0.313680 | stsb_loss=0.040408
# Epoch 11 | Shared Step 3600/22741 | sst2_loss=0.106168 | qqp_loss=0.313421 | stsb_loss=0.040452
# Epoch 11 | Shared Step 3650/22741 | sst2_loss=0.106421 | qqp_loss=0.313455 | stsb_loss=0.040426
# Epoch 11 | Shared Step 3700/22741 | sst2_loss=0.106417 | qqp_loss=0.313489 | stsb_loss=0.040395
# Epoch 11 | Shared Step 3750/22741 | sst2_loss=0.106668 | qqp_loss=0.313125 | stsb_loss=0.040385
# Epoch 11 | Shared Step 3800/22741 | sst2_loss=0.106693 | qqp_loss=0.313533 | stsb_loss=0.040394
# Epoch 11 | Shared Step 3850/22741 | sst2_loss=0.107188 | qqp_loss=0.313284 | stsb_loss=0.040364
# Epoch 11 | Shared Step 3900/22741 | sst2_loss=0.106900 | qqp_loss=0.313470 | stsb_loss=0.040415
# Epoch 11 | Shared Step 3950/22741 | sst2_loss=0.107016 | qqp_loss=0.313522 | stsb_loss=0.040429
# Epoch 11 | Shared Step 4000/22741 | sst2_loss=0.107106 | qqp_loss=0.313497 | stsb_loss=0.040420
# Epoch 11 | Shared Step 4050/22741 | sst2_loss=0.106847 | qqp_loss=0.313197 | stsb_loss=0.040397
# Epoch 11 | Shared Step 4100/22741 | sst2_loss=0.106739 | qqp_loss=0.313235 | stsb_loss=0.040382
# Epoch 11 | Shared Step 4150/22741 | sst2_loss=0.106735 | qqp_loss=0.313560 | stsb_loss=0.040369
# Epoch 11 | Shared Step 4200/22741 | sst2_loss=0.106785 | qqp_loss=0.313447 | stsb_loss=0.040313
# Epoch 11 | Shared Step 4250/22741 | sst2_loss=0.106877 | qqp_loss=0.313470 | stsb_loss=0.040285
# Epoch 11 | Shared Step 4300/22741 | sst2_loss=0.106806 | qqp_loss=0.313672 | stsb_loss=0.040319
# Epoch 11 | Shared Step 4350/22741 | sst2_loss=0.106761 | qqp_loss=0.313506 | stsb_loss=0.040271
# Epoch 11 | Shared Step 4400/22741 | sst2_loss=0.106642 | qqp_loss=0.313484 | stsb_loss=0.040269
# Epoch 11 | Shared Step 4450/22741 | sst2_loss=0.106476 | qqp_loss=0.313484 | stsb_loss=0.040259
# Epoch 11 | Shared Step 4500/22741 | sst2_loss=0.106449 | qqp_loss=0.313551 | stsb_loss=0.040243
# Epoch 11 | Shared Step 4550/22741 | sst2_loss=0.106477 | qqp_loss=0.313922 | stsb_loss=0.040237
# Epoch 11 | Shared Step 4600/22741 | sst2_loss=0.106213 | qqp_loss=0.313940 | stsb_loss=0.040216
# Epoch 11 | Shared Step 4650/22741 | sst2_loss=0.106509 | qqp_loss=0.314021 | stsb_loss=0.040218
# Epoch 11 | Shared Step 4700/22741 | sst2_loss=0.106287 | qqp_loss=0.314004 | stsb_loss=0.040233
# Epoch 11 | Shared Step 4750/22741 | sst2_loss=0.106370 | qqp_loss=0.313770 | stsb_loss=0.040194
# Epoch 11 | Shared Step 4800/22741 | sst2_loss=0.106263 | qqp_loss=0.313677 | stsb_loss=0.040149
# Epoch 11 | Shared Step 4850/22741 | sst2_loss=0.106278 | qqp_loss=0.314044 | stsb_loss=0.040115
# Epoch 11 | Shared Step 4900/22741 | sst2_loss=0.106315 | qqp_loss=0.313723 | stsb_loss=0.040103
# Epoch 11 | Shared Step 4950/22741 | sst2_loss=0.106570 | qqp_loss=0.313857 | stsb_loss=0.040103
# Epoch 11 | Shared Step 5000/22741 | sst2_loss=0.106359 | qqp_loss=0.314149 | stsb_loss=0.040088
# Epoch 11 | Shared Step 5050/22741 | sst2_loss=0.106406 | qqp_loss=0.314263 | stsb_loss=0.040099
# Epoch 11 | Shared Step 5100/22741 | sst2_loss=0.106508 | qqp_loss=0.313936 | stsb_loss=0.040094
# Epoch 11 | Shared Step 5150/22741 | sst2_loss=0.106428 | qqp_loss=0.313752 | stsb_loss=0.040083
# Epoch 11 | Shared Step 5200/22741 | sst2_loss=0.106694 | qqp_loss=0.313812 | stsb_loss=0.040044
# Epoch 11 | Shared Step 5250/22741 | sst2_loss=0.106700 | qqp_loss=0.313744 | stsb_loss=0.040012
# Epoch 11 | Shared Step 5300/22741 | sst2_loss=0.106734 | qqp_loss=0.313639 | stsb_loss=0.040004
# Epoch 11 | Shared Step 5350/22741 | sst2_loss=0.106736 | qqp_loss=0.313729 | stsb_loss=0.039992
# Epoch 11 | Shared Step 5400/22741 | sst2_loss=0.106688 | qqp_loss=0.313857 | stsb_loss=0.039983
# Epoch 11 | Shared Step 5450/22741 | sst2_loss=0.106748 | qqp_loss=0.313687 | stsb_loss=0.039923
# Epoch 11 | Shared Step 5500/22741 | sst2_loss=0.106818 | qqp_loss=0.313710 | stsb_loss=0.039913
# Epoch 11 | Shared Step 5550/22741 | sst2_loss=0.106738 | qqp_loss=0.313662 | stsb_loss=0.039902
# Epoch 11 | Shared Step 5600/22741 | sst2_loss=0.106637 | qqp_loss=0.313622 | stsb_loss=0.039864
# Epoch 11 | Shared Step 5650/22741 | sst2_loss=0.106418 | qqp_loss=0.313738 | stsb_loss=0.039873
# Epoch 11 | Shared Step 5700/22741 | sst2_loss=0.106284 | qqp_loss=0.313701 | stsb_loss=0.039875
# Epoch 11 | Shared Step 5750/22741 | sst2_loss=0.106085 | qqp_loss=0.313880 | stsb_loss=0.039904
# Epoch 11 | Shared Step 5800/22741 | sst2_loss=0.105872 | qqp_loss=0.313961 | stsb_loss=0.039888
# Epoch 11 | Shared Step 5850/22741 | sst2_loss=0.105556 | qqp_loss=0.313977 | stsb_loss=0.039842
# Epoch 11 | Shared Step 5900/22741 | sst2_loss=0.105626 | qqp_loss=0.313892 | stsb_loss=0.039850
# Epoch 11 | Shared Step 5950/22741 | sst2_loss=0.106001 | qqp_loss=0.313863 | stsb_loss=0.039857
# Epoch 11 | Shared Step 6000/22741 | sst2_loss=0.105985 | qqp_loss=0.313903 | stsb_loss=0.039833
# Epoch 11 | Shared Step 6050/22741 | sst2_loss=0.106063 | qqp_loss=0.313898 | stsb_loss=0.039833
# Epoch 11 | Shared Step 6100/22741 | sst2_loss=0.105980 | qqp_loss=0.314067 | stsb_loss=0.039849
# Epoch 11 | Shared Step 6150/22741 | sst2_loss=0.105963 | qqp_loss=0.314224 | stsb_loss=0.039859
# Epoch 11 | Shared Step 6200/22741 | sst2_loss=0.105859 | qqp_loss=0.313969 | stsb_loss=0.039870
# Epoch 11 | Shared Step 6250/22741 | sst2_loss=0.105779 | qqp_loss=0.313976 | stsb_loss=0.039875
# Epoch 11 | Shared Step 6300/22741 | sst2_loss=0.105736 | qqp_loss=0.313936 | stsb_loss=0.039873
# Epoch 11 | Shared Step 6350/22741 | sst2_loss=0.105689 | qqp_loss=0.314169 | stsb_loss=0.039880
# Epoch 11 | Shared Step 6400/22741 | sst2_loss=0.105377 | qqp_loss=0.314341 | stsb_loss=0.039866
# Epoch 11 | Shared Step 6450/22741 | sst2_loss=0.105375 | qqp_loss=0.314260 | stsb_loss=0.039839
# Epoch 11 | Shared Step 6500/22741 | sst2_loss=0.105432 | qqp_loss=0.313806 | stsb_loss=0.039847
# Epoch 11 | Shared Step 6550/22741 | sst2_loss=0.105461 | qqp_loss=0.313837 | stsb_loss=0.039847
# Epoch 11 | Shared Step 6600/22741 | sst2_loss=0.105731 | qqp_loss=0.313793 | stsb_loss=0.039862
# Epoch 11 | Shared Step 6650/22741 | sst2_loss=0.105829 | qqp_loss=0.313925 | stsb_loss=0.039857
# Epoch 11 | Shared Step 6700/22741 | sst2_loss=0.106032 | qqp_loss=0.314029 | stsb_loss=0.039860
# Epoch 11 | Shared Step 6750/22741 | sst2_loss=0.106273 | qqp_loss=0.314015 | stsb_loss=0.039870
# Epoch 11 | Shared Step 6800/22741 | sst2_loss=0.106139 | qqp_loss=0.313986 | stsb_loss=0.039864
# Epoch 11 | Shared Step 6850/22741 | sst2_loss=0.106109 | qqp_loss=0.313953 | stsb_loss=0.039874
# Epoch 11 | Shared Step 6900/22741 | sst2_loss=0.106061 | qqp_loss=0.313956 | stsb_loss=0.039876
# Epoch 11 | Shared Step 6950/22741 | sst2_loss=0.105962 | qqp_loss=0.313958 | stsb_loss=0.039857
# Epoch 11 | Shared Step 7000/22741 | sst2_loss=0.105880 | qqp_loss=0.314095 | stsb_loss=0.039831
# Epoch 11 | Shared Step 7050/22741 | sst2_loss=0.105959 | qqp_loss=0.314126 | stsb_loss=0.039821
# Epoch 11 | Shared Step 7100/22741 | sst2_loss=0.106061 | qqp_loss=0.314165 | stsb_loss=0.039805
# Epoch 11 | Shared Step 7150/22741 | sst2_loss=0.106060 | qqp_loss=0.314248 | stsb_loss=0.039825
# Epoch 11 | Shared Step 7200/22741 | sst2_loss=0.105977 | qqp_loss=0.314099 | stsb_loss=0.039832
# Epoch 11 | Shared Step 7250/22741 | sst2_loss=0.105878 | qqp_loss=0.314088 | stsb_loss=0.039832
# Epoch 11 | Shared Step 7300/22741 | sst2_loss=0.105886 | qqp_loss=0.314047 | stsb_loss=0.039816
# Epoch 11 | Shared Step 7350/22741 | sst2_loss=0.105768 | qqp_loss=0.314112 | stsb_loss=0.039807
# Epoch 11 | Shared Step 7400/22741 | sst2_loss=0.105723 | qqp_loss=0.314015 | stsb_loss=0.039797
# Epoch 11 | Shared Step 7450/22741 | sst2_loss=0.105834 | qqp_loss=0.313925 | stsb_loss=0.039777
# Epoch 11 | Shared Step 7500/22741 | sst2_loss=0.105840 | qqp_loss=0.313786 | stsb_loss=0.039791
# Epoch 11 | Shared Step 7550/22741 | sst2_loss=0.105894 | qqp_loss=0.313637 | stsb_loss=0.039775
# Epoch 11 | Shared Step 7600/22741 | sst2_loss=0.105915 | qqp_loss=0.313410 | stsb_loss=0.039789
# Epoch 11 | Shared Step 7650/22741 | sst2_loss=0.106009 | qqp_loss=0.313323 | stsb_loss=0.039781
# Epoch 11 | Shared Step 7700/22741 | sst2_loss=0.106153 | qqp_loss=0.313404 | stsb_loss=0.039756
# Epoch 11 | Shared Step 7750/22741 | sst2_loss=0.106203 | qqp_loss=0.313438 | stsb_loss=0.039735
# Epoch 11 | Shared Step 7800/22741 | sst2_loss=0.106104 | qqp_loss=0.313411 | stsb_loss=0.039749
# Epoch 11 | Shared Step 7850/22741 | sst2_loss=0.106149 | qqp_loss=0.313300 | stsb_loss=0.039774
# Epoch 11 | Shared Step 7900/22741 | sst2_loss=0.106149 | qqp_loss=0.313406 | stsb_loss=0.039758
# Epoch 11 | Shared Step 7950/22741 | sst2_loss=0.106283 | qqp_loss=0.313440 | stsb_loss=0.039739
# Epoch 11 | Shared Step 8000/22741 | sst2_loss=0.106284 | qqp_loss=0.313418 | stsb_loss=0.039740
# Epoch 11 | Shared Step 8050/22741 | sst2_loss=0.106392 | qqp_loss=0.313327 | stsb_loss=0.039752
# Epoch 11 | Shared Step 8100/22741 | sst2_loss=0.106289 | qqp_loss=0.313321 | stsb_loss=0.039735
# Epoch 11 | Shared Step 8150/22741 | sst2_loss=0.106347 | qqp_loss=0.313081 | stsb_loss=0.039729
# Epoch 11 | Shared Step 8200/22741 | sst2_loss=0.106312 | qqp_loss=0.312963 | stsb_loss=0.039718
# Epoch 11 | Shared Step 8250/22741 | sst2_loss=0.106354 | qqp_loss=0.312876 | stsb_loss=0.039717
# Epoch 11 | Shared Step 8300/22741 | sst2_loss=0.106225 | qqp_loss=0.312845 | stsb_loss=0.039702
# Epoch 11 | Shared Step 8350/22741 | sst2_loss=0.106174 | qqp_loss=0.312648 | stsb_loss=0.039708
# Epoch 11 | Shared Step 8400/22741 | sst2_loss=0.106153 | qqp_loss=0.312733 | stsb_loss=0.039703
# Epoch 11 | Shared Step 8450/22741 | sst2_loss=0.106216 | qqp_loss=0.312631 | stsb_loss=0.039701
# Epoch 11 | Shared Step 8500/22741 | sst2_loss=0.106156 | qqp_loss=0.312547 | stsb_loss=0.039705
# Epoch 11 | Shared Step 8550/22741 | sst2_loss=0.106102 | qqp_loss=0.312458 | stsb_loss=0.039678
# Epoch 11 | Shared Step 8600/22741 | sst2_loss=0.106090 | qqp_loss=0.312437 | stsb_loss=0.039688
# Epoch 11 | Shared Step 8650/22741 | sst2_loss=0.106108 | qqp_loss=0.312505 | stsb_loss=0.039695
# Epoch 11 | Shared Step 8700/22741 | sst2_loss=0.106002 | qqp_loss=0.312601 | stsb_loss=0.039684
# Epoch 11 | Shared Step 8750/22741 | sst2_loss=0.106053 | qqp_loss=0.312592 | stsb_loss=0.039663
# Epoch 11 | Shared Step 8800/22741 | sst2_loss=0.105954 | qqp_loss=0.312518 | stsb_loss=0.039645
# Epoch 11 | Shared Step 8850/22741 | sst2_loss=0.105967 | qqp_loss=0.312597 | stsb_loss=0.039637
# Epoch 11 | Shared Step 8900/22741 | sst2_loss=0.105951 | qqp_loss=0.312644 | stsb_loss=0.039622
# Epoch 11 | Shared Step 8950/22741 | sst2_loss=0.105913 | qqp_loss=0.312683 | stsb_loss=0.039627
# Epoch 11 | Shared Step 9000/22741 | sst2_loss=0.105869 | qqp_loss=0.312762 | stsb_loss=0.039621
# Epoch 11 | Shared Step 9050/22741 | sst2_loss=0.105894 | qqp_loss=0.312833 | stsb_loss=0.039613
# Epoch 11 | Shared Step 9100/22741 | sst2_loss=0.105846 | qqp_loss=0.312557 | stsb_loss=0.039588
# Epoch 11 | Shared Step 9150/22741 | sst2_loss=0.105952 | qqp_loss=0.312323 | stsb_loss=0.039593
# Epoch 11 | Shared Step 9200/22741 | sst2_loss=0.105888 | qqp_loss=0.312539 | stsb_loss=0.039585
# Epoch 11 | Shared Step 9250/22741 | sst2_loss=0.105844 | qqp_loss=0.312603 | stsb_loss=0.039583
# Epoch 11 | Shared Step 9300/22741 | sst2_loss=0.105894 | qqp_loss=0.312540 | stsb_loss=0.039573
# Epoch 11 | Shared Step 9350/22741 | sst2_loss=0.105921 | qqp_loss=0.312597 | stsb_loss=0.039554
# Epoch 11 | Shared Step 9400/22741 | sst2_loss=0.106065 | qqp_loss=0.312673 | stsb_loss=0.039582
# Epoch 11 | Shared Step 9450/22741 | sst2_loss=0.106021 | qqp_loss=0.312853 | stsb_loss=0.039576
# Epoch 11 | Shared Step 9500/22741 | sst2_loss=0.106110 | qqp_loss=0.312770 | stsb_loss=0.039590
# Epoch 11 | Shared Step 9550/22741 | sst2_loss=0.105956 | qqp_loss=0.312934 | stsb_loss=0.039583
# Epoch 11 | Shared Step 9600/22741 | sst2_loss=0.105993 | qqp_loss=0.313028 | stsb_loss=0.039583
# Epoch 11 | Shared Step 9650/22741 | sst2_loss=0.105898 | qqp_loss=0.312951 | stsb_loss=0.039576
# Epoch 11 | Shared Step 9700/22741 | sst2_loss=0.106013 | qqp_loss=0.313003 | stsb_loss=0.039572
# Epoch 11 | Shared Step 9750/22741 | sst2_loss=0.105953 | qqp_loss=0.312764 | stsb_loss=0.039559
# Epoch 11 | Shared Step 9800/22741 | sst2_loss=0.105858 | qqp_loss=0.312585 | stsb_loss=0.039528
# Epoch 11 | Shared Step 9850/22741 | sst2_loss=0.105765 | qqp_loss=0.312794 | stsb_loss=0.039526
# Epoch 11 | Shared Step 9900/22741 | sst2_loss=0.105640 | qqp_loss=0.312674 | stsb_loss=0.039512
# Epoch 11 | Shared Step 9950/22741 | sst2_loss=0.105543 | qqp_loss=0.312610 | stsb_loss=0.039513
# Epoch 11 | Shared Step 10000/22741 | sst2_loss=0.105400 | qqp_loss=0.312356 | stsb_loss=0.039497
# Epoch 11 | Shared Step 10050/22741 | sst2_loss=0.105241 | qqp_loss=0.312337 | stsb_loss=0.039510
# Epoch 11 | Shared Step 10100/22741 | sst2_loss=0.105161 | qqp_loss=0.312239 | stsb_loss=0.039503
# Epoch 11 | Shared Step 10150/22741 | sst2_loss=0.105325 | qqp_loss=0.312191 | stsb_loss=0.039484
# Epoch 11 | Shared Step 10200/22741 | sst2_loss=0.105356 | qqp_loss=0.312219 | stsb_loss=0.039494
# Epoch 11 | Shared Step 10250/22741 | sst2_loss=0.105384 | qqp_loss=0.312140 | stsb_loss=0.039500
# Epoch 11 | Shared Step 10300/22741 | sst2_loss=0.105382 | qqp_loss=0.312154 | stsb_loss=0.039503
# Epoch 11 | Shared Step 10350/22741 | sst2_loss=0.105386 | qqp_loss=0.312270 | stsb_loss=0.039495
# Epoch 11 | Shared Step 10400/22741 | sst2_loss=0.105282 | qqp_loss=0.312360 | stsb_loss=0.039479
# Epoch 11 | Shared Step 10450/22741 | sst2_loss=0.105231 | qqp_loss=0.312395 | stsb_loss=0.039474
# Epoch 11 | Shared Step 10500/22741 | sst2_loss=0.105177 | qqp_loss=0.312270 | stsb_loss=0.039477
# Epoch 11 | Shared Step 10550/22741 | sst2_loss=0.105194 | qqp_loss=0.312199 | stsb_loss=0.039478
# Epoch 11 | Shared Step 10600/22741 | sst2_loss=0.105032 | qqp_loss=0.312084 | stsb_loss=0.039467
# Epoch 11 | Shared Step 10650/22741 | sst2_loss=0.104906 | qqp_loss=0.312203 | stsb_loss=0.039469
# Epoch 11 | Shared Step 10700/22741 | sst2_loss=0.104890 | qqp_loss=0.312207 | stsb_loss=0.039461
# Epoch 11 | Shared Step 10750/22741 | sst2_loss=0.105023 | qqp_loss=0.312209 | stsb_loss=0.039455
# Epoch 11 | Shared Step 10800/22741 | sst2_loss=0.105106 | qqp_loss=0.312235 | stsb_loss=0.039459
# Epoch 11 | Shared Step 10850/22741 | sst2_loss=0.105218 | qqp_loss=0.312314 | stsb_loss=0.039464
# Epoch 11 | Shared Step 10900/22741 | sst2_loss=0.105420 | qqp_loss=0.312297 | stsb_loss=0.039457
# Epoch 11 | Shared Step 10950/22741 | sst2_loss=0.105503 | qqp_loss=0.312302 | stsb_loss=0.039460
# Epoch 11 | Shared Step 11000/22741 | sst2_loss=0.105488 | qqp_loss=0.312340 | stsb_loss=0.039457
# Epoch 11 | Shared Step 11050/22741 | sst2_loss=0.105467 | qqp_loss=0.312304 | stsb_loss=0.039451
# Epoch 11 | Shared Step 11100/22741 | sst2_loss=0.105485 | qqp_loss=0.312196 | stsb_loss=0.039452
# Epoch 11 | Shared Step 11150/22741 | sst2_loss=0.105468 | qqp_loss=0.312361 | stsb_loss=0.039446
# Epoch 11 | Shared Step 11200/22741 | sst2_loss=0.105414 | qqp_loss=0.312361 | stsb_loss=0.039435
# Epoch 11 | Shared Step 11250/22741 | sst2_loss=0.105376 | qqp_loss=0.312463 | stsb_loss=0.039435
# Epoch 11 | Shared Step 11300/22741 | sst2_loss=0.105322 | qqp_loss=0.312460 | stsb_loss=0.039432
# Epoch 11 | Shared Step 11350/22741 | sst2_loss=0.105393 | qqp_loss=0.312451 | stsb_loss=0.039433
# Epoch 11 | Shared Step 11400/22741 | sst2_loss=0.105337 | qqp_loss=0.312533 | stsb_loss=0.039444
# Epoch 11 | Shared Step 11450/22741 | sst2_loss=0.105297 | qqp_loss=0.312584 | stsb_loss=0.039447
# Epoch 11 | Shared Step 11500/22741 | sst2_loss=0.105340 | qqp_loss=0.312547 | stsb_loss=0.039458
# Epoch 11 | Shared Step 11550/22741 | sst2_loss=0.105190 | qqp_loss=0.312486 | stsb_loss=0.039454
# Epoch 11 | Shared Step 11600/22741 | sst2_loss=0.105181 | qqp_loss=0.312482 | stsb_loss=0.039473
# Epoch 11 | Shared Step 11650/22741 | sst2_loss=0.105230 | qqp_loss=0.312446 | stsb_loss=0.039476
# Epoch 11 | Shared Step 11700/22741 | sst2_loss=0.105238 | qqp_loss=0.312319 | stsb_loss=0.039476
# Epoch 11 | Shared Step 11750/22741 | sst2_loss=0.105259 | qqp_loss=0.312243 | stsb_loss=0.039489
# Epoch 11 | Shared Step 11800/22741 | sst2_loss=0.105290 | qqp_loss=0.312269 | stsb_loss=0.039496
# Epoch 11 | Shared Step 11850/22741 | sst2_loss=0.105337 | qqp_loss=0.312235 | stsb_loss=0.039498
# Epoch 11 | Shared Step 11900/22741 | sst2_loss=0.105423 | qqp_loss=0.312219 | stsb_loss=0.039507
# Epoch 11 | Shared Step 11950/22741 | sst2_loss=0.105536 | qqp_loss=0.312197 | stsb_loss=0.039501
# Epoch 11 | Shared Step 12000/22741 | sst2_loss=0.105510 | qqp_loss=0.312209 | stsb_loss=0.039495
# Epoch 11 | Shared Step 12050/22741 | sst2_loss=0.105496 | qqp_loss=0.312286 | stsb_loss=0.039489
# Epoch 11 | Shared Step 12100/22741 | sst2_loss=0.105484 | qqp_loss=0.312213 | stsb_loss=0.039487
# Epoch 11 | Shared Step 12150/22741 | sst2_loss=0.105613 | qqp_loss=0.312248 | stsb_loss=0.039481
# Epoch 11 | Shared Step 12200/22741 | sst2_loss=0.105545 | qqp_loss=0.312041 | stsb_loss=0.039485
# Epoch 11 | Shared Step 12250/22741 | sst2_loss=0.105687 | qqp_loss=0.311851 | stsb_loss=0.039470
# Epoch 11 | Shared Step 12300/22741 | sst2_loss=0.105649 | qqp_loss=0.311902 | stsb_loss=0.039469
# Epoch 11 | Shared Step 12350/22741 | sst2_loss=0.105676 | qqp_loss=0.311928 | stsb_loss=0.039454
# Epoch 11 | Shared Step 12400/22741 | sst2_loss=0.105665 | qqp_loss=0.311810 | stsb_loss=0.039443
# Epoch 11 | Shared Step 12450/22741 | sst2_loss=0.105681 | qqp_loss=0.311766 | stsb_loss=0.039444
# Epoch 11 | Shared Step 12500/22741 | sst2_loss=0.105559 | qqp_loss=0.311683 | stsb_loss=0.039449
# Epoch 11 | Shared Step 12550/22741 | sst2_loss=0.105521 | qqp_loss=0.311623 | stsb_loss=0.039453
# Epoch 11 | Shared Step 12600/22741 | sst2_loss=0.105522 | qqp_loss=0.311536 | stsb_loss=0.039459
# Epoch 11 | Shared Step 12650/22741 | sst2_loss=0.105486 | qqp_loss=0.311652 | stsb_loss=0.039456
# Epoch 11 | Shared Step 12700/22741 | sst2_loss=0.105572 | qqp_loss=0.311714 | stsb_loss=0.039447
# Epoch 11 | Shared Step 12750/22741 | sst2_loss=0.105498 | qqp_loss=0.311654 | stsb_loss=0.039460
# Epoch 11 | Shared Step 12800/22741 | sst2_loss=0.105523 | qqp_loss=0.311693 | stsb_loss=0.039448
# Epoch 11 | Shared Step 12850/22741 | sst2_loss=0.105499 | qqp_loss=0.311561 | stsb_loss=0.039457
# Epoch 11 | Shared Step 12900/22741 | sst2_loss=0.105415 | qqp_loss=0.311530 | stsb_loss=0.039459
# Epoch 11 | Shared Step 12950/22741 | sst2_loss=0.105430 | qqp_loss=0.311561 | stsb_loss=0.039462
# Epoch 11 | Shared Step 13000/22741 | sst2_loss=0.105380 | qqp_loss=0.311576 | stsb_loss=0.039473
# Epoch 11 | Shared Step 13050/22741 | sst2_loss=0.105392 | qqp_loss=0.311553 | stsb_loss=0.039451
# Epoch 11 | Shared Step 13100/22741 | sst2_loss=0.105457 | qqp_loss=0.311481 | stsb_loss=0.039451
# Epoch 11 | Shared Step 13150/22741 | sst2_loss=0.105362 | qqp_loss=0.311439 | stsb_loss=0.039457
# Epoch 11 | Shared Step 13200/22741 | sst2_loss=0.105362 | qqp_loss=0.311471 | stsb_loss=0.039456
# Epoch 11 | Shared Step 13250/22741 | sst2_loss=0.105293 | qqp_loss=0.311435 | stsb_loss=0.039452
# Epoch 11 | Shared Step 13300/22741 | sst2_loss=0.105311 | qqp_loss=0.311385 | stsb_loss=0.039460
# Epoch 11 | Shared Step 13350/22741 | sst2_loss=0.105349 | qqp_loss=0.311328 | stsb_loss=0.039454
# Epoch 11 | Shared Step 13400/22741 | sst2_loss=0.105344 | qqp_loss=0.311343 | stsb_loss=0.039461
# Epoch 11 | Shared Step 13450/22741 | sst2_loss=0.105351 | qqp_loss=0.311297 | stsb_loss=0.039468
# Epoch 11 | Shared Step 13500/22741 | sst2_loss=0.105325 | qqp_loss=0.311222 | stsb_loss=0.039464
# Epoch 11 | Shared Step 13550/22741 | sst2_loss=0.105307 | qqp_loss=0.311237 | stsb_loss=0.039470
# Epoch 11 | Shared Step 13600/22741 | sst2_loss=0.105338 | qqp_loss=0.311234 | stsb_loss=0.039472
# Epoch 11 | Shared Step 13650/22741 | sst2_loss=0.105350 | qqp_loss=0.311277 | stsb_loss=0.039476
# Epoch 11 | Shared Step 13700/22741 | sst2_loss=0.105378 | qqp_loss=0.311218 | stsb_loss=0.039470
# Epoch 11 | Shared Step 13750/22741 | sst2_loss=0.105317 | qqp_loss=0.311189 | stsb_loss=0.039484
# Epoch 11 | Shared Step 13800/22741 | sst2_loss=0.105351 | qqp_loss=0.311324 | stsb_loss=0.039474
# Epoch 11 | Shared Step 13850/22741 | sst2_loss=0.105324 | qqp_loss=0.311366 | stsb_loss=0.039476
# Epoch 11 | Shared Step 13900/22741 | sst2_loss=0.105377 | qqp_loss=0.311393 | stsb_loss=0.039481
# Epoch 11 | Shared Step 13950/22741 | sst2_loss=0.105391 | qqp_loss=0.311267 | stsb_loss=0.039478
# Epoch 11 | Shared Step 14000/22741 | sst2_loss=0.105372 | qqp_loss=0.311172 | stsb_loss=0.039463
# Epoch 11 | Shared Step 14050/22741 | sst2_loss=0.105312 | qqp_loss=0.311102 | stsb_loss=0.039458
# Epoch 11 | Shared Step 14100/22741 | sst2_loss=0.105227 | qqp_loss=0.311115 | stsb_loss=0.039468
# Epoch 11 | Shared Step 14150/22741 | sst2_loss=0.105143 | qqp_loss=0.311113 | stsb_loss=0.039463
# Epoch 11 | Shared Step 14200/22741 | sst2_loss=0.105077 | qqp_loss=0.311152 | stsb_loss=0.039460
# Epoch 11 | Shared Step 14250/22741 | sst2_loss=0.104924 | qqp_loss=0.311128 | stsb_loss=0.039464
# Epoch 11 | Shared Step 14300/22741 | sst2_loss=0.104881 | qqp_loss=0.311151 | stsb_loss=0.039474
# Epoch 11 | Shared Step 14350/22741 | sst2_loss=0.104956 | qqp_loss=0.311105 | stsb_loss=0.039470
# Epoch 11 | Shared Step 14400/22741 | sst2_loss=0.104983 | qqp_loss=0.311165 | stsb_loss=0.039474
# Epoch 11 | Shared Step 14450/22741 | sst2_loss=0.104930 | qqp_loss=0.311186 | stsb_loss=0.039476
# Epoch 11 | Shared Step 14500/22741 | sst2_loss=0.104985 | qqp_loss=0.311210 | stsb_loss=0.039472
# Epoch 11 | Shared Step 14550/22741 | sst2_loss=0.104962 | qqp_loss=0.311259 | stsb_loss=0.039466
# Epoch 11 | Shared Step 14600/22741 | sst2_loss=0.104936 | qqp_loss=0.311165 | stsb_loss=0.039452
# Epoch 11 | Shared Step 14650/22741 | sst2_loss=0.104913 | qqp_loss=0.311260 | stsb_loss=0.039451
# Epoch 11 | Shared Step 14700/22741 | sst2_loss=0.104868 | qqp_loss=0.311282 | stsb_loss=0.039452
# Epoch 11 | Shared Step 14750/22741 | sst2_loss=0.104825 | qqp_loss=0.311278 | stsb_loss=0.039461
# Epoch 11 | Shared Step 14800/22741 | sst2_loss=0.104726 | qqp_loss=0.311274 | stsb_loss=0.039474
# Epoch 11 | Shared Step 14850/22741 | sst2_loss=0.104659 | qqp_loss=0.311241 | stsb_loss=0.039460
# Epoch 11 | Shared Step 14900/22741 | sst2_loss=0.104601 | qqp_loss=0.311183 | stsb_loss=0.039463
# Epoch 11 | Shared Step 14950/22741 | sst2_loss=0.104678 | qqp_loss=0.311232 | stsb_loss=0.039467
# Epoch 11 | Shared Step 15000/22741 | sst2_loss=0.104760 | qqp_loss=0.311304 | stsb_loss=0.039457
# Epoch 11 | Shared Step 15050/22741 | sst2_loss=0.104794 | qqp_loss=0.311225 | stsb_loss=0.039461
# Epoch 11 | Shared Step 15100/22741 | sst2_loss=0.104902 | qqp_loss=0.311199 | stsb_loss=0.039460
# Epoch 11 | Shared Step 15150/22741 | sst2_loss=0.104968 | qqp_loss=0.311240 | stsb_loss=0.039464
# Epoch 11 | Shared Step 15200/22741 | sst2_loss=0.104995 | qqp_loss=0.311146 | stsb_loss=0.039460
# Epoch 11 | Shared Step 15250/22741 | sst2_loss=0.104950 | qqp_loss=0.311169 | stsb_loss=0.039457
# Epoch 11 | Shared Step 15300/22741 | sst2_loss=0.104970 | qqp_loss=0.311210 | stsb_loss=0.039452
# Epoch 11 | Shared Step 15350/22741 | sst2_loss=0.104922 | qqp_loss=0.311161 | stsb_loss=0.039445
# Epoch 11 | Shared Step 15400/22741 | sst2_loss=0.104864 | qqp_loss=0.311171 | stsb_loss=0.039429
# Epoch 11 | Shared Step 15450/22741 | sst2_loss=0.104801 | qqp_loss=0.311109 | stsb_loss=0.039425
# Epoch 11 | Shared Step 15500/22741 | sst2_loss=0.104822 | qqp_loss=0.311106 | stsb_loss=0.039424
# Epoch 11 | Shared Step 15550/22741 | sst2_loss=0.104872 | qqp_loss=0.311146 | stsb_loss=0.039422
# Epoch 11 | Shared Step 15600/22741 | sst2_loss=0.104809 | qqp_loss=0.311185 | stsb_loss=0.039430
# Epoch 11 | Shared Step 15650/22741 | sst2_loss=0.104785 | qqp_loss=0.311281 | stsb_loss=0.039435
# Epoch 11 | Shared Step 15700/22741 | sst2_loss=0.104798 | qqp_loss=0.311361 | stsb_loss=0.039434
# Epoch 11 | Shared Step 15750/22741 | sst2_loss=0.104696 | qqp_loss=0.311449 | stsb_loss=0.039433
# Epoch 11 | Shared Step 15800/22741 | sst2_loss=0.104699 | qqp_loss=0.311407 | stsb_loss=0.039448
# Epoch 11 | Shared Step 15850/22741 | sst2_loss=0.104730 | qqp_loss=0.311416 | stsb_loss=0.039446
# Epoch 11 | Shared Step 15900/22741 | sst2_loss=0.104713 | qqp_loss=0.311449 | stsb_loss=0.039440
# Epoch 11 | Shared Step 15950/22741 | sst2_loss=0.104728 | qqp_loss=0.311401 | stsb_loss=0.039451
# Epoch 11 | Shared Step 16000/22741 | sst2_loss=0.104770 | qqp_loss=0.311481 | stsb_loss=0.039438
# Epoch 11 | Shared Step 16050/22741 | sst2_loss=0.104772 | qqp_loss=0.311489 | stsb_loss=0.039447
# Epoch 11 | Shared Step 16100/22741 | sst2_loss=0.104793 | qqp_loss=0.311374 | stsb_loss=0.039440
# Epoch 11 | Shared Step 16150/22741 | sst2_loss=0.104908 | qqp_loss=0.311433 | stsb_loss=0.039444
# Epoch 11 | Shared Step 16200/22741 | sst2_loss=0.104880 | qqp_loss=0.311432 | stsb_loss=0.039445
# Epoch 11 | Shared Step 16250/22741 | sst2_loss=0.104837 | qqp_loss=0.311460 | stsb_loss=0.039433
# Epoch 11 | Shared Step 16300/22741 | sst2_loss=0.104836 | qqp_loss=0.311441 | stsb_loss=0.039445
# Epoch 11 | Shared Step 16350/22741 | sst2_loss=0.104882 | qqp_loss=0.311469 | stsb_loss=0.039442
# Epoch 11 | Shared Step 16400/22741 | sst2_loss=0.104871 | qqp_loss=0.311399 | stsb_loss=0.039447
# Epoch 11 | Shared Step 16450/22741 | sst2_loss=0.104953 | qqp_loss=0.311327 | stsb_loss=0.039445
# Epoch 11 | Shared Step 16500/22741 | sst2_loss=0.104954 | qqp_loss=0.311259 | stsb_loss=0.039444
# Epoch 11 | Shared Step 16550/22741 | sst2_loss=0.104942 | qqp_loss=0.311387 | stsb_loss=0.039442
# Epoch 11 | Shared Step 16600/22741 | sst2_loss=0.104950 | qqp_loss=0.311437 | stsb_loss=0.039438
# Epoch 11 | Shared Step 16650/22741 | sst2_loss=0.104995 | qqp_loss=0.311257 | stsb_loss=0.039437
# Epoch 11 | Shared Step 16700/22741 | sst2_loss=0.104918 | qqp_loss=0.311304 | stsb_loss=0.039425
# Epoch 11 | Shared Step 16750/22741 | sst2_loss=0.104860 | qqp_loss=0.311362 | stsb_loss=0.039417
# Epoch 11 | Shared Step 16800/22741 | sst2_loss=0.104842 | qqp_loss=0.311492 | stsb_loss=0.039434
# Epoch 11 | Shared Step 16850/22741 | sst2_loss=0.104803 | qqp_loss=0.311546 | stsb_loss=0.039433
# Epoch 11 | Shared Step 16900/22741 | sst2_loss=0.104871 | qqp_loss=0.311522 | stsb_loss=0.039433
# Epoch 11 | Shared Step 16950/22741 | sst2_loss=0.104831 | qqp_loss=0.311549 | stsb_loss=0.039431
# Epoch 11 | Shared Step 17000/22741 | sst2_loss=0.104847 | qqp_loss=0.311459 | stsb_loss=0.039423
# Epoch 11 | Shared Step 17050/22741 | sst2_loss=0.104825 | qqp_loss=0.311446 | stsb_loss=0.039414
# Epoch 11 | Shared Step 17100/22741 | sst2_loss=0.104775 | qqp_loss=0.311440 | stsb_loss=0.039405
# Epoch 11 | Shared Step 17150/22741 | sst2_loss=0.104803 | qqp_loss=0.311431 | stsb_loss=0.039413
# Epoch 11 | Shared Step 17200/22741 | sst2_loss=0.104790 | qqp_loss=0.311513 | stsb_loss=0.039422
# Epoch 11 | Shared Step 17250/22741 | sst2_loss=0.104728 | qqp_loss=0.311478 | stsb_loss=0.039425
# Epoch 11 | Shared Step 17300/22741 | sst2_loss=0.104754 | qqp_loss=0.311415 | stsb_loss=0.039414
# Epoch 11 | Shared Step 17350/22741 | sst2_loss=0.104674 | qqp_loss=0.311371 | stsb_loss=0.039410
# Epoch 11 | Shared Step 17400/22741 | sst2_loss=0.104718 | qqp_loss=0.311332 | stsb_loss=0.039408
# Epoch 11 | Shared Step 17450/22741 | sst2_loss=0.104655 | qqp_loss=0.311306 | stsb_loss=0.039398
# Epoch 11 | Shared Step 17500/22741 | sst2_loss=0.104653 | qqp_loss=0.311249 | stsb_loss=0.039400
# Epoch 11 | Shared Step 17550/22741 | sst2_loss=0.104650 | qqp_loss=0.311332 | stsb_loss=0.039398
# Epoch 11 | Shared Step 17600/22741 | sst2_loss=0.104685 | qqp_loss=0.311352 | stsb_loss=0.039394
# Epoch 11 | Shared Step 17650/22741 | sst2_loss=0.104662 | qqp_loss=0.311302 | stsb_loss=0.039402
# Epoch 11 | Shared Step 17700/22741 | sst2_loss=0.104659 | qqp_loss=0.311282 | stsb_loss=0.039396
# Epoch 11 | Shared Step 17750/22741 | sst2_loss=0.104647 | qqp_loss=0.311244 | stsb_loss=0.039398
# Epoch 11 | Shared Step 17800/22741 | sst2_loss=0.104664 | qqp_loss=0.311246 | stsb_loss=0.039386
# Epoch 11 | Shared Step 17850/22741 | sst2_loss=0.104644 | qqp_loss=0.311276 | stsb_loss=0.039393
# Epoch 11 | Shared Step 17900/22741 | sst2_loss=0.104704 | qqp_loss=0.311291 | stsb_loss=0.039394
# Epoch 11 | Shared Step 17950/22741 | sst2_loss=0.104640 | qqp_loss=0.311319 | stsb_loss=0.039396
# Epoch 11 | Shared Step 18000/22741 | sst2_loss=0.104624 | qqp_loss=0.311241 | stsb_loss=0.039393
# Epoch 11 | Shared Step 18050/22741 | sst2_loss=0.104576 | qqp_loss=0.311205 | stsb_loss=0.039389
# Epoch 11 | Shared Step 18100/22741 | sst2_loss=0.104584 | qqp_loss=0.311200 | stsb_loss=0.039379
# Epoch 11 | Shared Step 18150/22741 | sst2_loss=0.104594 | qqp_loss=0.311130 | stsb_loss=0.039366
# Epoch 11 | Shared Step 18200/22741 | sst2_loss=0.104578 | qqp_loss=0.311144 | stsb_loss=0.039359
# Epoch 11 | Shared Step 18250/22741 | sst2_loss=0.104530 | qqp_loss=0.311202 | stsb_loss=0.039355
# Epoch 11 | Shared Step 18300/22741 | sst2_loss=0.104499 | qqp_loss=0.311186 | stsb_loss=0.039357
# Epoch 11 | Shared Step 18350/22741 | sst2_loss=0.104420 | qqp_loss=0.311270 | stsb_loss=0.039349
# Epoch 11 | Shared Step 18400/22741 | sst2_loss=0.104346 | qqp_loss=0.311269 | stsb_loss=0.039348
# Epoch 11 | Shared Step 18450/22741 | sst2_loss=0.104270 | qqp_loss=0.311341 | stsb_loss=0.039351
# Epoch 11 | Shared Step 18500/22741 | sst2_loss=0.104174 | qqp_loss=0.311346 | stsb_loss=0.039346
# Epoch 11 | Shared Step 18550/22741 | sst2_loss=0.104217 | qqp_loss=0.311388 | stsb_loss=0.039341
# Epoch 11 | Shared Step 18600/22741 | sst2_loss=0.104280 | qqp_loss=0.311449 | stsb_loss=0.039336
# Epoch 11 | Shared Step 18650/22741 | sst2_loss=0.104250 | qqp_loss=0.311488 | stsb_loss=0.039332
# Epoch 11 | Shared Step 18700/22741 | sst2_loss=0.104247 | qqp_loss=0.311480 | stsb_loss=0.039324
# Epoch 11 | Shared Step 18750/22741 | sst2_loss=0.104252 | qqp_loss=0.311471 | stsb_loss=0.039326
# Epoch 11 | Shared Step 18800/22741 | sst2_loss=0.104231 | qqp_loss=0.311498 | stsb_loss=0.039322
# Epoch 11 | Shared Step 18850/22741 | sst2_loss=0.104192 | qqp_loss=0.311462 | stsb_loss=0.039328
# Epoch 11 | Shared Step 18900/22741 | sst2_loss=0.104182 | qqp_loss=0.311540 | stsb_loss=0.039327
# Epoch 11 | Shared Step 18950/22741 | sst2_loss=0.104140 | qqp_loss=0.311512 | stsb_loss=0.039326
# Epoch 11 | Shared Step 19000/22741 | sst2_loss=0.104065 | qqp_loss=0.311504 | stsb_loss=0.039317
# Epoch 11 | Shared Step 19050/22741 | sst2_loss=0.103967 | qqp_loss=0.311468 | stsb_loss=0.039319
# Epoch 11 | Shared Step 19100/22741 | sst2_loss=0.103934 | qqp_loss=0.311491 | stsb_loss=0.039318
# Epoch 11 | Shared Step 19150/22741 | sst2_loss=0.103950 | qqp_loss=0.311469 | stsb_loss=0.039321
# Epoch 11 | Shared Step 19200/22741 | sst2_loss=0.103982 | qqp_loss=0.311518 | stsb_loss=0.039314
# Epoch 11 | Shared Step 19250/22741 | sst2_loss=0.104061 | qqp_loss=0.311459 | stsb_loss=0.039306
# Epoch 11 | Shared Step 19300/22741 | sst2_loss=0.104135 | qqp_loss=0.311517 | stsb_loss=0.039303
# Epoch 11 | Shared Step 19350/22741 | sst2_loss=0.104195 | qqp_loss=0.311488 | stsb_loss=0.039299
# Epoch 11 | Shared Step 19400/22741 | sst2_loss=0.104227 | qqp_loss=0.311466 | stsb_loss=0.039306
# Epoch 11 | Shared Step 19450/22741 | sst2_loss=0.104176 | qqp_loss=0.311497 | stsb_loss=0.039309
# Epoch 11 | Shared Step 19500/22741 | sst2_loss=0.104169 | qqp_loss=0.311592 | stsb_loss=0.039306
# Epoch 11 | Shared Step 19550/22741 | sst2_loss=0.104154 | qqp_loss=0.311535 | stsb_loss=0.039298
# Epoch 11 | Shared Step 19600/22741 | sst2_loss=0.104107 | qqp_loss=0.311521 | stsb_loss=0.039290
# Epoch 11 | Shared Step 19650/22741 | sst2_loss=0.104077 | qqp_loss=0.311586 | stsb_loss=0.039296
# Epoch 11 | Shared Step 19700/22741 | sst2_loss=0.104062 | qqp_loss=0.311536 | stsb_loss=0.039290
# Epoch 11 | Shared Step 19750/22741 | sst2_loss=0.104115 | qqp_loss=0.311439 | stsb_loss=0.039292
# Epoch 11 | Shared Step 19800/22741 | sst2_loss=0.104071 | qqp_loss=0.311482 | stsb_loss=0.039285
# Epoch 11 | Shared Step 19850/22741 | sst2_loss=0.104040 | qqp_loss=0.311449 | stsb_loss=0.039282
# Epoch 11 | Shared Step 19900/22741 | sst2_loss=0.104036 | qqp_loss=0.311432 | stsb_loss=0.039282
# Epoch 11 | Shared Step 19950/22741 | sst2_loss=0.103968 | qqp_loss=0.311383 | stsb_loss=0.039280
# Epoch 11 | Shared Step 20000/22741 | sst2_loss=0.103981 | qqp_loss=0.311309 | stsb_loss=0.039276
# Epoch 11 | Shared Step 20050/22741 | sst2_loss=0.103988 | qqp_loss=0.311251 | stsb_loss=0.039277
# Epoch 11 | Shared Step 20100/22741 | sst2_loss=0.104045 | qqp_loss=0.311306 | stsb_loss=0.039276
# Epoch 11 | Shared Step 20150/22741 | sst2_loss=0.104046 | qqp_loss=0.311318 | stsb_loss=0.039274
# Epoch 11 | Shared Step 20200/22741 | sst2_loss=0.104093 | qqp_loss=0.311310 | stsb_loss=0.039272
# Epoch 11 | Shared Step 20250/22741 | sst2_loss=0.104063 | qqp_loss=0.311222 | stsb_loss=0.039271
# Epoch 11 | Shared Step 20300/22741 | sst2_loss=0.104072 | qqp_loss=0.311196 | stsb_loss=0.039270
# Epoch 11 | Shared Step 20350/22741 | sst2_loss=0.104118 | qqp_loss=0.311222 | stsb_loss=0.039266
# Epoch 11 | Shared Step 20400/22741 | sst2_loss=0.104165 | qqp_loss=0.311309 | stsb_loss=0.039256
# Epoch 11 | Shared Step 20450/22741 | sst2_loss=0.104115 | qqp_loss=0.311367 | stsb_loss=0.039252
# Epoch 11 | Shared Step 20500/22741 | sst2_loss=0.104120 | qqp_loss=0.311430 | stsb_loss=0.039254
# Epoch 11 | Shared Step 20550/22741 | sst2_loss=0.104125 | qqp_loss=0.311474 | stsb_loss=0.039252
# Epoch 11 | Shared Step 20600/22741 | sst2_loss=0.104117 | qqp_loss=0.311437 | stsb_loss=0.039249
# Epoch 11 | Shared Step 20650/22741 | sst2_loss=0.104142 | qqp_loss=0.311337 | stsb_loss=0.039244
# Epoch 11 | Shared Step 20700/22741 | sst2_loss=0.104174 | qqp_loss=0.311257 | stsb_loss=0.039237
# Epoch 11 | Shared Step 20750/22741 | sst2_loss=0.104123 | qqp_loss=0.311229 | stsb_loss=0.039238
# Epoch 11 | Shared Step 20800/22741 | sst2_loss=0.104108 | qqp_loss=0.311229 | stsb_loss=0.039240
# Epoch 11 | Shared Step 20850/22741 | sst2_loss=0.104143 | qqp_loss=0.311191 | stsb_loss=0.039241
# Epoch 11 | Shared Step 20900/22741 | sst2_loss=0.104083 | qqp_loss=0.311227 | stsb_loss=0.039252
# Epoch 11 | Shared Step 20950/22741 | sst2_loss=0.104047 | qqp_loss=0.311233 | stsb_loss=0.039253
# Epoch 11 | Shared Step 21000/22741 | sst2_loss=0.104058 | qqp_loss=0.311185 | stsb_loss=0.039245
# Epoch 11 | Shared Step 21050/22741 | sst2_loss=0.104004 | qqp_loss=0.311140 | stsb_loss=0.039244
# Epoch 11 | Shared Step 21100/22741 | sst2_loss=0.104029 | qqp_loss=0.311193 | stsb_loss=0.039240
# Epoch 11 | Shared Step 21150/22741 | sst2_loss=0.104011 | qqp_loss=0.311201 | stsb_loss=0.039238
# Epoch 11 | Shared Step 21200/22741 | sst2_loss=0.104019 | qqp_loss=0.311173 | stsb_loss=0.039236
# Epoch 11 | Shared Step 21250/22741 | sst2_loss=0.104032 | qqp_loss=0.311090 | stsb_loss=0.039236
# Epoch 11 | Shared Step 21300/22741 | sst2_loss=0.103986 | qqp_loss=0.311150 | stsb_loss=0.039235
# Epoch 11 | Shared Step 21350/22741 | sst2_loss=0.103993 | qqp_loss=0.311115 | stsb_loss=0.039231
# Epoch 11 | Shared Step 21400/22741 | sst2_loss=0.104010 | qqp_loss=0.311161 | stsb_loss=0.039226
# Epoch 11 | Shared Step 21450/22741 | sst2_loss=0.103991 | qqp_loss=0.311120 | stsb_loss=0.039232
# Epoch 11 | Shared Step 21500/22741 | sst2_loss=0.104006 | qqp_loss=0.311051 | stsb_loss=0.039235
# Epoch 11 | Shared Step 21550/22741 | sst2_loss=0.103943 | qqp_loss=0.311023 | stsb_loss=0.039234
# Epoch 11 | Shared Step 21600/22741 | sst2_loss=0.103981 | qqp_loss=0.311014 | stsb_loss=0.039238
# Epoch 11 | Shared Step 21650/22741 | sst2_loss=0.103961 | qqp_loss=0.311034 | stsb_loss=0.039235
# Epoch 11 | Shared Step 21700/22741 | sst2_loss=0.103957 | qqp_loss=0.311032 | stsb_loss=0.039224
# Epoch 11 | Shared Step 21750/22741 | sst2_loss=0.103934 | qqp_loss=0.311060 | stsb_loss=0.039213
# Epoch 11 | Shared Step 21800/22741 | sst2_loss=0.103990 | qqp_loss=0.311095 | stsb_loss=0.039213
# Epoch 11 | Shared Step 21850/22741 | sst2_loss=0.103929 | qqp_loss=0.311108 | stsb_loss=0.039205
# Epoch 11 | Shared Step 21900/22741 | sst2_loss=0.103951 | qqp_loss=0.311078 | stsb_loss=0.039207
# Epoch 11 | Shared Step 21950/22741 | sst2_loss=0.103966 | qqp_loss=0.311064 | stsb_loss=0.039225
# Epoch 11 | Shared Step 22000/22741 | sst2_loss=0.103966 | qqp_loss=0.311098 | stsb_loss=0.039220
# Epoch 11 | Shared Step 22050/22741 | sst2_loss=0.103989 | qqp_loss=0.311014 | stsb_loss=0.039222
# Epoch 11 | Shared Step 22100/22741 | sst2_loss=0.104012 | qqp_loss=0.311124 | stsb_loss=0.039216
# Epoch 11 | Shared Step 22150/22741 | sst2_loss=0.103956 | qqp_loss=0.311098 | stsb_loss=0.039214
# Epoch 11 | Shared Step 22200/22741 | sst2_loss=0.103933 | qqp_loss=0.311082 | stsb_loss=0.039208
# Epoch 11 | Shared Step 22250/22741 | sst2_loss=0.103900 | qqp_loss=0.311067 | stsb_loss=0.039215
# Epoch 11 | Shared Step 22300/22741 | sst2_loss=0.103909 | qqp_loss=0.311082 | stsb_loss=0.039220
# Epoch 11 | Shared Step 22350/22741 | sst2_loss=0.103910 | qqp_loss=0.311111 | stsb_loss=0.039217
# Epoch 11 | Shared Step 22400/22741 | sst2_loss=0.103880 | qqp_loss=0.311168 | stsb_loss=0.039216
# Epoch 11 | Shared Step 22450/22741 | sst2_loss=0.103844 | qqp_loss=0.311162 | stsb_loss=0.039217
# Epoch 11 | Shared Step 22500/22741 | sst2_loss=0.103765 | qqp_loss=0.311212 | stsb_loss=0.039221
# Epoch 11 | Shared Step 22550/22741 | sst2_loss=0.103713 | qqp_loss=0.311216 | stsb_loss=0.039225
# Epoch 11 | Shared Step 22600/22741 | sst2_loss=0.103650 | qqp_loss=0.311074 | stsb_loss=0.039222
# Epoch 11 | Shared Step 22650/22741 | sst2_loss=0.103579 | qqp_loss=0.311011 | stsb_loss=0.039224
# Epoch 11 | Shared Step 22700/22741 | sst2_loss=0.103528 | qqp_loss=0.311098 | stsb_loss=0.039224
# Epoch 11 | Shared Step 22741/22741 | sst2_loss=0.103524 | qqp_loss=0.311107 | stsb_loss=0.039227
#
# Validation results:
# {
#   "epoch": 11,
#   "train_loss_overall": 0.15128629387980383,
#   "train_loss_sst2": 0.10352449271985135,
#   "train_loss_qqp": 0.31110709473802944,
#   "train_loss_stsb": 0.03922729418153068,
#   "sst2_eval_loss": 0.3468706295825541,
#   "sst2_accuracy": 0.9025229357798165,
#   "sst2_macro_f1": 0.9024550736653704,
#   "sst2_precision": 0.9026839275086769,
#   "sst2_recall": 0.9023427633240717,
#   "qqp_eval_loss": 0.31622524234732713,
#   "qqp_accuracy": 0.8558496166213208,
#   "qqp_macro_f1": 0.846181680235873,
#   "qqp_precision": 0.8439478610048811,
#   "qqp_recall": 0.8487522233647105,
#   "stsb_eval_loss": 0.6468923291627396,
#   "stsb_pearson": 0.8636214767099599,
#   "stsb_spearman": 0.8638292938903753,
#   "overall_score": 0.8740326459004351,
#   "time_per_epoch": 9606.512278795242,
#   "trainable_params": 40709,
#   "total_params": 11724293,
#   "model_name": "albert-base-v2",
#   "dataset_name": "sst2+qqp+stsb",
#   "setting": "centralized_mtl_lora",
#   "best_metric_so_far": 0.8750573274691323,
#   "patience_counter": 3,
#   "is_new_best": false,
#   "lora_r": 8,
#   "lora_alpha": 16,
#   "lora_dropout": 0.1
# }
#
# Early stopping triggered.
# Overall validation score did not improve for 3 consecutive epochs.
#
# Training completed.
# History CSV : /content/drive/MyDrive/mtl_runs/albert_mtl_lora_sst2_qqp_stsb/history.csv
# History JSON: /content/drive/MyDrive/mtl_runs/albert_mtl_lora_sst2_qqp_stsb/history.json
# Best model  : /content/drive/MyDrive/mtl_runs/albert_mtl_lora_sst2_qqp_stsb/best_model
# Final model : /content/drive/MyDrive/mtl_runs/albert_mtl_lora_sst2_qqp_stsb/final_model
# Checkpoints : /content/drive/MyDrive/mtl_runs/albert_mtl_lora_sst2_qqp_stsb/checkpoints
