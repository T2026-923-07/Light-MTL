# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip -q install -U transformers datasets evaluate accelerate scikit-learn scipy pandas
# !mkdir -p /content/drive/MyDrive/mtl_runs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 6.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 9.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 108.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 51.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 120.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 24.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 127.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 17.0 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.2 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.2 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.2 which is incompatible.
# dask-cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.2 which is incompatible.
# db-dtypes 1.5.1 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.2 which is incompatible.
# cudf-cu12 26.2.1 requires pandas<2.4.0,>=2.0, but you have pandas 3.0.2 which is incompatible.

# %%
# %%writefile /content/drive/MyDrive/mtl_runs/bert_base_mtl.py
import os
import json
import time
import shutil
import random
from pathlib import Path
from itertools import cycle

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModel,
    DataCollatorWithPadding,
    get_linear_schedule_with_warmup,
)
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from scipy.stats import pearsonr, spearmanr


# =========================================================
# Config
# =========================================================
MODEL_NAME = "bert-base-uncased"
SETTING = "centralized_mtl_full"
TASKS = ["sst2", "qqp", "stsb"]

BATCH_SIZE = 16
LR = 2e-5
WEIGHT_DECAY = 0.01
WARMUP_RATIO = 0.1
MAX_LENGTH = 256
NUM_WORKERS = 2
EARLY_STOPPING_PATIENCE = 3
KEEP_LAST_K_CHECKPOINTS = 2
SEED = 42

BASE_DIR = Path("/content/drive/MyDrive/mtl_runs")
RUN_NAME = "bert_base_mtl_sst2_qqp_stsb"
RUN_DIR = BASE_DIR / RUN_NAME

CHECKPOINT_DIR = RUN_DIR / "checkpoints"
BEST_MODEL_DIR = RUN_DIR / "best_model"
FINAL_MODEL_DIR = RUN_DIR / "final_model"
LOG_CSV_PATH = RUN_DIR / "history.csv"
LOG_JSON_PATH = RUN_DIR / "history.json"
STATE_PATH = RUN_DIR / "training_state.json"


# =========================================================
# Utils
# =========================================================
def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def ensure_dirs():
    RUN_DIR.mkdir(parents=True, exist_ok=True)
    CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
    BEST_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    FINAL_MODEL_DIR.mkdir(parents=True, exist_ok=True)


def save_json(obj, path):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False)


def save_history(history):
    pd.DataFrame(history).to_csv(LOG_CSV_PATH, index=False)
    save_json(history, LOG_JSON_PATH)


def cleanup_old_checkpoints(keep_k=2):
    ckpts = [p for p in CHECKPOINT_DIR.iterdir() if p.is_dir() and p.name.startswith("epoch_")]
    ckpts = sorted(ckpts, key=lambda x: int(x.name.split("_")[-1]))
    while len(ckpts) > keep_k:
        oldest = ckpts.pop(0)
        shutil.rmtree(oldest, ignore_errors=True)


def get_latest_checkpoint():
    if not CHECKPOINT_DIR.exists():
        return None
    ckpts = [p for p in CHECKPOINT_DIR.iterdir() if p.is_dir() and p.name.startswith("epoch_")]
    if not ckpts:
        return None
    ckpts = sorted(ckpts, key=lambda x: int(x.name.split("_")[-1]))
    return ckpts[-1]


def count_parameters(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return trainable_params, total_params


def safe_float(x):
    if x is None:
        return None
    try:
        if isinstance(x, (float, int, np.floating, np.integer)):
            if np.isnan(x) or np.isinf(x):
                return None
        return float(x)
    except Exception:
        return None


# =========================================================
# Model
# =========================================================
class BertBaseMTL(nn.Module):
    def __init__(self, model_name):
        super().__init__()
        self.encoder = AutoModel.from_pretrained(model_name)
        hidden_size = self.encoder.config.hidden_size

        self.dropout = nn.Dropout(0.1)
        self.sst2_head = nn.Linear(hidden_size, 2)
        self.qqp_head = nn.Linear(hidden_size, 2)
        self.stsb_head = nn.Linear(hidden_size, 1)

    def encode(self, input_ids, attention_mask, token_type_ids=None):
        outputs = self.encoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
        )
        pooled = outputs.last_hidden_state[:, 0]
        return self.dropout(pooled)

    def forward(self, task_name, input_ids, attention_mask, token_type_ids=None, labels=None):
        features = self.encode(input_ids, attention_mask, token_type_ids)

        if task_name == "sst2":
            logits = self.sst2_head(features)
            loss = None
            if labels is not None:
                loss = nn.CrossEntropyLoss()(logits, labels.long())
            return {"loss": loss, "logits": logits}

        elif task_name == "qqp":
            logits = self.qqp_head(features)
            loss = None
            if labels is not None:
                loss = nn.CrossEntropyLoss()(logits, labels.long())
            return {"loss": loss, "logits": logits}

        elif task_name == "stsb":
            logits = self.stsb_head(features).squeeze(-1)
            loss = None
            if labels is not None:
                loss = nn.MSELoss()(logits, labels.float())
            return {"loss": loss, "logits": logits}

        else:
            raise ValueError(f"Unsupported task: {task_name}")


def save_model_bundle(model, tokenizer, save_dir, extra_info=None):
    save_dir = Path(save_dir)
    if save_dir.exists():
        shutil.rmtree(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    torch.save(model.state_dict(), save_dir / "pytorch_model.bin")
    tokenizer.save_pretrained(save_dir)

    payload = {
        "model_name": MODEL_NAME,
        "setting": SETTING,
        "tasks": TASKS,
        "fine_tuning": "full",
    }
    if extra_info is not None:
        payload["extra_info"] = extra_info
    save_json(payload, save_dir / "mtl_config.json")


# =========================================================
# Data
# =========================================================
def get_task_specs():
    return {
        "sst2": {
            "task_type": "classification",
            "dataset_loader": ("glue", "sst2"),
            "text_cols": ("sentence", None),
            "label_col": "label",
        },
        "qqp": {
            "task_type": "classification",
            "dataset_loader": ("glue", "qqp"),
            "text_cols": ("question1", "question2"),
            "label_col": "label",
        },
        "stsb": {
            "task_type": "regression",
            "dataset_loader": ("glue", "stsb"),
            "text_cols": ("sentence1", "sentence2"),
            "label_col": "label",
        },
    }


def preprocess_dataset(task_name, tokenizer, max_length):
    specs = get_task_specs()[task_name]
    dataset_name, subset_name = specs["dataset_loader"]
    raw = load_dataset(dataset_name, subset_name)

    text_a, text_b = specs["text_cols"]
    label_col = specs["label_col"]
    task_type = specs["task_type"]

    def preprocess_fn(examples):
        if text_b is None:
            enc = tokenizer(
                examples[text_a],
                truncation=True,
                max_length=max_length,
            )
        else:
            enc = tokenizer(
                examples[text_a],
                examples[text_b],
                truncation=True,
                max_length=max_length,
            )

        if task_type == "classification":
            enc["labels"] = examples[label_col]
        else:
            enc["labels"] = [float(x) for x in examples[label_col]]
        return enc

    encoded = raw.map(preprocess_fn, batched=True, remove_columns=raw["train"].column_names)

    if "validation" in encoded:
        val_split = "validation"
    elif "validation_matched" in encoded:
        val_split = "validation_matched"
    else:
        raise ValueError(f"No validation split for task {task_name}")

    return encoded["train"], encoded[val_split]


# =========================================================
# Evaluation
# =========================================================
@torch.no_grad()
def evaluate_task(model, dataloader, device, task_name):
    model.eval()

    total_loss = 0.0
    all_preds = []
    all_labels = []

    for batch in dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}

        outputs = model(
            task_name=task_name,
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            token_type_ids=batch.get("token_type_ids", None),
            labels=batch["labels"],
        )
        loss = outputs["loss"]
        logits = outputs["logits"]

        total_loss += loss.item()

        if task_name in ["sst2", "qqp"]:
            preds = torch.argmax(logits, dim=-1)
            all_preds.extend(preds.detach().cpu().numpy().tolist())
            all_labels.extend(batch["labels"].detach().cpu().numpy().tolist())
        else:
            all_preds.extend(logits.detach().cpu().numpy().tolist())
            all_labels.extend(batch["labels"].detach().cpu().numpy().tolist())

    eval_loss = total_loss / max(len(dataloader), 1)

    if task_name in ["sst2", "qqp"]:
        return {
            "eval_loss": eval_loss,
            "accuracy": accuracy_score(all_labels, all_preds),
            "macro_f1": f1_score(all_labels, all_preds, average="macro", zero_division=0),
            "precision": precision_score(all_labels, all_preds, average="macro", zero_division=0),
            "recall": recall_score(all_labels, all_preds, average="macro", zero_division=0),
            "pearson": None,
            "spearman": None,
        }

    pearson = 0.0
    spearman = 0.0
    if len(set(all_labels)) > 1 and len(set(all_preds)) > 1:
        pearson = float(pearsonr(all_labels, all_preds)[0])
        spearman = float(spearmanr(all_labels, all_preds)[0])

    return {
        "eval_loss": eval_loss,
        "accuracy": None,
        "macro_f1": None,
        "precision": None,
        "recall": None,
        "pearson": pearson,
        "spearman": spearman,
    }


def compute_overall_metric(metrics_by_task):
    sst2_score = metrics_by_task["sst2"]["accuracy"]
    qqp_score = metrics_by_task["qqp"]["accuracy"]
    stsb_score = (metrics_by_task["stsb"]["pearson"] + metrics_by_task["stsb"]["spearman"]) / 2.0
    return float((sst2_score + qqp_score + stsb_score) / 3.0)


# =========================================================
# Checkpoint
# =========================================================
def save_checkpoint(epoch, model, tokenizer, optimizer, scheduler, history, best_metric_so_far, patience_counter):
    ckpt_dir = CHECKPOINT_DIR / f"epoch_{epoch}"
    ckpt_dir.mkdir(parents=True, exist_ok=True)

    torch.save(model.state_dict(), ckpt_dir / "model_state.pt")
    torch.save(
        {
            "epoch": epoch,
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict(),
            "best_metric_so_far": best_metric_so_far,
            "patience_counter": patience_counter,
            "history": history,
        },
        ckpt_dir / "trainer_state.pt",
    )
    tokenizer.save_pretrained(ckpt_dir)

    save_json(
        {
            "epoch": epoch,
            "best_metric_so_far": best_metric_so_far,
            "patience_counter": patience_counter,
            "history_length": len(history),
        },
        STATE_PATH,
    )
    cleanup_old_checkpoints(KEEP_LAST_K_CHECKPOINTS)


# =========================================================
# Main
# =========================================================
def main():
    set_seed(SEED)
    ensure_dirs()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("=" * 100)
    print(f"MODEL_NAME: {MODEL_NAME}")
    print(f"SETTING   : {SETTING}")
    print(f"TASKS     : {TASKS}")
    print(f"DEVICE    : {device}")
    print(f"RUN_DIR   : {RUN_DIR}")
    print("Training will continue until early stopping patience=3 is met.")
    print("No fixed max_epochs is used.")
    print("=" * 100)

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True)

    train_datasets = {}
    val_datasets = {}
    train_loaders = {}
    val_loaders = {}

    for task_name in TASKS:
        train_ds, val_ds = preprocess_dataset(task_name, tokenizer, MAX_LENGTH)
        train_datasets[task_name] = train_ds
        val_datasets[task_name] = val_ds

    collator = DataCollatorWithPadding(tokenizer=tokenizer)

    for task_name in TASKS:
        train_loaders[task_name] = DataLoader(
            train_datasets[task_name],
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collator,
            num_workers=NUM_WORKERS,
            pin_memory=True,
        )
        val_loaders[task_name] = DataLoader(
            val_datasets[task_name],
            batch_size=BATCH_SIZE,
            shuffle=False,
            collate_fn=collator,
            num_workers=NUM_WORKERS,
            pin_memory=True,
        )

    model = BertBaseMTL(MODEL_NAME).to(device)

    trainable_params, total_params = count_parameters(model)
    print(f"Trainable params: {trainable_params:,}")
    print(f"Total params    : {total_params:,}")

    for task_name in TASKS:
        print(
            f"{task_name} -> train: {len(train_datasets[task_name])}, "
            f"validation: {len(val_datasets[task_name])}, "
            f"train_batches: {len(train_loaders[task_name])}, "
            f"val_batches: {len(val_loaders[task_name])}"
        )

    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    max_train_batches = max(len(train_loaders[t]) for t in TASKS)
    steps_per_epoch = max_train_batches * len(TASKS)
    warmup_steps = max(1, int(steps_per_epoch * WARMUP_RATIO))
    scheduler = get_linear_schedule_with_warmup(
        optimizer=optimizer,
        num_warmup_steps=warmup_steps,
        num_training_steps=10**12,
    )

    history = []
    start_epoch = 1
    best_metric_so_far = -float("inf")
    patience_counter = 0

    latest_ckpt = get_latest_checkpoint()
    if latest_ckpt is not None:
        print(f"Resuming from checkpoint: {latest_ckpt}")
        model.load_state_dict(torch.load(latest_ckpt / "model_state.pt", map_location=device))

        trainer_state = torch.load(latest_ckpt / "trainer_state.pt", map_location=device)
        optimizer.load_state_dict(trainer_state["optimizer_state_dict"])
        scheduler.load_state_dict(trainer_state["scheduler_state_dict"])
        history = trainer_state.get("history", [])
        best_metric_so_far = trainer_state.get("best_metric_so_far", -float("inf"))
        patience_counter = trainer_state.get("patience_counter", 0)
        start_epoch = trainer_state.get("epoch", 0) + 1

    epoch = start_epoch
    while True:
        model.train()
        epoch_start_time = time.time()

        task_iterators = {task_name: cycle(train_loaders[task_name]) for task_name in TASKS}
        running_task_loss = {task_name: 0.0 for task_name in TASKS}
        running_task_steps = {task_name: 0 for task_name in TASKS}

        print("\n" + "=" * 100)
        print(f"Epoch {epoch} started")
        print("=" * 100)

        for shared_step in range(1, max_train_batches + 1):
            for task_name in TASKS:
                batch = next(task_iterators[task_name])
                batch = {k: v.to(device) for k, v in batch.items()}

                optimizer.zero_grad()
                outputs = model(
                    task_name=task_name,
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    token_type_ids=batch.get("token_type_ids", None),
                    labels=batch["labels"],
                )
                loss = outputs["loss"]
                loss.backward()
                optimizer.step()
                scheduler.step()

                running_task_loss[task_name] += loss.item()
                running_task_steps[task_name] += 1

            if shared_step % 50 == 0 or shared_step == max_train_batches:
                msg = [f"Epoch {epoch} | Shared Step {shared_step}/{max_train_batches}"]
                for task_name in TASKS:
                    avg_loss = running_task_loss[task_name] / max(running_task_steps[task_name], 1)
                    msg.append(f"{task_name}_loss={avg_loss:.6f}")
                print(" | ".join(msg))

        train_loss_sst2 = running_task_loss["sst2"] / max(running_task_steps["sst2"], 1)
        train_loss_qqp = running_task_loss["qqp"] / max(running_task_steps["qqp"], 1)
        train_loss_stsb = running_task_loss["stsb"] / max(running_task_steps["stsb"], 1)
        train_loss_overall = float((train_loss_sst2 + train_loss_qqp + train_loss_stsb) / 3.0)

        metrics_by_task = {}
        for task_name in TASKS:
            metrics_by_task[task_name] = evaluate_task(model, val_loaders[task_name], device, task_name)

        overall_metric = compute_overall_metric(metrics_by_task)
        is_new_best = overall_metric > best_metric_so_far

        if is_new_best:
            best_metric_so_far = overall_metric
            patience_counter = 0
            save_model_bundle(
                model,
                tokenizer,
                BEST_MODEL_DIR,
                extra_info={"epoch": epoch, "best_metric_so_far": best_metric_so_far},
            )
        else:
            patience_counter += 1

        row = {
            "epoch": epoch,
            "train_loss_overall": safe_float(train_loss_overall),
            "train_loss_sst2": safe_float(train_loss_sst2),
            "train_loss_qqp": safe_float(train_loss_qqp),
            "train_loss_stsb": safe_float(train_loss_stsb),

            "sst2_eval_loss": safe_float(metrics_by_task["sst2"]["eval_loss"]),
            "sst2_accuracy": safe_float(metrics_by_task["sst2"]["accuracy"]),
            "sst2_macro_f1": safe_float(metrics_by_task["sst2"]["macro_f1"]),
            "sst2_precision": safe_float(metrics_by_task["sst2"]["precision"]),
            "sst2_recall": safe_float(metrics_by_task["sst2"]["recall"]),

            "qqp_eval_loss": safe_float(metrics_by_task["qqp"]["eval_loss"]),
            "qqp_accuracy": safe_float(metrics_by_task["qqp"]["accuracy"]),
            "qqp_macro_f1": safe_float(metrics_by_task["qqp"]["macro_f1"]),
            "qqp_precision": safe_float(metrics_by_task["qqp"]["precision"]),
            "qqp_recall": safe_float(metrics_by_task["qqp"]["recall"]),

            "stsb_eval_loss": safe_float(metrics_by_task["stsb"]["eval_loss"]),
            "stsb_pearson": safe_float(metrics_by_task["stsb"]["pearson"]),
            "stsb_spearman": safe_float(metrics_by_task["stsb"]["spearman"]),

            "overall_score": safe_float(overall_metric),
            "time_per_epoch": safe_float(time.time() - epoch_start_time),
            "trainable_params": int(trainable_params),
            "total_params": int(total_params),
            "model_name": MODEL_NAME,
            "dataset_name": "sst2+qqp+stsb",
            "setting": SETTING,
            "best_metric_so_far": safe_float(best_metric_so_far),
            "patience_counter": int(patience_counter),
            "is_new_best": bool(is_new_best),
        }

        history.append(row)
        save_history(history)

        save_checkpoint(
            epoch=epoch,
            model=model,
            tokenizer=tokenizer,
            optimizer=optimizer,
            scheduler=scheduler,
            history=history,
            best_metric_so_far=best_metric_so_far,
            patience_counter=patience_counter,
        )

        print("\nValidation results:")
        print(json.dumps(row, indent=2, ensure_ascii=False, default=str))

        if patience_counter >= EARLY_STOPPING_PATIENCE:
            print("\nEarly stopping triggered.")
            print(f"Overall validation score did not improve for {EARLY_STOPPING_PATIENCE} consecutive epochs.")
            break

        epoch += 1

    save_model_bundle(
        model,
        tokenizer,
        FINAL_MODEL_DIR,
        extra_info={"final_epoch": epoch, "best_metric_so_far": best_metric_so_far},
    )
    save_history(history)

    print("\nTraining completed.")
    print(f"History CSV : {LOG_CSV_PATH}")
    print(f"History JSON: {LOG_JSON_PATH}")
    print(f"Best model  : {BEST_MODEL_DIR}")
    print(f"Final model : {FINAL_MODEL_DIR}")
    print(f"Checkpoints : {CHECKPOINT_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Overwriting /content/drive/MyDrive/mtl_runs/bert_base_mtl.py

# %%
# !python /content/drive/MyDrive/mtl_runs/bert_base_mtl.py
# Out:
# ====================================================================================================
# MODEL_NAME: bert-base-uncased
# SETTING   : centralized_mtl_full
# TASKS     : ['sst2', 'qqp', 'stsb']
# DEVICE    : cuda
# RUN_DIR   : /content/drive/MyDrive/mtl_runs/bert_base_mtl_sst2_qqp_stsb
# Training will continue until early stopping patience=3 is met.
# No fixed max_epochs is used.
# ====================================================================================================
# config.json: 100% 570/570 [00:00<00:00, 1.89MB/s]
# tokenizer_config.json: 100% 48.0/48.0 [00:00<00:00, 225kB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# vocab.txt: 232kB [00:00, 5.64MB/s]
# tokenizer.json: 466kB [00:00, 3.57MB/s]
# README.md: 35.3kB [00:00, 67.6MB/s]
# sst2/train-00000-of-00001.parquet: 100% 3.11M/3.11M [00:01<00:00, 1.82MB/s]
# sst2/validation-00000-of-00001.parquet: 100% 72.8k/72.8k [00:00<00:00, 348kB/s]
# sst2/test-00000-of-00001.parquet: 100% 148k/148k [00:00<00:00, 700kB/s]
# Generating train split: 100% 67349/67349 [00:00<00:00, 977869.94 examples/s]
# Generating validation split: 100% 872/872 [00:00<00:00, 200440.24 examples/s]
# Generating test split: 100% 1821/1821 [00:00<00:00, 397244.89 examples/s]
# Map: 100% 67349/67349 [00:04<00:00, 14961.79 examples/s]
# Map: 100% 872/872 [00:00<00:00, 6059.21 examples/s]
# Map: 100% 1821/1821 [00:00<00:00, 6540.06 examples/s]
# qqp/train-00000-of-00001.parquet: 100% 33.6M/33.6M [00:00<00:00, 54.5MB/s]
# qqp/validation-00000-of-00001.parquet: 100% 3.73M/3.73M [00:00<00:00, 9.07MB/s]
# qqp/test-00000-of-00001.parquet: 100% 36.7M/36.7M [00:00<00:00, 60.0MB/s]
# Generating train split: 100% 363846/363846 [00:00<00:00, 922199.00 examples/s]
# Generating validation split: 100% 40430/40430 [00:00<00:00, 859085.32 examples/s]
# Generating test split: 100% 390965/390965 [00:00<00:00, 998107.09 examples/s]
# Map: 100% 363846/363846 [00:49<00:00, 7281.70 examples/s]
# Map: 100% 40430/40430 [00:06<00:00, 5938.85 examples/s]
# Map: 100% 390965/390965 [00:56<00:00, 6974.39 examples/s]
# stsb/train-00000-of-00001.parquet: 100% 502k/502k [00:00<00:00, 821kB/s]
# stsb/validation-00000-of-00001.parquet: 100% 151k/151k [00:00<00:00, 716kB/s]
# stsb/test-00000-of-00001.parquet: 100% 114k/114k [00:00<00:00, 279kB/s]
# Generating train split: 100% 5749/5749 [00:00<00:00, 733856.40 examples/s]
# Generating validation split: 100% 1500/1500 [00:00<00:00, 281308.12 examples/s]
# Generating test split: 100% 1379/1379 [00:00<00:00, 469895.62 examples/s]
# Map: 100% 5749/5749 [00:00<00:00, 8767.08 examples/s]
# Map: 100% 1500/1500 [00:00<00:00, 8584.68 examples/s]
# Map: 100% 1379/1379 [00:00<00:00, 9674.51 examples/s]
# model.safetensors: 100% 440M/440M [00:08<00:00, 54.9MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 1027.36it/s, Materializing param=pooler.dense.weight]
# BertModel LOAD REPORT from: bert-base-uncased
# Key                                        | Status     |  |
# -------------------------------------------+------------+--+-
# cls.predictions.transform.dense.weight     | UNEXPECTED |  |
# cls.predictions.transform.dense.bias       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.weight | UNEXPECTED |  |
# cls.seq_relationship.bias                  | UNEXPECTED |  |
# cls.predictions.bias                       | UNEXPECTED |  |
# cls.predictions.transform.LayerNorm.bias   | UNEXPECTED |  |
# cls.seq_relationship.weight                | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.
# Trainable params: 109,486,085
# Total params    : 109,486,085
# sst2 -> train: 67349, validation: 872, train_batches: 4210, val_batches: 55
# qqp -> train: 363846, validation: 40430, train_batches: 22741, val_batches: 2527
# stsb -> train: 5749, validation: 1500, train_batches: 360, val_batches: 94
# Resuming from checkpoint: /content/drive/MyDrive/mtl_runs/bert_base_mtl_sst2_qqp_stsb/checkpoints/epoch_3
#
# ====================================================================================================
# Epoch 4 started
# ====================================================================================================
# Epoch 4 | Shared Step 50/22741 | sst2_loss=0.012603 | qqp_loss=0.082196 | stsb_loss=0.009388
# Epoch 4 | Shared Step 100/22741 | sst2_loss=0.014783 | qqp_loss=0.077796 | stsb_loss=0.009773
# Epoch 4 | Shared Step 150/22741 | sst2_loss=0.014231 | qqp_loss=0.073050 | stsb_loss=0.009688
# Epoch 4 | Shared Step 200/22741 | sst2_loss=0.012801 | qqp_loss=0.074373 | stsb_loss=0.009587
# Epoch 4 | Shared Step 250/22741 | sst2_loss=0.012722 | qqp_loss=0.070805 | stsb_loss=0.009684
# Epoch 4 | Shared Step 300/22741 | sst2_loss=0.011254 | qqp_loss=0.073742 | stsb_loss=0.010428
# Epoch 4 | Shared Step 350/22741 | sst2_loss=0.013025 | qqp_loss=0.074615 | stsb_loss=0.010605
# Epoch 4 | Shared Step 400/22741 | sst2_loss=0.012572 | qqp_loss=0.073975 | stsb_loss=0.010646
# Epoch 4 | Shared Step 450/22741 | sst2_loss=0.013809 | qqp_loss=0.072960 | stsb_loss=0.010745
# Epoch 4 | Shared Step 500/22741 | sst2_loss=0.012917 | qqp_loss=0.074820 | stsb_loss=0.010665
# Epoch 4 | Shared Step 550/22741 | sst2_loss=0.013370 | qqp_loss=0.075553 | stsb_loss=0.010619
# Epoch 4 | Shared Step 600/22741 | sst2_loss=0.012557 | qqp_loss=0.076302 | stsb_loss=0.010493
# Epoch 4 | Shared Step 650/22741 | sst2_loss=0.012743 | qqp_loss=0.076257 | stsb_loss=0.010414
# Epoch 4 | Shared Step 700/22741 | sst2_loss=0.011984 | qqp_loss=0.076922 | stsb_loss=0.010411
# Epoch 4 | Shared Step 750/22741 | sst2_loss=0.011367 | qqp_loss=0.076813 | stsb_loss=0.010335
# Epoch 4 | Shared Step 800/22741 | sst2_loss=0.011053 | qqp_loss=0.078797 | stsb_loss=0.010309
# Epoch 4 | Shared Step 850/22741 | sst2_loss=0.011049 | qqp_loss=0.079504 | stsb_loss=0.010224
# Epoch 4 | Shared Step 900/22741 | sst2_loss=0.010888 | qqp_loss=0.079722 | stsb_loss=0.010179
# Epoch 4 | Shared Step 950/22741 | sst2_loss=0.010713 | qqp_loss=0.079237 | stsb_loss=0.010119
# Epoch 4 | Shared Step 1000/22741 | sst2_loss=0.010235 | qqp_loss=0.078269 | stsb_loss=0.010183
# Epoch 4 | Shared Step 1050/22741 | sst2_loss=0.009947 | qqp_loss=0.077879 | stsb_loss=0.010181
# Epoch 4 | Shared Step 1100/22741 | sst2_loss=0.009839 | qqp_loss=0.077150 | stsb_loss=0.010196
# Epoch 4 | Shared Step 1150/22741 | sst2_loss=0.009565 | qqp_loss=0.077378 | stsb_loss=0.010257
# Epoch 4 | Shared Step 1200/22741 | sst2_loss=0.009481 | qqp_loss=0.077960 | stsb_loss=0.010275
# Epoch 4 | Shared Step 1250/22741 | sst2_loss=0.009581 | qqp_loss=0.078289 | stsb_loss=0.010224
# Epoch 4 | Shared Step 1300/22741 | sst2_loss=0.009316 | qqp_loss=0.077460 | stsb_loss=0.010230
# Epoch 4 | Shared Step 1350/22741 | sst2_loss=0.009110 | qqp_loss=0.077631 | stsb_loss=0.010178
# Epoch 4 | Shared Step 1400/22741 | sst2_loss=0.009074 | qqp_loss=0.078001 | stsb_loss=0.010146
# Epoch 4 | Shared Step 1450/22741 | sst2_loss=0.008997 | qqp_loss=0.077520 | stsb_loss=0.010154
# Epoch 4 | Shared Step 1500/22741 | sst2_loss=0.009241 | qqp_loss=0.077809 | stsb_loss=0.010167
# Epoch 4 | Shared Step 1550/22741 | sst2_loss=0.009795 | qqp_loss=0.077253 | stsb_loss=0.010314
# Epoch 4 | Shared Step 1600/22741 | sst2_loss=0.009650 | qqp_loss=0.076102 | stsb_loss=0.010358
# Epoch 4 | Shared Step 1650/22741 | sst2_loss=0.009647 | qqp_loss=0.076179 | stsb_loss=0.010387
# Epoch 4 | Shared Step 1700/22741 | sst2_loss=0.009795 | qqp_loss=0.075696 | stsb_loss=0.010343
# Epoch 4 | Shared Step 1750/22741 | sst2_loss=0.009929 | qqp_loss=0.075465 | stsb_loss=0.010302
# Epoch 4 | Shared Step 1800/22741 | sst2_loss=0.010095 | qqp_loss=0.075398 | stsb_loss=0.010339
# Epoch 4 | Shared Step 1850/22741 | sst2_loss=0.010273 | qqp_loss=0.075507 | stsb_loss=0.010375
# Epoch 4 | Shared Step 1900/22741 | sst2_loss=0.010260 | qqp_loss=0.076152 | stsb_loss=0.010406
# Epoch 4 | Shared Step 1950/22741 | sst2_loss=0.010407 | qqp_loss=0.075818 | stsb_loss=0.010374
# Epoch 4 | Shared Step 2000/22741 | sst2_loss=0.010629 | qqp_loss=0.075060 | stsb_loss=0.010372
# Epoch 4 | Shared Step 2050/22741 | sst2_loss=0.010498 | qqp_loss=0.074569 | stsb_loss=0.010349
# Epoch 4 | Shared Step 2100/22741 | sst2_loss=0.010470 | qqp_loss=0.074902 | stsb_loss=0.010364
# Epoch 4 | Shared Step 2150/22741 | sst2_loss=0.010512 | qqp_loss=0.074979 | stsb_loss=0.010349
# Epoch 4 | Shared Step 2200/22741 | sst2_loss=0.010531 | qqp_loss=0.074778 | stsb_loss=0.010351
# Epoch 4 | Shared Step 2250/22741 | sst2_loss=0.010386 | qqp_loss=0.074035 | stsb_loss=0.010353
# Epoch 4 | Shared Step 2300/22741 | sst2_loss=0.010502 | qqp_loss=0.074096 | stsb_loss=0.010346
# Epoch 4 | Shared Step 2350/22741 | sst2_loss=0.010401 | qqp_loss=0.073919 | stsb_loss=0.010337
# Epoch 4 | Shared Step 2400/22741 | sst2_loss=0.010338 | qqp_loss=0.073967 | stsb_loss=0.010310
# Epoch 4 | Shared Step 2450/22741 | sst2_loss=0.010262 | qqp_loss=0.073748 | stsb_loss=0.010348
# Epoch 4 | Shared Step 2500/22741 | sst2_loss=0.010116 | qqp_loss=0.073557 | stsb_loss=0.010335
# Epoch 4 | Shared Step 2550/22741 | sst2_loss=0.010189 | qqp_loss=0.073632 | stsb_loss=0.010335
# Epoch 4 | Shared Step 2600/22741 | sst2_loss=0.010256 | qqp_loss=0.073547 | stsb_loss=0.010357
# Epoch 4 | Shared Step 2650/22741 | sst2_loss=0.010267 | qqp_loss=0.073462 | stsb_loss=0.010352
# Epoch 4 | Shared Step 2700/22741 | sst2_loss=0.010237 | qqp_loss=0.073592 | stsb_loss=0.010345
# Epoch 4 | Shared Step 2750/22741 | sst2_loss=0.010091 | qqp_loss=0.073257 | stsb_loss=0.010342
# Epoch 4 | Shared Step 2800/22741 | sst2_loss=0.010109 | qqp_loss=0.072677 | stsb_loss=0.010304
# Epoch 4 | Shared Step 2850/22741 | sst2_loss=0.010183 | qqp_loss=0.072638 | stsb_loss=0.010299
# Epoch 4 | Shared Step 2900/22741 | sst2_loss=0.010280 | qqp_loss=0.072422 | stsb_loss=0.010294
# Epoch 4 | Shared Step 2950/22741 | sst2_loss=0.010640 | qqp_loss=0.072323 | stsb_loss=0.010285
# Epoch 4 | Shared Step 3000/22741 | sst2_loss=0.010726 | qqp_loss=0.072078 | stsb_loss=0.010297
# Epoch 4 | Shared Step 3050/22741 | sst2_loss=0.010686 | qqp_loss=0.071913 | stsb_loss=0.010294
# Epoch 4 | Shared Step 3100/22741 | sst2_loss=0.010616 | qqp_loss=0.071547 | stsb_loss=0.010285
# Epoch 4 | Shared Step 3150/22741 | sst2_loss=0.010644 | qqp_loss=0.071381 | stsb_loss=0.010273
# Epoch 4 | Shared Step 3200/22741 | sst2_loss=0.010677 | qqp_loss=0.071398 | stsb_loss=0.010266
# Epoch 4 | Shared Step 3250/22741 | sst2_loss=0.010565 | qqp_loss=0.071534 | stsb_loss=0.010238
# Epoch 4 | Shared Step 3300/22741 | sst2_loss=0.010543 | qqp_loss=0.071274 | stsb_loss=0.010240
# Epoch 4 | Shared Step 3350/22741 | sst2_loss=0.010666 | qqp_loss=0.071379 | stsb_loss=0.010240
# Epoch 4 | Shared Step 3400/22741 | sst2_loss=0.010620 | qqp_loss=0.071281 | stsb_loss=0.010249
# Epoch 4 | Shared Step 3450/22741 | sst2_loss=0.010742 | qqp_loss=0.070997 | stsb_loss=0.010227
# Epoch 4 | Shared Step 3500/22741 | sst2_loss=0.011025 | qqp_loss=0.070931 | stsb_loss=0.010214
# Epoch 4 | Shared Step 3550/22741 | sst2_loss=0.011011 | qqp_loss=0.070835 | stsb_loss=0.010193
# Epoch 4 | Shared Step 3600/22741 | sst2_loss=0.010950 | qqp_loss=0.070589 | stsb_loss=0.010191
# Epoch 4 | Shared Step 3650/22741 | sst2_loss=0.010898 | qqp_loss=0.070719 | stsb_loss=0.010184
# Epoch 4 | Shared Step 3700/22741 | sst2_loss=0.010955 | qqp_loss=0.070793 | stsb_loss=0.010180
# Epoch 4 | Shared Step 3750/22741 | sst2_loss=0.011076 | qqp_loss=0.070518 | stsb_loss=0.010182
# Epoch 4 | Shared Step 3800/22741 | sst2_loss=0.011032 | qqp_loss=0.070702 | stsb_loss=0.010166
# Epoch 4 | Shared Step 3850/22741 | sst2_loss=0.011005 | qqp_loss=0.071013 | stsb_loss=0.010151
# Epoch 4 | Shared Step 3900/22741 | sst2_loss=0.011207 | qqp_loss=0.071063 | stsb_loss=0.010135
# Epoch 4 | Shared Step 3950/22741 | sst2_loss=0.011406 | qqp_loss=0.071153 | stsb_loss=0.010141
# Epoch 4 | Shared Step 4000/22741 | sst2_loss=0.011493 | qqp_loss=0.071119 | stsb_loss=0.010125
# Epoch 4 | Shared Step 4050/22741 | sst2_loss=0.011574 | qqp_loss=0.071223 | stsb_loss=0.010103
# Epoch 4 | Shared Step 4100/22741 | sst2_loss=0.011566 | qqp_loss=0.071136 | stsb_loss=0.010106
# Epoch 4 | Shared Step 4150/22741 | sst2_loss=0.011476 | qqp_loss=0.071203 | stsb_loss=0.010098
# Epoch 4 | Shared Step 4200/22741 | sst2_loss=0.011494 | qqp_loss=0.070936 | stsb_loss=0.010076
# Epoch 4 | Shared Step 4250/22741 | sst2_loss=0.011611 | qqp_loss=0.070650 | stsb_loss=0.010060
# Epoch 4 | Shared Step 4300/22741 | sst2_loss=0.011600 | qqp_loss=0.070589 | stsb_loss=0.010050
# Epoch 4 | Shared Step 4350/22741 | sst2_loss=0.011502 | qqp_loss=0.070689 | stsb_loss=0.010039
# Epoch 4 | Shared Step 4400/22741 | sst2_loss=0.011521 | qqp_loss=0.070600 | stsb_loss=0.010040
# Epoch 4 | Shared Step 4450/22741 | sst2_loss=0.011434 | qqp_loss=0.070668 | stsb_loss=0.010034
# Epoch 4 | Shared Step 4500/22741 | sst2_loss=0.011375 | qqp_loss=0.070722 | stsb_loss=0.010024
# Epoch 4 | Shared Step 4550/22741 | sst2_loss=0.011335 | qqp_loss=0.070578 | stsb_loss=0.010013
# Epoch 4 | Shared Step 4600/22741 | sst2_loss=0.011260 | qqp_loss=0.070479 | stsb_loss=0.009992
# Epoch 4 | Shared Step 4650/22741 | sst2_loss=0.011188 | qqp_loss=0.070309 | stsb_loss=0.009993
# Epoch 4 | Shared Step 4700/22741 | sst2_loss=0.011267 | qqp_loss=0.070302 | stsb_loss=0.009997
# Epoch 4 | Shared Step 4750/22741 | sst2_loss=0.011237 | qqp_loss=0.069954 | stsb_loss=0.009982
# Epoch 4 | Shared Step 4800/22741 | sst2_loss=0.011138 | qqp_loss=0.070072 | stsb_loss=0.009984
# Epoch 4 | Shared Step 4850/22741 | sst2_loss=0.011154 | qqp_loss=0.070085 | stsb_loss=0.009972
# Epoch 4 | Shared Step 4900/22741 | sst2_loss=0.011169 | qqp_loss=0.069945 | stsb_loss=0.009966
# Epoch 4 | Shared Step 4950/22741 | sst2_loss=0.011112 | qqp_loss=0.069565 | stsb_loss=0.009948
# Epoch 4 | Shared Step 5000/22741 | sst2_loss=0.011031 | qqp_loss=0.069275 | stsb_loss=0.009936
# Epoch 4 | Shared Step 5050/22741 | sst2_loss=0.011061 | qqp_loss=0.069100 | stsb_loss=0.009922
# Epoch 4 | Shared Step 5100/22741 | sst2_loss=0.011005 | qqp_loss=0.069017 | stsb_loss=0.009920
# Epoch 4 | Shared Step 5150/22741 | sst2_loss=0.011008 | qqp_loss=0.069164 | stsb_loss=0.009924
# Epoch 4 | Shared Step 5200/22741 | sst2_loss=0.011018 | qqp_loss=0.069194 | stsb_loss=0.009925
# Epoch 4 | Shared Step 5250/22741 | sst2_loss=0.011104 | qqp_loss=0.069145 | stsb_loss=0.009921
# Epoch 4 | Shared Step 5300/22741 | sst2_loss=0.011047 | qqp_loss=0.069137 | stsb_loss=0.009920
# Epoch 4 | Shared Step 5350/22741 | sst2_loss=0.010991 | qqp_loss=0.069171 | stsb_loss=0.009909
# Epoch 4 | Shared Step 5400/22741 | sst2_loss=0.011027 | qqp_loss=0.069005 | stsb_loss=0.009902
# Epoch 4 | Shared Step 5450/22741 | sst2_loss=0.011018 | qqp_loss=0.068924 | stsb_loss=0.009906
# Epoch 4 | Shared Step 5500/22741 | sst2_loss=0.010959 | qqp_loss=0.068967 | stsb_loss=0.009903
# Epoch 4 | Shared Step 5550/22741 | sst2_loss=0.010941 | qqp_loss=0.068881 | stsb_loss=0.009918
# Epoch 4 | Shared Step 5600/22741 | sst2_loss=0.010888 | qqp_loss=0.068601 | stsb_loss=0.009930
# Epoch 4 | Shared Step 5650/22741 | sst2_loss=0.010849 | qqp_loss=0.068442 | stsb_loss=0.009928
# Epoch 4 | Shared Step 5700/22741 | sst2_loss=0.010878 | qqp_loss=0.068431 | stsb_loss=0.009917
# Epoch 4 | Shared Step 5750/22741 | sst2_loss=0.010834 | qqp_loss=0.068205 | stsb_loss=0.009923
# Epoch 4 | Shared Step 5800/22741 | sst2_loss=0.010761 | qqp_loss=0.068107 | stsb_loss=0.009918
# Epoch 4 | Shared Step 5850/22741 | sst2_loss=0.010696 | qqp_loss=0.067859 | stsb_loss=0.009910
# Epoch 4 | Shared Step 5900/22741 | sst2_loss=0.010770 | qqp_loss=0.068021 | stsb_loss=0.009909
# Epoch 4 | Shared Step 5950/22741 | sst2_loss=0.010720 | qqp_loss=0.067994 | stsb_loss=0.009905
# Epoch 4 | Shared Step 6000/22741 | sst2_loss=0.010737 | qqp_loss=0.067918 | stsb_loss=0.009899
# Epoch 4 | Shared Step 6050/22741 | sst2_loss=0.010773 | qqp_loss=0.068064 | stsb_loss=0.009908
# Epoch 4 | Shared Step 6100/22741 | sst2_loss=0.010858 | qqp_loss=0.067957 | stsb_loss=0.009896
# Epoch 4 | Shared Step 6150/22741 | sst2_loss=0.010996 | qqp_loss=0.067863 | stsb_loss=0.009898
# Epoch 4 | Shared Step 6200/22741 | sst2_loss=0.010917 | qqp_loss=0.067829 | stsb_loss=0.009890
# Epoch 4 | Shared Step 6250/22741 | sst2_loss=0.010876 | qqp_loss=0.067716 | stsb_loss=0.009894
# Epoch 4 | Shared Step 6300/22741 | sst2_loss=0.010858 | qqp_loss=0.067809 | stsb_loss=0.009900
# Epoch 4 | Shared Step 6350/22741 | sst2_loss=0.010918 | qqp_loss=0.067796 | stsb_loss=0.009887
# Epoch 4 | Shared Step 6400/22741 | sst2_loss=0.010903 | qqp_loss=0.067785 | stsb_loss=0.009885
# Epoch 4 | Shared Step 6450/22741 | sst2_loss=0.010999 | qqp_loss=0.067686 | stsb_loss=0.009879
# Epoch 4 | Shared Step 6500/22741 | sst2_loss=0.011079 | qqp_loss=0.067451 | stsb_loss=0.009880
# Epoch 4 | Shared Step 6550/22741 | sst2_loss=0.011039 | qqp_loss=0.067515 | stsb_loss=0.009876
# Epoch 4 | Shared Step 6600/22741 | sst2_loss=0.011062 | qqp_loss=0.067487 | stsb_loss=0.009881
# Epoch 4 | Shared Step 6650/22741 | sst2_loss=0.011114 | qqp_loss=0.067251 | stsb_loss=0.009883
# Epoch 4 | Shared Step 6700/22741 | sst2_loss=0.011050 | qqp_loss=0.067309 | stsb_loss=0.009880
# Epoch 4 | Shared Step 6750/22741 | sst2_loss=0.011095 | qqp_loss=0.067334 | stsb_loss=0.009873
# Epoch 4 | Shared Step 6800/22741 | sst2_loss=0.011162 | qqp_loss=0.067217 | stsb_loss=0.009867
# Epoch 4 | Shared Step 6850/22741 | sst2_loss=0.011175 | qqp_loss=0.067139 | stsb_loss=0.009864
# Epoch 4 | Shared Step 6900/22741 | sst2_loss=0.011234 | qqp_loss=0.067222 | stsb_loss=0.009871
# Epoch 4 | Shared Step 6950/22741 | sst2_loss=0.011211 | qqp_loss=0.067067 | stsb_loss=0.009867
# Epoch 4 | Shared Step 7000/22741 | sst2_loss=0.011206 | qqp_loss=0.067036 | stsb_loss=0.009878
# Epoch 4 | Shared Step 7050/22741 | sst2_loss=0.011183 | qqp_loss=0.067025 | stsb_loss=0.009885
# Epoch 4 | Shared Step 7100/22741 | sst2_loss=0.011152 | qqp_loss=0.066960 | stsb_loss=0.009891
# Epoch 4 | Shared Step 7150/22741 | sst2_loss=0.011237 | qqp_loss=0.066974 | stsb_loss=0.009916
# Epoch 4 | Shared Step 7200/22741 | sst2_loss=0.011329 | qqp_loss=0.066855 | stsb_loss=0.009918
# Epoch 4 | Shared Step 7250/22741 | sst2_loss=0.011339 | qqp_loss=0.066737 | stsb_loss=0.009929
# Epoch 4 | Shared Step 7300/22741 | sst2_loss=0.011273 | qqp_loss=0.066724 | stsb_loss=0.009932
# Epoch 4 | Shared Step 7350/22741 | sst2_loss=0.011226 | qqp_loss=0.066586 | stsb_loss=0.009925
# Epoch 4 | Shared Step 7400/22741 | sst2_loss=0.011262 | qqp_loss=0.066465 | stsb_loss=0.009928
# Epoch 4 | Shared Step 7450/22741 | sst2_loss=0.011247 | qqp_loss=0.066380 | stsb_loss=0.009927
# Epoch 4 | Shared Step 7500/22741 | sst2_loss=0.011216 | qqp_loss=0.066232 | stsb_loss=0.009920
# Epoch 4 | Shared Step 7550/22741 | sst2_loss=0.011190 | qqp_loss=0.066147 | stsb_loss=0.009921
# Epoch 4 | Shared Step 7600/22741 | sst2_loss=0.011176 | qqp_loss=0.066364 | stsb_loss=0.009919
# Epoch 4 | Shared Step 7650/22741 | sst2_loss=0.011134 | qqp_loss=0.066328 | stsb_loss=0.009920
# Epoch 4 | Shared Step 7700/22741 | sst2_loss=0.011144 | qqp_loss=0.066583 | stsb_loss=0.009921
# Epoch 4 | Shared Step 7750/22741 | sst2_loss=0.011126 | qqp_loss=0.066482 | stsb_loss=0.009919
# Epoch 4 | Shared Step 7800/22741 | sst2_loss=0.011088 | qqp_loss=0.066481 | stsb_loss=0.009917
# Epoch 4 | Shared Step 7850/22741 | sst2_loss=0.011119 | qqp_loss=0.066393 | stsb_loss=0.009907
# Epoch 4 | Shared Step 7900/22741 | sst2_loss=0.011061 | qqp_loss=0.066244 | stsb_loss=0.009902
# Epoch 4 | Shared Step 7950/22741 | sst2_loss=0.011169 | qqp_loss=0.066163 | stsb_loss=0.009902
# Epoch 4 | Shared Step 8000/22741 | sst2_loss=0.011132 | qqp_loss=0.066292 | stsb_loss=0.009901
# Epoch 4 | Shared Step 8050/22741 | sst2_loss=0.011158 | qqp_loss=0.066257 | stsb_loss=0.009900
# Epoch 4 | Shared Step 8100/22741 | sst2_loss=0.011186 | qqp_loss=0.066160 | stsb_loss=0.009894
# Epoch 4 | Shared Step 8150/22741 | sst2_loss=0.011188 | qqp_loss=0.066071 | stsb_loss=0.009890
# Epoch 4 | Shared Step 8200/22741 | sst2_loss=0.011265 | qqp_loss=0.066160 | stsb_loss=0.009891
# Epoch 4 | Shared Step 8250/22741 | sst2_loss=0.011332 | qqp_loss=0.066181 | stsb_loss=0.009892
# Epoch 4 | Shared Step 8300/22741 | sst2_loss=0.011376 | qqp_loss=0.066305 | stsb_loss=0.009888
# Epoch 4 | Shared Step 8350/22741 | sst2_loss=0.011453 | qqp_loss=0.066240 | stsb_loss=0.009923
# Epoch 4 | Shared Step 8400/22741 | sst2_loss=0.011410 | qqp_loss=0.066118 | stsb_loss=0.009944
# Epoch 4 | Shared Step 8450/22741 | sst2_loss=0.011364 | qqp_loss=0.066147 | stsb_loss=0.009950
# Epoch 4 | Shared Step 8500/22741 | sst2_loss=0.011324 | qqp_loss=0.066150 | stsb_loss=0.009943
# Epoch 4 | Shared Step 8550/22741 | sst2_loss=0.011277 | qqp_loss=0.066195 | stsb_loss=0.009939
# Epoch 4 | Shared Step 8600/22741 | sst2_loss=0.011232 | qqp_loss=0.066028 | stsb_loss=0.009937
# Epoch 4 | Shared Step 8650/22741 | sst2_loss=0.011175 | qqp_loss=0.066192 | stsb_loss=0.009936
# Epoch 4 | Shared Step 8700/22741 | sst2_loss=0.011128 | qqp_loss=0.066209 | stsb_loss=0.009938
# Epoch 4 | Shared Step 8750/22741 | sst2_loss=0.011137 | qqp_loss=0.066104 | stsb_loss=0.009933
# Epoch 4 | Shared Step 8800/22741 | sst2_loss=0.011081 | qqp_loss=0.066022 | stsb_loss=0.009923
# Epoch 4 | Shared Step 8850/22741 | sst2_loss=0.011084 | qqp_loss=0.065888 | stsb_loss=0.009923
# Epoch 4 | Shared Step 8900/22741 | sst2_loss=0.011046 | qqp_loss=0.065820 | stsb_loss=0.009925
# Epoch 4 | Shared Step 8950/22741 | sst2_loss=0.011012 | qqp_loss=0.065870 | stsb_loss=0.009923
# Epoch 4 | Shared Step 9000/22741 | sst2_loss=0.010970 | qqp_loss=0.065817 | stsb_loss=0.009925
# Epoch 4 | Shared Step 9050/22741 | sst2_loss=0.011021 | qqp_loss=0.065731 | stsb_loss=0.009915
# Epoch 4 | Shared Step 9100/22741 | sst2_loss=0.010993 | qqp_loss=0.065778 | stsb_loss=0.009922
# Epoch 4 | Shared Step 9150/22741 | sst2_loss=0.011100 | qqp_loss=0.065784 | stsb_loss=0.009921
# Epoch 4 | Shared Step 9200/22741 | sst2_loss=0.011101 | qqp_loss=0.065819 | stsb_loss=0.009921
# Epoch 4 | Shared Step 9250/22741 | sst2_loss=0.011064 | qqp_loss=0.065899 | stsb_loss=0.009916
# Epoch 4 | Shared Step 9300/22741 | sst2_loss=0.011028 | qqp_loss=0.065971 | stsb_loss=0.009913
# Epoch 4 | Shared Step 9350/22741 | sst2_loss=0.010990 | qqp_loss=0.065931 | stsb_loss=0.009910
# Epoch 4 | Shared Step 9400/22741 | sst2_loss=0.011087 | qqp_loss=0.065965 | stsb_loss=0.009905
# Epoch 4 | Shared Step 9450/22741 | sst2_loss=0.011071 | qqp_loss=0.065996 | stsb_loss=0.009902
# Epoch 4 | Shared Step 9500/22741 | sst2_loss=0.011018 | qqp_loss=0.065944 | stsb_loss=0.009900
# Epoch 4 | Shared Step 9550/22741 | sst2_loss=0.011013 | qqp_loss=0.065928 | stsb_loss=0.009914
# Epoch 4 | Shared Step 9600/22741 | sst2_loss=0.011006 | qqp_loss=0.065966 | stsb_loss=0.009931
# Epoch 4 | Shared Step 9650/22741 | sst2_loss=0.010998 | qqp_loss=0.065871 | stsb_loss=0.009919
# Epoch 4 | Shared Step 9700/22741 | sst2_loss=0.010948 | qqp_loss=0.065702 | stsb_loss=0.009912
# Epoch 4 | Shared Step 9750/22741 | sst2_loss=0.010935 | qqp_loss=0.065676 | stsb_loss=0.009908
# Epoch 4 | Shared Step 9800/22741 | sst2_loss=0.010939 | qqp_loss=0.065609 | stsb_loss=0.009908
# Epoch 4 | Shared Step 9850/22741 | sst2_loss=0.010903 | qqp_loss=0.065555 | stsb_loss=0.009904
# Epoch 4 | Shared Step 9900/22741 | sst2_loss=0.010937 | qqp_loss=0.065518 | stsb_loss=0.009909
# Epoch 4 | Shared Step 9950/22741 | sst2_loss=0.010930 | qqp_loss=0.065551 | stsb_loss=0.009902
# Epoch 4 | Shared Step 10000/22741 | sst2_loss=0.010923 | qqp_loss=0.065536 | stsb_loss=0.009898
# Epoch 4 | Shared Step 10050/22741 | sst2_loss=0.010933 | qqp_loss=0.065553 | stsb_loss=0.009891
# Epoch 4 | Shared Step 10100/22741 | sst2_loss=0.010934 | qqp_loss=0.065536 | stsb_loss=0.009880
# Epoch 4 | Shared Step 10150/22741 | sst2_loss=0.010963 | qqp_loss=0.065527 | stsb_loss=0.009876
# Epoch 4 | Shared Step 10200/22741 | sst2_loss=0.011051 | qqp_loss=0.065439 | stsb_loss=0.009873
# Epoch 4 | Shared Step 10250/22741 | sst2_loss=0.011094 | qqp_loss=0.065488 | stsb_loss=0.009868
# Epoch 4 | Shared Step 10300/22741 | sst2_loss=0.011096 | qqp_loss=0.065439 | stsb_loss=0.009865
# Epoch 4 | Shared Step 10350/22741 | sst2_loss=0.011101 | qqp_loss=0.065428 | stsb_loss=0.009858
# Epoch 4 | Shared Step 10400/22741 | sst2_loss=0.011060 | qqp_loss=0.065274 | stsb_loss=0.009853
# Epoch 4 | Shared Step 10450/22741 | sst2_loss=0.011077 | qqp_loss=0.065268 | stsb_loss=0.009852
# Epoch 4 | Shared Step 10500/22741 | sst2_loss=0.011045 | qqp_loss=0.065212 | stsb_loss=0.009843
# Epoch 4 | Shared Step 10550/22741 | sst2_loss=0.011042 | qqp_loss=0.065086 | stsb_loss=0.009839
# Epoch 4 | Shared Step 10600/22741 | sst2_loss=0.011028 | qqp_loss=0.065030 | stsb_loss=0.009842
# Epoch 4 | Shared Step 10650/22741 | sst2_loss=0.010989 | qqp_loss=0.065039 | stsb_loss=0.009837
# Epoch 4 | Shared Step 10700/22741 | sst2_loss=0.010966 | qqp_loss=0.064992 | stsb_loss=0.009828
# Epoch 4 | Shared Step 10750/22741 | sst2_loss=0.010996 | qqp_loss=0.064953 | stsb_loss=0.009838
# Epoch 4 | Shared Step 10800/22741 | sst2_loss=0.010977 | qqp_loss=0.064875 | stsb_loss=0.009836
# Epoch 4 | Shared Step 10850/22741 | sst2_loss=0.010951 | qqp_loss=0.064880 | stsb_loss=0.009841
# Epoch 4 | Shared Step 10900/22741 | sst2_loss=0.010944 | qqp_loss=0.064956 | stsb_loss=0.009840
# Epoch 4 | Shared Step 10950/22741 | sst2_loss=0.010946 | qqp_loss=0.064955 | stsb_loss=0.009837
# Epoch 4 | Shared Step 11000/22741 | sst2_loss=0.010915 | qqp_loss=0.064963 | stsb_loss=0.009833
# Epoch 4 | Shared Step 11050/22741 | sst2_loss=0.010875 | qqp_loss=0.064832 | stsb_loss=0.009825
# Epoch 4 | Shared Step 11100/22741 | sst2_loss=0.010833 | qqp_loss=0.064800 | stsb_loss=0.009824
# Epoch 4 | Shared Step 11150/22741 | sst2_loss=0.010876 | qqp_loss=0.064862 | stsb_loss=0.009818
# Epoch 4 | Shared Step 11200/22741 | sst2_loss=0.010901 | qqp_loss=0.064846 | stsb_loss=0.009819
# Epoch 4 | Shared Step 11250/22741 | sst2_loss=0.010885 | qqp_loss=0.064825 | stsb_loss=0.009814
# Epoch 4 | Shared Step 11300/22741 | sst2_loss=0.010858 | qqp_loss=0.064755 | stsb_loss=0.009807
# Epoch 4 | Shared Step 11350/22741 | sst2_loss=0.010864 | qqp_loss=0.064753 | stsb_loss=0.009831
# Epoch 4 | Shared Step 11400/22741 | sst2_loss=0.010820 | qqp_loss=0.064736 | stsb_loss=0.009829
# Epoch 4 | Shared Step 11450/22741 | sst2_loss=0.010838 | qqp_loss=0.064726 | stsb_loss=0.009833
# Epoch 4 | Shared Step 11500/22741 | sst2_loss=0.010863 | qqp_loss=0.064741 | stsb_loss=0.009839
# Epoch 4 | Shared Step 11550/22741 | sst2_loss=0.010847 | qqp_loss=0.064698 | stsb_loss=0.009837
# Epoch 4 | Shared Step 11600/22741 | sst2_loss=0.010822 | qqp_loss=0.064626 | stsb_loss=0.009830
# Epoch 4 | Shared Step 11650/22741 | sst2_loss=0.010878 | qqp_loss=0.064615 | stsb_loss=0.009831
# Epoch 4 | Shared Step 11700/22741 | sst2_loss=0.010843 | qqp_loss=0.064628 | stsb_loss=0.009829
# Epoch 4 | Shared Step 11750/22741 | sst2_loss=0.010813 | qqp_loss=0.064669 | stsb_loss=0.009824
# Epoch 4 | Shared Step 11800/22741 | sst2_loss=0.010776 | qqp_loss=0.064669 | stsb_loss=0.009819
# Epoch 4 | Shared Step 11850/22741 | sst2_loss=0.010788 | qqp_loss=0.064651 | stsb_loss=0.009823
# Epoch 4 | Shared Step 11900/22741 | sst2_loss=0.010788 | qqp_loss=0.064610 | stsb_loss=0.009820
# Epoch 4 | Shared Step 11950/22741 | sst2_loss=0.010786 | qqp_loss=0.064620 | stsb_loss=0.009814
# Epoch 4 | Shared Step 12000/22741 | sst2_loss=0.010806 | qqp_loss=0.064588 | stsb_loss=0.009811
# Epoch 4 | Shared Step 12050/22741 | sst2_loss=0.010779 | qqp_loss=0.064604 | stsb_loss=0.009805
# Epoch 4 | Shared Step 12100/22741 | sst2_loss=0.010744 | qqp_loss=0.064584 | stsb_loss=0.009800
# Epoch 4 | Shared Step 12150/22741 | sst2_loss=0.010708 | qqp_loss=0.064516 | stsb_loss=0.009796
# Epoch 4 | Shared Step 12200/22741 | sst2_loss=0.010735 | qqp_loss=0.064484 | stsb_loss=0.009795
# Epoch 4 | Shared Step 12250/22741 | sst2_loss=0.010762 | qqp_loss=0.064431 | stsb_loss=0.009789
# Epoch 4 | Shared Step 12300/22741 | sst2_loss=0.010766 | qqp_loss=0.064311 | stsb_loss=0.009783
# Epoch 4 | Shared Step 12350/22741 | sst2_loss=0.010769 | qqp_loss=0.064307 | stsb_loss=0.009783
# Epoch 4 | Shared Step 12400/22741 | sst2_loss=0.010782 | qqp_loss=0.064227 | stsb_loss=0.009781
# Epoch 4 | Shared Step 12450/22741 | sst2_loss=0.010769 | qqp_loss=0.064187 | stsb_loss=0.009774
# Epoch 4 | Shared Step 12500/22741 | sst2_loss=0.010787 | qqp_loss=0.064224 | stsb_loss=0.009772
# Epoch 4 | Shared Step 12550/22741 | sst2_loss=0.010812 | qqp_loss=0.064169 | stsb_loss=0.009767
# Epoch 4 | Shared Step 12600/22741 | sst2_loss=0.010875 | qqp_loss=0.064184 | stsb_loss=0.009766
# Epoch 4 | Shared Step 12650/22741 | sst2_loss=0.010852 | qqp_loss=0.064206 | stsb_loss=0.009762
# Epoch 4 | Shared Step 12700/22741 | sst2_loss=0.010820 | qqp_loss=0.064120 | stsb_loss=0.009754
# Epoch 4 | Shared Step 12750/22741 | sst2_loss=0.010797 | qqp_loss=0.064157 | stsb_loss=0.009753
# Epoch 4 | Shared Step 12800/22741 | sst2_loss=0.010806 | qqp_loss=0.064179 | stsb_loss=0.009755
# Epoch 4 | Shared Step 12850/22741 | sst2_loss=0.010785 | qqp_loss=0.064176 | stsb_loss=0.009748
# Epoch 4 | Shared Step 12900/22741 | sst2_loss=0.010766 | qqp_loss=0.064182 | stsb_loss=0.009746
# Epoch 4 | Shared Step 12950/22741 | sst2_loss=0.010740 | qqp_loss=0.064133 | stsb_loss=0.009741
# Epoch 4 | Shared Step 13000/22741 | sst2_loss=0.010724 | qqp_loss=0.064123 | stsb_loss=0.009735
# Epoch 4 | Shared Step 13050/22741 | sst2_loss=0.010738 | qqp_loss=0.064079 | stsb_loss=0.009728
# Epoch 4 | Shared Step 13100/22741 | sst2_loss=0.010739 | qqp_loss=0.064044 | stsb_loss=0.009718
# Epoch 4 | Shared Step 13150/22741 | sst2_loss=0.010706 | qqp_loss=0.063966 | stsb_loss=0.009714
# Epoch 4 | Shared Step 13200/22741 | sst2_loss=0.010686 | qqp_loss=0.063932 | stsb_loss=0.009710
# Epoch 4 | Shared Step 13250/22741 | sst2_loss=0.010718 | qqp_loss=0.063900 | stsb_loss=0.009707
# Epoch 4 | Shared Step 13300/22741 | sst2_loss=0.010701 | qqp_loss=0.063874 | stsb_loss=0.009700
# Epoch 4 | Shared Step 13350/22741 | sst2_loss=0.010697 | qqp_loss=0.063895 | stsb_loss=0.009694
# Epoch 4 | Shared Step 13400/22741 | sst2_loss=0.010712 | qqp_loss=0.063893 | stsb_loss=0.009689
# Epoch 4 | Shared Step 13450/22741 | sst2_loss=0.010722 | qqp_loss=0.063869 | stsb_loss=0.009684
# Epoch 4 | Shared Step 13500/22741 | sst2_loss=0.010758 | qqp_loss=0.063783 | stsb_loss=0.009693
# Epoch 4 | Shared Step 13550/22741 | sst2_loss=0.010730 | qqp_loss=0.063803 | stsb_loss=0.009708
# Epoch 4 | Shared Step 13600/22741 | sst2_loss=0.010715 | qqp_loss=0.063825 | stsb_loss=0.009714
# Epoch 4 | Shared Step 13650/22741 | sst2_loss=0.010719 | qqp_loss=0.063862 | stsb_loss=0.009713
# Epoch 4 | Shared Step 13700/22741 | sst2_loss=0.010749 | qqp_loss=0.063825 | stsb_loss=0.009708
# Epoch 4 | Shared Step 13750/22741 | sst2_loss=0.010759 | qqp_loss=0.063857 | stsb_loss=0.009704
# Epoch 4 | Shared Step 13800/22741 | sst2_loss=0.010759 | qqp_loss=0.063811 | stsb_loss=0.009702
# Epoch 4 | Shared Step 13850/22741 | sst2_loss=0.010755 | qqp_loss=0.063789 | stsb_loss=0.009716
# Epoch 4 | Shared Step 13900/22741 | sst2_loss=0.010737 | qqp_loss=0.063876 | stsb_loss=0.009712
# Epoch 4 | Shared Step 13950/22741 | sst2_loss=0.010727 | qqp_loss=0.063836 | stsb_loss=0.009710
# Epoch 4 | Shared Step 14000/22741 | sst2_loss=0.010698 | qqp_loss=0.063737 | stsb_loss=0.009705
# Epoch 4 | Shared Step 14050/22741 | sst2_loss=0.010665 | qqp_loss=0.063848 | stsb_loss=0.009703
# Epoch 4 | Shared Step 14100/22741 | sst2_loss=0.010636 | qqp_loss=0.063782 | stsb_loss=0.009700
# Epoch 4 | Shared Step 14150/22741 | sst2_loss=0.010643 | qqp_loss=0.063836 | stsb_loss=0.009698
# Epoch 4 | Shared Step 14200/22741 | sst2_loss=0.010626 | qqp_loss=0.063901 | stsb_loss=0.009692
# Epoch 4 | Shared Step 14250/22741 | sst2_loss=0.010605 | qqp_loss=0.063976 | stsb_loss=0.009688
# Epoch 4 | Shared Step 14300/22741 | sst2_loss=0.010648 | qqp_loss=0.063996 | stsb_loss=0.009686
# Epoch 4 | Shared Step 14350/22741 | sst2_loss=0.010645 | qqp_loss=0.064021 | stsb_loss=0.009685
# Epoch 4 | Shared Step 14400/22741 | sst2_loss=0.010675 | qqp_loss=0.064002 | stsb_loss=0.009680
# Epoch 4 | Shared Step 14450/22741 | sst2_loss=0.010719 | qqp_loss=0.064035 | stsb_loss=0.009676
# Epoch 4 | Shared Step 14500/22741 | sst2_loss=0.010735 | qqp_loss=0.064023 | stsb_loss=0.009672
# Epoch 4 | Shared Step 14550/22741 | sst2_loss=0.010742 | qqp_loss=0.064022 | stsb_loss=0.009670
# Epoch 4 | Shared Step 14600/22741 | sst2_loss=0.010762 | qqp_loss=0.063940 | stsb_loss=0.009668
# Epoch 4 | Shared Step 14650/22741 | sst2_loss=0.010732 | qqp_loss=0.063980 | stsb_loss=0.009668
# Epoch 4 | Shared Step 14700/22741 | sst2_loss=0.010700 | qqp_loss=0.063979 | stsb_loss=0.009662
# Epoch 4 | Shared Step 14750/22741 | sst2_loss=0.010685 | qqp_loss=0.064022 | stsb_loss=0.009660
# Epoch 4 | Shared Step 14800/22741 | sst2_loss=0.010688 | qqp_loss=0.064007 | stsb_loss=0.009658
# Epoch 4 | Shared Step 14850/22741 | sst2_loss=0.010718 | qqp_loss=0.063987 | stsb_loss=0.009658
# Epoch 4 | Shared Step 14900/22741 | sst2_loss=0.010705 | qqp_loss=0.064014 | stsb_loss=0.009653
# Epoch 4 | Shared Step 14950/22741 | sst2_loss=0.010686 | qqp_loss=0.064078 | stsb_loss=0.009651
# Epoch 4 | Shared Step 15000/22741 | sst2_loss=0.010711 | qqp_loss=0.064125 | stsb_loss=0.009646
# Epoch 4 | Shared Step 15050/22741 | sst2_loss=0.010740 | qqp_loss=0.064140 | stsb_loss=0.009646
# Epoch 4 | Shared Step 15100/22741 | sst2_loss=0.010716 | qqp_loss=0.064138 | stsb_loss=0.009648
# Epoch 4 | Shared Step 15150/22741 | sst2_loss=0.010694 | qqp_loss=0.064157 | stsb_loss=0.009645
# Epoch 4 | Shared Step 15200/22741 | sst2_loss=0.010669 | qqp_loss=0.064109 | stsb_loss=0.009643
# Epoch 4 | Shared Step 15250/22741 | sst2_loss=0.010648 | qqp_loss=0.064024 | stsb_loss=0.009641
# Epoch 4 | Shared Step 15300/22741 | sst2_loss=0.010659 | qqp_loss=0.064064 | stsb_loss=0.009639
# Epoch 4 | Shared Step 15350/22741 | sst2_loss=0.010657 | qqp_loss=0.064010 | stsb_loss=0.009634
# Epoch 4 | Shared Step 15400/22741 | sst2_loss=0.010664 | qqp_loss=0.063946 | stsb_loss=0.009630
# Epoch 4 | Shared Step 15450/22741 | sst2_loss=0.010665 | qqp_loss=0.063985 | stsb_loss=0.009630
# Epoch 4 | Shared Step 15500/22741 | sst2_loss=0.010657 | qqp_loss=0.063986 | stsb_loss=0.009627
# Epoch 4 | Shared Step 15550/22741 | sst2_loss=0.010643 | qqp_loss=0.063963 | stsb_loss=0.009623
# Epoch 4 | Shared Step 15600/22741 | sst2_loss=0.010642 | qqp_loss=0.063949 | stsb_loss=0.009620
# Epoch 4 | Shared Step 15650/22741 | sst2_loss=0.010659 | qqp_loss=0.063924 | stsb_loss=0.009617
# Epoch 4 | Shared Step 15700/22741 | sst2_loss=0.010637 | qqp_loss=0.063986 | stsb_loss=0.009614
# Epoch 4 | Shared Step 15750/22741 | sst2_loss=0.010639 | qqp_loss=0.064025 | stsb_loss=0.009608
# Epoch 4 | Shared Step 15800/22741 | sst2_loss=0.010657 | qqp_loss=0.064080 | stsb_loss=0.009603
# Epoch 4 | Shared Step 15850/22741 | sst2_loss=0.010652 | qqp_loss=0.064103 | stsb_loss=0.009598
# Epoch 4 | Shared Step 15900/22741 | sst2_loss=0.010645 | qqp_loss=0.064120 | stsb_loss=0.009595
# Epoch 4 | Shared Step 15950/22741 | sst2_loss=0.010633 | qqp_loss=0.064189 | stsb_loss=0.009592
# Epoch 4 | Shared Step 16000/22741 | sst2_loss=0.010616 | qqp_loss=0.064217 | stsb_loss=0.009590
# Epoch 4 | Shared Step 16050/22741 | sst2_loss=0.010591 | qqp_loss=0.064281 | stsb_loss=0.009586
# Epoch 4 | Shared Step 16100/22741 | sst2_loss=0.010622 | qqp_loss=0.064241 | stsb_loss=0.009580
# Epoch 4 | Shared Step 16150/22741 | sst2_loss=0.010624 | qqp_loss=0.064268 | stsb_loss=0.009577
# Epoch 4 | Shared Step 16200/22741 | sst2_loss=0.010618 | qqp_loss=0.064302 | stsb_loss=0.009574
# Epoch 4 | Shared Step 16250/22741 | sst2_loss=0.010598 | qqp_loss=0.064278 | stsb_loss=0.009575
# Epoch 4 | Shared Step 16300/22741 | sst2_loss=0.010573 | qqp_loss=0.064246 | stsb_loss=0.009574
# Epoch 4 | Shared Step 16350/22741 | sst2_loss=0.010581 | qqp_loss=0.064191 | stsb_loss=0.009573
# Epoch 4 | Shared Step 16400/22741 | sst2_loss=0.010559 | qqp_loss=0.064190 | stsb_loss=0.009575
# Epoch 4 | Shared Step 16450/22741 | sst2_loss=0.010566 | qqp_loss=0.064181 | stsb_loss=0.009578
# Epoch 4 | Shared Step 16500/22741 | sst2_loss=0.010575 | qqp_loss=0.064250 | stsb_loss=0.009588
# Epoch 4 | Shared Step 16550/22741 | sst2_loss=0.010550 | qqp_loss=0.064199 | stsb_loss=0.009594
# Epoch 4 | Shared Step 16600/22741 | sst2_loss=0.010544 | qqp_loss=0.064194 | stsb_loss=0.009593
# Epoch 4 | Shared Step 16650/22741 | sst2_loss=0.010575 | qqp_loss=0.064181 | stsb_loss=0.009592
# Epoch 4 | Shared Step 16700/22741 | sst2_loss=0.010565 | qqp_loss=0.064196 | stsb_loss=0.009600
# Epoch 4 | Shared Step 16750/22741 | sst2_loss=0.010563 | qqp_loss=0.064211 | stsb_loss=0.009600
# Epoch 4 | Shared Step 16800/22741 | sst2_loss=0.010541 | qqp_loss=0.064192 | stsb_loss=0.009600
# Epoch 4 | Shared Step 16850/22741 | sst2_loss=0.010540 | qqp_loss=0.064133 | stsb_loss=0.009594
# Epoch 4 | Shared Step 16900/22741 | sst2_loss=0.010587 | qqp_loss=0.064110 | stsb_loss=0.009592
# Epoch 4 | Shared Step 16950/22741 | sst2_loss=0.010598 | qqp_loss=0.064089 | stsb_loss=0.009590
# Epoch 4 | Shared Step 17000/22741 | sst2_loss=0.010577 | qqp_loss=0.064031 | stsb_loss=0.009589
# Epoch 4 | Shared Step 17050/22741 | sst2_loss=0.010589 | qqp_loss=0.063984 | stsb_loss=0.009588
# Epoch 4 | Shared Step 17100/22741 | sst2_loss=0.010564 | qqp_loss=0.064000 | stsb_loss=0.009583
# Epoch 4 | Shared Step 17150/22741 | sst2_loss=0.010542 | qqp_loss=0.063975 | stsb_loss=0.009576
# Epoch 4 | Shared Step 17200/22741 | sst2_loss=0.010539 | qqp_loss=0.064014 | stsb_loss=0.009576
# Epoch 4 | Shared Step 17250/22741 | sst2_loss=0.010524 | qqp_loss=0.064011 | stsb_loss=0.009571
# Epoch 4 | Shared Step 17300/22741 | sst2_loss=0.010503 | qqp_loss=0.064038 | stsb_loss=0.009567
# Epoch 4 | Shared Step 17350/22741 | sst2_loss=0.010478 | qqp_loss=0.064084 | stsb_loss=0.009563
# Epoch 4 | Shared Step 17400/22741 | sst2_loss=0.010491 | qqp_loss=0.064123 | stsb_loss=0.009560
# Epoch 4 | Shared Step 17450/22741 | sst2_loss=0.010491 | qqp_loss=0.064119 | stsb_loss=0.009554
# Epoch 4 | Shared Step 17500/22741 | sst2_loss=0.010484 | qqp_loss=0.064153 | stsb_loss=0.009549
# Epoch 4 | Shared Step 17550/22741 | sst2_loss=0.010467 | qqp_loss=0.064157 | stsb_loss=0.009545
# Epoch 4 | Shared Step 17600/22741 | sst2_loss=0.010487 | qqp_loss=0.064098 | stsb_loss=0.009541
# Epoch 4 | Shared Step 17650/22741 | sst2_loss=0.010472 | qqp_loss=0.064085 | stsb_loss=0.009538
# Epoch 4 | Shared Step 17700/22741 | sst2_loss=0.010470 | qqp_loss=0.064128 | stsb_loss=0.009534
# Epoch 4 | Shared Step 17750/22741 | sst2_loss=0.010454 | qqp_loss=0.064116 | stsb_loss=0.009531
# Epoch 4 | Shared Step 17800/22741 | sst2_loss=0.010444 | qqp_loss=0.064090 | stsb_loss=0.009527
# Epoch 4 | Shared Step 17850/22741 | sst2_loss=0.010424 | qqp_loss=0.063977 | stsb_loss=0.009522
# Epoch 4 | Shared Step 17900/22741 | sst2_loss=0.010406 | qqp_loss=0.063968 | stsb_loss=0.009516
# Epoch 4 | Shared Step 17950/22741 | sst2_loss=0.010389 | qqp_loss=0.063994 | stsb_loss=0.009512
# Epoch 4 | Shared Step 18000/22741 | sst2_loss=0.010368 | qqp_loss=0.063996 | stsb_loss=0.009506
# Epoch 4 | Shared Step 18050/22741 | sst2_loss=0.010366 | qqp_loss=0.064019 | stsb_loss=0.009504
# Epoch 4 | Shared Step 18100/22741 | sst2_loss=0.010377 | qqp_loss=0.064064 | stsb_loss=0.009502
# Epoch 4 | Shared Step 18150/22741 | sst2_loss=0.010356 | qqp_loss=0.064075 | stsb_loss=0.009507
# Epoch 4 | Shared Step 18200/22741 | sst2_loss=0.010407 | qqp_loss=0.064049 | stsb_loss=0.009501
# Epoch 4 | Shared Step 18250/22741 | sst2_loss=0.010415 | qqp_loss=0.064043 | stsb_loss=0.009497
# Epoch 4 | Shared Step 18300/22741 | sst2_loss=0.010405 | qqp_loss=0.063997 | stsb_loss=0.009494
# Epoch 4 | Shared Step 18350/22741 | sst2_loss=0.010423 | qqp_loss=0.064001 | stsb_loss=0.009493
# Epoch 4 | Shared Step 18400/22741 | sst2_loss=0.010408 | qqp_loss=0.063950 | stsb_loss=0.009495
# Epoch 4 | Shared Step 18450/22741 | sst2_loss=0.010384 | qqp_loss=0.063973 | stsb_loss=0.009495
# Epoch 4 | Shared Step 18500/22741 | sst2_loss=0.010382 | qqp_loss=0.063940 | stsb_loss=0.009496
# Epoch 4 | Shared Step 18550/22741 | sst2_loss=0.010366 | qqp_loss=0.063858 | stsb_loss=0.009491
# Epoch 4 | Shared Step 18600/22741 | sst2_loss=0.010364 | qqp_loss=0.063881 | stsb_loss=0.009496
# Epoch 4 | Shared Step 18650/22741 | sst2_loss=0.010370 | qqp_loss=0.063860 | stsb_loss=0.009496
# Epoch 4 | Shared Step 18700/22741 | sst2_loss=0.010353 | qqp_loss=0.063860 | stsb_loss=0.009494
# Epoch 4 | Shared Step 18750/22741 | sst2_loss=0.010335 | qqp_loss=0.063862 | stsb_loss=0.009492
# Epoch 4 | Shared Step 18800/22741 | sst2_loss=0.010347 | qqp_loss=0.063816 | stsb_loss=0.009490
# Epoch 4 | Shared Step 18850/22741 | sst2_loss=0.010322 | qqp_loss=0.063834 | stsb_loss=0.009493
# Epoch 4 | Shared Step 18900/22741 | sst2_loss=0.010298 | qqp_loss=0.063817 | stsb_loss=0.009492
# Epoch 4 | Shared Step 18950/22741 | sst2_loss=0.010320 | qqp_loss=0.063792 | stsb_loss=0.009488
# Epoch 4 | Shared Step 19000/22741 | sst2_loss=0.010307 | qqp_loss=0.063745 | stsb_loss=0.009485
# Epoch 4 | Shared Step 19050/22741 | sst2_loss=0.010324 | qqp_loss=0.063753 | stsb_loss=0.009482
# Epoch 4 | Shared Step 19100/22741 | sst2_loss=0.010307 | qqp_loss=0.063778 | stsb_loss=0.009479
# Epoch 4 | Shared Step 19150/22741 | sst2_loss=0.010330 | qqp_loss=0.063773 | stsb_loss=0.009479
# Epoch 4 | Shared Step 19200/22741 | sst2_loss=0.010346 | qqp_loss=0.063762 | stsb_loss=0.009477
# Epoch 4 | Shared Step 19250/22741 | sst2_loss=0.010349 | qqp_loss=0.063771 | stsb_loss=0.009478
# Epoch 4 | Shared Step 19300/22741 | sst2_loss=0.010373 | qqp_loss=0.063707 | stsb_loss=0.009475
# Epoch 4 | Shared Step 19350/22741 | sst2_loss=0.010377 | qqp_loss=0.063749 | stsb_loss=0.009474
# Epoch 4 | Shared Step 19400/22741 | sst2_loss=0.010357 | qqp_loss=0.063750 | stsb_loss=0.009477
# Epoch 4 | Shared Step 19450/22741 | sst2_loss=0.010341 | qqp_loss=0.063783 | stsb_loss=0.009473
# Epoch 4 | Shared Step 19500/22741 | sst2_loss=0.010344 | qqp_loss=0.063766 | stsb_loss=0.009469
# Epoch 4 | Shared Step 19550/22741 | sst2_loss=0.010337 | qqp_loss=0.063788 | stsb_loss=0.009468
# Epoch 4 | Shared Step 19600/22741 | sst2_loss=0.010324 | qqp_loss=0.063785 | stsb_loss=0.009464
# Epoch 4 | Shared Step 19650/22741 | sst2_loss=0.010323 | qqp_loss=0.063777 | stsb_loss=0.009461
# Epoch 4 | Shared Step 19700/22741 | sst2_loss=0.010350 | qqp_loss=0.063734 | stsb_loss=0.009456
# Epoch 4 | Shared Step 19750/22741 | sst2_loss=0.010334 | qqp_loss=0.063729 | stsb_loss=0.009453
# Epoch 4 | Shared Step 19800/22741 | sst2_loss=0.010347 | qqp_loss=0.063744 | stsb_loss=0.009453
# Epoch 4 | Shared Step 19850/22741 | sst2_loss=0.010361 | qqp_loss=0.063744 | stsb_loss=0.009453
# Epoch 4 | Shared Step 19900/22741 | sst2_loss=0.010346 | qqp_loss=0.063738 | stsb_loss=0.009452
# Epoch 4 | Shared Step 19950/22741 | sst2_loss=0.010325 | qqp_loss=0.063697 | stsb_loss=0.009449
# Epoch 4 | Shared Step 20000/22741 | sst2_loss=0.010335 | qqp_loss=0.063702 | stsb_loss=0.009444
# Epoch 4 | Shared Step 20050/22741 | sst2_loss=0.010335 | qqp_loss=0.063648 | stsb_loss=0.009440
# Epoch 4 | Shared Step 20100/22741 | sst2_loss=0.010318 | qqp_loss=0.063607 | stsb_loss=0.009438
# Epoch 4 | Shared Step 20150/22741 | sst2_loss=0.010320 | qqp_loss=0.063596 | stsb_loss=0.009434
# Epoch 4 | Shared Step 20200/22741 | sst2_loss=0.010333 | qqp_loss=0.063619 | stsb_loss=0.009434
# Epoch 4 | Shared Step 20250/22741 | sst2_loss=0.010329 | qqp_loss=0.063634 | stsb_loss=0.009431
# Epoch 4 | Shared Step 20300/22741 | sst2_loss=0.010336 | qqp_loss=0.063641 | stsb_loss=0.009426
# Epoch 4 | Shared Step 20350/22741 | sst2_loss=0.010323 | qqp_loss=0.063643 | stsb_loss=0.009428
# Epoch 4 | Shared Step 20400/22741 | sst2_loss=0.010348 | qqp_loss=0.063589 | stsb_loss=0.009426
# Epoch 4 | Shared Step 20450/22741 | sst2_loss=0.010358 | qqp_loss=0.063598 | stsb_loss=0.009422
# Epoch 4 | Shared Step 20500/22741 | sst2_loss=0.010361 | qqp_loss=0.063631 | stsb_loss=0.009420
# Epoch 4 | Shared Step 20550/22741 | sst2_loss=0.010378 | qqp_loss=0.063641 | stsb_loss=0.009419
# Epoch 4 | Shared Step 20600/22741 | sst2_loss=0.010384 | qqp_loss=0.063630 | stsb_loss=0.009416
# Epoch 4 | Shared Step 20650/22741 | sst2_loss=0.010364 | qqp_loss=0.063707 | stsb_loss=0.009412
# Epoch 4 | Shared Step 20700/22741 | sst2_loss=0.010384 | qqp_loss=0.063716 | stsb_loss=0.009407
# Epoch 4 | Shared Step 20750/22741 | sst2_loss=0.010367 | qqp_loss=0.063713 | stsb_loss=0.009403
# Epoch 4 | Shared Step 20800/22741 | sst2_loss=0.010379 | qqp_loss=0.063688 | stsb_loss=0.009398
# Epoch 4 | Shared Step 20850/22741 | sst2_loss=0.010386 | qqp_loss=0.063679 | stsb_loss=0.009393
# Epoch 4 | Shared Step 20900/22741 | sst2_loss=0.010409 | qqp_loss=0.063750 | stsb_loss=0.009393
# Epoch 4 | Shared Step 20950/22741 | sst2_loss=0.010425 | qqp_loss=0.063736 | stsb_loss=0.009393
# Epoch 4 | Shared Step 21000/22741 | sst2_loss=0.010427 | qqp_loss=0.063720 | stsb_loss=0.009398
# Epoch 4 | Shared Step 21050/22741 | sst2_loss=0.010424 | qqp_loss=0.063692 | stsb_loss=0.009406
# Epoch 4 | Shared Step 21100/22741 | sst2_loss=0.010445 | qqp_loss=0.063685 | stsb_loss=0.009405
# Epoch 4 | Shared Step 21150/22741 | sst2_loss=0.010431 | qqp_loss=0.063667 | stsb_loss=0.009404
# Epoch 4 | Shared Step 21200/22741 | sst2_loss=0.010415 | qqp_loss=0.063723 | stsb_loss=0.009407
# Epoch 4 | Shared Step 21250/22741 | sst2_loss=0.010404 | qqp_loss=0.063700 | stsb_loss=0.009405
# Epoch 4 | Shared Step 21300/22741 | sst2_loss=0.010382 | qqp_loss=0.063668 | stsb_loss=0.009403
# Epoch 4 | Shared Step 21350/22741 | sst2_loss=0.010389 | qqp_loss=0.063654 | stsb_loss=0.009402
# Epoch 4 | Shared Step 21400/22741 | sst2_loss=0.010384 | qqp_loss=0.063609 | stsb_loss=0.009400
# Epoch 4 | Shared Step 21450/22741 | sst2_loss=0.010376 | qqp_loss=0.063662 | stsb_loss=0.009400
# Epoch 4 | Shared Step 21500/22741 | sst2_loss=0.010374 | qqp_loss=0.063675 | stsb_loss=0.009397
# Epoch 4 | Shared Step 21550/22741 | sst2_loss=0.010352 | qqp_loss=0.063705 | stsb_loss=0.009396
# Epoch 4 | Shared Step 21600/22741 | sst2_loss=0.010332 | qqp_loss=0.063681 | stsb_loss=0.009393
# Epoch 4 | Shared Step 21650/22741 | sst2_loss=0.010356 | qqp_loss=0.063689 | stsb_loss=0.009391
# Epoch 4 | Shared Step 21700/22741 | sst2_loss=0.010356 | qqp_loss=0.063633 | stsb_loss=0.009389
# Epoch 4 | Shared Step 21750/22741 | sst2_loss=0.010347 | qqp_loss=0.063577 | stsb_loss=0.009385
# Epoch 4 | Shared Step 21800/22741 | sst2_loss=0.010334 | qqp_loss=0.063565 | stsb_loss=0.009384
# Epoch 4 | Shared Step 21850/22741 | sst2_loss=0.010350 | qqp_loss=0.063623 | stsb_loss=0.009383
# Epoch 4 | Shared Step 21900/22741 | sst2_loss=0.010352 | qqp_loss=0.063633 | stsb_loss=0.009382
# Epoch 4 | Shared Step 21950/22741 | sst2_loss=0.010339 | qqp_loss=0.063602 | stsb_loss=0.009379
# Epoch 4 | Shared Step 22000/22741 | sst2_loss=0.010340 | qqp_loss=0.063568 | stsb_loss=0.009375
# Epoch 4 | Shared Step 22050/22741 | sst2_loss=0.010333 | qqp_loss=0.063588 | stsb_loss=0.009377
# Epoch 4 | Shared Step 22100/22741 | sst2_loss=0.010345 | qqp_loss=0.063574 | stsb_loss=0.009376
# Epoch 4 | Shared Step 22150/22741 | sst2_loss=0.010334 | qqp_loss=0.063547 | stsb_loss=0.009373
# Epoch 4 | Shared Step 22200/22741 | sst2_loss=0.010342 | qqp_loss=0.063528 | stsb_loss=0.009370
# Epoch 4 | Shared Step 22250/22741 | sst2_loss=0.010357 | qqp_loss=0.063501 | stsb_loss=0.009368
# Epoch 4 | Shared Step 22300/22741 | sst2_loss=0.010341 | qqp_loss=0.063454 | stsb_loss=0.009371
# Epoch 4 | Shared Step 22350/22741 | sst2_loss=0.010322 | qqp_loss=0.063467 | stsb_loss=0.009370
# Epoch 4 | Shared Step 22400/22741 | sst2_loss=0.010328 | qqp_loss=0.063480 | stsb_loss=0.009369
# Epoch 4 | Shared Step 22450/22741 | sst2_loss=0.010344 | qqp_loss=0.063421 | stsb_loss=0.009367
# Epoch 4 | Shared Step 22500/22741 | sst2_loss=0.010339 | qqp_loss=0.063441 | stsb_loss=0.009364
# Epoch 4 | Shared Step 22550/22741 | sst2_loss=0.010357 | qqp_loss=0.063475 | stsb_loss=0.009362
# Epoch 4 | Shared Step 22600/22741 | sst2_loss=0.010363 | qqp_loss=0.063534 | stsb_loss=0.009359
# Epoch 4 | Shared Step 22650/22741 | sst2_loss=0.010348 | qqp_loss=0.063530 | stsb_loss=0.009355
# Epoch 4 | Shared Step 22700/22741 | sst2_loss=0.010339 | qqp_loss=0.063499 | stsb_loss=0.009354
# Epoch 4 | Shared Step 22741/22741 | sst2_loss=0.010344 | qqp_loss=0.063471 | stsb_loss=0.009357
#
# Validation results:
# {
#   "epoch": 4,
#   "train_loss_overall": 0.02772378099162677,
#   "train_loss_sst2": 0.010343598797815871,
#   "train_loss_qqp": 0.06347094391807742,
#   "train_loss_stsb": 0.009356800258987009,
#   "sst2_eval_loss": 0.6663734613663771,
#   "sst2_accuracy": 0.8876146788990825,
#   "sst2_macro_f1": 0.8875857024841223,
#   "sst2_precision": 0.8875618225823425,
#   "sst2_recall": 0.8876189273385535,
#   "qqp_eval_loss": 0.3947407854318426,
#   "qqp_accuracy": 0.8908236458075687,
#   "qqp_macro_f1": 0.8832679275869338,
#   "qqp_precision": 0.8814289511331717,
#   "qqp_recall": 0.8852879711374995,
#   "stsb_eval_loss": 0.5684582493565185,
#   "stsb_pearson": 0.8683913262550497,
#   "stsb_spearman": 0.8657484179871724,
#   "overall_score": 0.8818360656092542,
#   "time_per_epoch": 12362.59551024437,
#   "trainable_params": 109486085,
#   "total_params": 109486085,
#   "model_name": "bert-base-uncased",
#   "dataset_name": "sst2+qqp+stsb",
#   "setting": "centralized_mtl_full",
#   "best_metric_so_far": 0.8919703877832067,
#   "patience_counter": 3,
#   "is_new_best": false
# }
#
# Early stopping triggered.
# Overall validation score did not improve for 3 consecutive epochs.
#
# Training completed.
# History CSV : /content/drive/MyDrive/mtl_runs/bert_base_mtl_sst2_qqp_stsb/history.csv
# History JSON: /content/drive/MyDrive/mtl_runs/bert_base_mtl_sst2_qqp_stsb/history.json
# Best model  : /content/drive/MyDrive/mtl_runs/bert_base_mtl_sst2_qqp_stsb/best_model
# Final model : /content/drive/MyDrive/mtl_runs/bert_base_mtl_sst2_qqp_stsb/final_model
# Checkpoints : /content/drive/MyDrive/mtl_runs/bert_base_mtl_sst2_qqp_stsb/checkpoints
