# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip -q install -U transformers datasets evaluate accelerate scikit-learn scipy pandas peft
# !mkdir -p /content/drive/MyDrive/mtl_runs
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.1/62.1 kB 2.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.5/79.5 kB 4.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 52.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 527.0/527.0 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 4.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 54.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.2/35.2 MB 16.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 65.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 47.6/47.6 MB 17.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 3.0.2 which is incompatible.
# db-dtypes 1.5.1 requires pandas<3.0.0,>=1.5.3, but you have pandas 3.0.2 which is incompatible.
# bqplot 0.12.45 requires pandas<3.0.0,>=1.0.0, but you have pandas 3.0.2 which is incompatible.
# gradio 5.50.0 requires pandas<3.0,>=1.0, but you have pandas 3.0.2 which is incompatible.

# %%
# %%writefile /content/drive/MyDrive/mtl_runs/minilm_mtl_lora.py
import os
import json
import time
import shutil
import random
from pathlib import Path
from itertools import cycle

import numpy as np
import pandas as pd
import torch
import torch.nn as nn
from torch.utils.data import DataLoader

from datasets import load_dataset
from transformers import (
    AutoTokenizer,
    AutoModel,
    DataCollatorWithPadding,
    get_linear_schedule_with_warmup,
)
from peft import LoraConfig, get_peft_model, TaskType
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
from scipy.stats import pearsonr, spearmanr


# =========================================================
# Config
# =========================================================
MODEL_NAME = "microsoft/MiniLM-L12-H384-uncased"
SETTING = "centralized_mtl_lora"
TASKS = ["sst2", "qqp", "stsb"]

BATCH_SIZE = 16
LR = 2e-5
WEIGHT_DECAY = 0.01
WARMUP_RATIO = 0.1
MAX_LENGTH = 256
NUM_WORKERS = 2
EARLY_STOPPING_PATIENCE = 3
KEEP_LAST_K_CHECKPOINTS = 2
SEED = 42

LORA_R = 8
LORA_ALPHA = 16
LORA_DROPOUT = 0.1
LORA_TARGET_MODULES = ["query", "key", "value"]

BASE_DIR = Path("/content/drive/MyDrive/mtl_runs")
RUN_NAME = "minilm_mtl_lora_sst2_qqp_stsb"
RUN_DIR = BASE_DIR / RUN_NAME

CHECKPOINT_DIR = RUN_DIR / "checkpoints"
BEST_MODEL_DIR = RUN_DIR / "best_model"
FINAL_MODEL_DIR = RUN_DIR / "final_model"
LOG_CSV_PATH = RUN_DIR / "history.csv"
LOG_JSON_PATH = RUN_DIR / "history.json"
STATE_PATH = RUN_DIR / "training_state.json"


def set_seed(seed=42):
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)


def ensure_dirs():
    RUN_DIR.mkdir(parents=True, exist_ok=True)
    CHECKPOINT_DIR.mkdir(parents=True, exist_ok=True)
    BEST_MODEL_DIR.mkdir(parents=True, exist_ok=True)
    FINAL_MODEL_DIR.mkdir(parents=True, exist_ok=True)


def save_json(obj, path):
    with open(path, "w", encoding="utf-8") as f:
        json.dump(obj, f, indent=2, ensure_ascii=False)


def save_history(history):
    pd.DataFrame(history).to_csv(LOG_CSV_PATH, index=False)
    save_json(history, LOG_JSON_PATH)


def cleanup_old_checkpoints(keep_k=2):
    ckpts = [p for p in CHECKPOINT_DIR.iterdir() if p.is_dir() and p.name.startswith("epoch_")]
    ckpts = sorted(ckpts, key=lambda x: int(x.name.split("_")[-1]))
    while len(ckpts) > keep_k:
        oldest = ckpts.pop(0)
        shutil.rmtree(oldest, ignore_errors=True)


def get_latest_checkpoint():
    if not CHECKPOINT_DIR.exists():
        return None
    ckpts = [p for p in CHECKPOINT_DIR.iterdir() if p.is_dir() and p.name.startswith("epoch_")]
    if not ckpts:
        return None
    ckpts = sorted(ckpts, key=lambda x: int(x.name.split("_")[-1]))
    return ckpts[-1]


def count_parameters(model):
    total_params = sum(p.numel() for p in model.parameters())
    trainable_params = sum(p.numel() for p in model.parameters() if p.requires_grad)
    return trainable_params, total_params


def safe_float(x):
    if x is None:
        return None
    try:
        if isinstance(x, (float, int, np.floating, np.integer)):
            if np.isnan(x) or np.isinf(x):
                return None
        return float(x)
    except Exception:
        return None


class MiniLMMTL(nn.Module):
    def __init__(self, model_name, use_lora=True):
        super().__init__()
        self.encoder = AutoModel.from_pretrained(model_name)

        if use_lora:
            lora_config = LoraConfig(
                task_type=TaskType.FEATURE_EXTRACTION,
                r=LORA_R,
                lora_alpha=LORA_ALPHA,
                lora_dropout=LORA_DROPOUT,
                target_modules=LORA_TARGET_MODULES,
                bias="none",
            )
            self.encoder = get_peft_model(self.encoder, lora_config)

        hidden_size = self.encoder.config.hidden_size
        self.dropout = nn.Dropout(0.1)
        self.sst2_head = nn.Linear(hidden_size, 2)
        self.qqp_head = nn.Linear(hidden_size, 2)
        self.stsb_head = nn.Linear(hidden_size, 1)

    def encode(self, input_ids, attention_mask, token_type_ids=None):
        outputs = self.encoder(
            input_ids=input_ids,
            attention_mask=attention_mask,
            token_type_ids=token_type_ids,
        )
        pooled = outputs.last_hidden_state[:, 0]
        return self.dropout(pooled)

    def forward(self, task_name, input_ids, attention_mask, token_type_ids=None, labels=None):
        features = self.encode(input_ids, attention_mask, token_type_ids)

        if task_name == "sst2":
            logits = self.sst2_head(features)
            loss = None
            if labels is not None:
                loss = nn.CrossEntropyLoss()(logits, labels.long())
            return {"loss": loss, "logits": logits}

        elif task_name == "qqp":
            logits = self.qqp_head(features)
            loss = None
            if labels is not None:
                loss = nn.CrossEntropyLoss()(logits, labels.long())
            return {"loss": loss, "logits": logits}

        elif task_name == "stsb":
            logits = self.stsb_head(features).squeeze(-1)
            loss = None
            if labels is not None:
                loss = nn.MSELoss()(logits, labels.float())
            return {"loss": loss, "logits": logits}

        else:
            raise ValueError(f"Unsupported task: {task_name}")


def save_model_bundle(model, tokenizer, save_dir, extra_info=None):
    save_dir = Path(save_dir)
    if save_dir.exists():
        shutil.rmtree(save_dir)
    save_dir.mkdir(parents=True, exist_ok=True)

    torch.save(model.state_dict(), save_dir / "pytorch_model.bin")
    tokenizer.save_pretrained(save_dir)

    payload = {
        "model_name": MODEL_NAME,
        "setting": SETTING,
        "tasks": TASKS,
        "lora": {
            "enabled": True,
            "r": LORA_R,
            "alpha": LORA_ALPHA,
            "dropout": LORA_DROPOUT,
            "target_modules": LORA_TARGET_MODULES,
        },
    }
    if extra_info is not None:
        payload["extra_info"] = extra_info
    save_json(payload, save_dir / "mtl_config.json")


def get_task_specs():
    return {
        "sst2": {
            "task_type": "classification",
            "dataset_loader": ("glue", "sst2"),
            "text_cols": ("sentence", None),
            "label_col": "label",
        },
        "qqp": {
            "task_type": "classification",
            "dataset_loader": ("glue", "qqp"),
            "text_cols": ("question1", "question2"),
            "label_col": "label",
        },
        "stsb": {
            "task_type": "regression",
            "dataset_loader": ("glue", "stsb"),
            "text_cols": ("sentence1", "sentence2"),
            "label_col": "label",
        },
    }


def preprocess_dataset(task_name, tokenizer, max_length):
    specs = get_task_specs()[task_name]
    dataset_name, subset_name = specs["dataset_loader"]
    raw = load_dataset(dataset_name, subset_name)

    text_a, text_b = specs["text_cols"]
    label_col = specs["label_col"]
    task_type = specs["task_type"]

    def preprocess_fn(examples):
        if text_b is None:
            enc = tokenizer(examples[text_a], truncation=True, max_length=max_length)
        else:
            enc = tokenizer(examples[text_a], examples[text_b], truncation=True, max_length=max_length)

        if task_type == "classification":
            enc["labels"] = examples[label_col]
        else:
            enc["labels"] = [float(x) for x in examples[label_col]]
        return enc

    encoded = raw.map(preprocess_fn, batched=True, remove_columns=raw["train"].column_names)

    if "validation" in encoded:
        val_split = "validation"
    elif "validation_matched" in encoded:
        val_split = "validation_matched"
    else:
        raise ValueError(f"No validation split for task {task_name}")

    return encoded["train"], encoded[val_split]


@torch.no_grad()
def evaluate_task(model, dataloader, device, task_name):
    model.eval()

    total_loss = 0.0
    all_preds = []
    all_labels = []

    for batch in dataloader:
        batch = {k: v.to(device) for k, v in batch.items()}

        outputs = model(
            task_name=task_name,
            input_ids=batch["input_ids"],
            attention_mask=batch["attention_mask"],
            token_type_ids=batch.get("token_type_ids", None),
            labels=batch["labels"],
        )
        loss = outputs["loss"]
        logits = outputs["logits"]

        total_loss += loss.item()

        if task_name in ["sst2", "qqp"]:
            preds = torch.argmax(logits, dim=-1)
            all_preds.extend(preds.detach().cpu().numpy().tolist())
            all_labels.extend(batch["labels"].detach().cpu().numpy().tolist())
        else:
            all_preds.extend(logits.detach().cpu().numpy().tolist())
            all_labels.extend(batch["labels"].detach().cpu().numpy().tolist())

    eval_loss = total_loss / max(len(dataloader), 1)

    if task_name in ["sst2", "qqp"]:
        return {
            "eval_loss": eval_loss,
            "accuracy": accuracy_score(all_labels, all_preds),
            "macro_f1": f1_score(all_labels, all_preds, average="macro", zero_division=0),
            "precision": precision_score(all_labels, all_preds, average="macro", zero_division=0),
            "recall": recall_score(all_labels, all_preds, average="macro", zero_division=0),
            "pearson": None,
            "spearman": None,
        }

    pearson = 0.0
    spearman = 0.0
    if len(set(all_labels)) > 1 and len(set(all_preds)) > 1:
        pearson = float(pearsonr(all_labels, all_preds)[0])
        spearman = float(spearmanr(all_labels, all_preds)[0])

    return {
        "eval_loss": eval_loss,
        "accuracy": None,
        "macro_f1": None,
        "precision": None,
        "recall": None,
        "pearson": pearson,
        "spearman": spearman,
    }


def compute_overall_metric(metrics_by_task):
    sst2_score = metrics_by_task["sst2"]["accuracy"]
    qqp_score = metrics_by_task["qqp"]["accuracy"]
    stsb_score = (metrics_by_task["stsb"]["pearson"] + metrics_by_task["stsb"]["spearman"]) / 2.0
    return float((sst2_score + qqp_score + stsb_score) / 3.0)


def save_checkpoint(epoch, model, tokenizer, optimizer, scheduler, history, best_metric_so_far, patience_counter):
    ckpt_dir = CHECKPOINT_DIR / f"epoch_{epoch}"
    ckpt_dir.mkdir(parents=True, exist_ok=True)

    torch.save(model.state_dict(), ckpt_dir / "model_state.pt")
    torch.save(
        {
            "epoch": epoch,
            "optimizer_state_dict": optimizer.state_dict(),
            "scheduler_state_dict": scheduler.state_dict(),
            "best_metric_so_far": best_metric_so_far,
            "patience_counter": patience_counter,
            "history": history,
        },
        ckpt_dir / "trainer_state.pt",
    )
    tokenizer.save_pretrained(ckpt_dir)

    save_json(
        {
            "epoch": epoch,
            "best_metric_so_far": best_metric_so_far,
            "patience_counter": patience_counter,
            "history_length": len(history),
        },
        STATE_PATH,
    )
    cleanup_old_checkpoints(KEEP_LAST_K_CHECKPOINTS)


def main():
    set_seed(SEED)
    ensure_dirs()

    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print("=" * 100)
    print(f"MODEL_NAME: {MODEL_NAME}")
    print(f"SETTING   : {SETTING}")
    print(f"TASKS     : {TASKS}")
    print(f"DEVICE    : {device}")
    print(f"RUN_DIR   : {RUN_DIR}")
    print("Training will continue until early stopping patience=3 is met.")
    print("No fixed max_epochs is used.")
    print("=" * 100)

    tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME, use_fast=True)

    train_datasets = {}
    val_datasets = {}
    train_loaders = {}
    val_loaders = {}

    for task_name in TASKS:
        train_ds, val_ds = preprocess_dataset(task_name, tokenizer, MAX_LENGTH)
        train_datasets[task_name] = train_ds
        val_datasets[task_name] = val_ds

    collator = DataCollatorWithPadding(tokenizer=tokenizer)

    for task_name in TASKS:
        train_loaders[task_name] = DataLoader(
            train_datasets[task_name],
            batch_size=BATCH_SIZE,
            shuffle=True,
            collate_fn=collator,
            num_workers=NUM_WORKERS,
            pin_memory=True,
        )
        val_loaders[task_name] = DataLoader(
            val_datasets[task_name],
            batch_size=BATCH_SIZE,
            shuffle=False,
            collate_fn=collator,
            num_workers=NUM_WORKERS,
            pin_memory=True,
        )

    model = MiniLMMTL(MODEL_NAME, use_lora=True).to(device)

    trainable_params, total_params = count_parameters(model)
    print(f"Trainable params: {trainable_params:,}")
    print(f"Total params    : {total_params:,}")

    for task_name in TASKS:
        print(
            f"{task_name} -> train: {len(train_datasets[task_name])}, "
            f"validation: {len(val_datasets[task_name])}, "
            f"train_batches: {len(train_loaders[task_name])}, "
            f"val_batches: {len(val_loaders[task_name])}"
        )

    optimizer = torch.optim.AdamW(model.parameters(), lr=LR, weight_decay=WEIGHT_DECAY)

    max_train_batches = max(len(train_loaders[t]) for t in TASKS)
    steps_per_epoch = max_train_batches * len(TASKS)
    warmup_steps = max(1, int(steps_per_epoch * WARMUP_RATIO))
    scheduler = get_linear_schedule_with_warmup(
        optimizer=optimizer,
        num_warmup_steps=warmup_steps,
        num_training_steps=10**12,
    )

    history = []
    start_epoch = 1
    best_metric_so_far = -float("inf")
    patience_counter = 0

    latest_ckpt = get_latest_checkpoint()
    if latest_ckpt is not None:
        print(f"Resuming from checkpoint: {latest_ckpt}")
        model.load_state_dict(torch.load(latest_ckpt / "model_state.pt", map_location=device))

        trainer_state = torch.load(latest_ckpt / "trainer_state.pt", map_location=device)
        optimizer.load_state_dict(trainer_state["optimizer_state_dict"])
        scheduler.load_state_dict(trainer_state["scheduler_state_dict"])
        history = trainer_state.get("history", [])
        best_metric_so_far = trainer_state.get("best_metric_so_far", -float("inf"))
        patience_counter = trainer_state.get("patience_counter", 0)
        start_epoch = trainer_state.get("epoch", 0) + 1

    epoch = start_epoch
    while True:
        model.train()
        epoch_start_time = time.time()

        task_iterators = {task_name: cycle(train_loaders[task_name]) for task_name in TASKS}
        running_task_loss = {task_name: 0.0 for task_name in TASKS}
        running_task_steps = {task_name: 0 for task_name in TASKS}

        print("\n" + "=" * 100)
        print(f"Epoch {epoch} started")
        print("=" * 100)

        for shared_step in range(1, max_train_batches + 1):
            for task_name in TASKS:
                batch = next(task_iterators[task_name])
                batch = {k: v.to(device) for k, v in batch.items()}

                optimizer.zero_grad()
                outputs = model(
                    task_name=task_name,
                    input_ids=batch["input_ids"],
                    attention_mask=batch["attention_mask"],
                    token_type_ids=batch.get("token_type_ids", None),
                    labels=batch["labels"],
                )
                loss = outputs["loss"]
                loss.backward()
                optimizer.step()
                scheduler.step()

                running_task_loss[task_name] += loss.item()
                running_task_steps[task_name] += 1

            if shared_step % 50 == 0 or shared_step == max_train_batches:
                msg = [f"Epoch {epoch} | Shared Step {shared_step}/{max_train_batches}"]
                for task_name in TASKS:
                    avg_loss = running_task_loss[task_name] / max(running_task_steps[task_name], 1)
                    msg.append(f"{task_name}_loss={avg_loss:.6f}")
                print(" | ".join(msg))

        train_loss_sst2 = running_task_loss["sst2"] / max(running_task_steps["sst2"], 1)
        train_loss_qqp = running_task_loss["qqp"] / max(running_task_steps["qqp"], 1)
        train_loss_stsb = running_task_loss["stsb"] / max(running_task_steps["stsb"], 1)
        train_loss_overall = float((train_loss_sst2 + train_loss_qqp + train_loss_stsb) / 3.0)

        metrics_by_task = {}
        for task_name in TASKS:
            metrics_by_task[task_name] = evaluate_task(model, val_loaders[task_name], device, task_name)

        overall_metric = compute_overall_metric(metrics_by_task)
        is_new_best = overall_metric > best_metric_so_far

        if is_new_best:
            best_metric_so_far = overall_metric
            patience_counter = 0
            save_model_bundle(
                model,
                tokenizer,
                BEST_MODEL_DIR,
                extra_info={"epoch": epoch, "best_metric_so_far": best_metric_so_far},
            )
        else:
            patience_counter += 1

        row = {
            "epoch": epoch,
            "train_loss_overall": safe_float(train_loss_overall),
            "train_loss_sst2": safe_float(train_loss_sst2),
            "train_loss_qqp": safe_float(train_loss_qqp),
            "train_loss_stsb": safe_float(train_loss_stsb),

            "sst2_eval_loss": safe_float(metrics_by_task["sst2"]["eval_loss"]),
            "sst2_accuracy": safe_float(metrics_by_task["sst2"]["accuracy"]),
            "sst2_macro_f1": safe_float(metrics_by_task["sst2"]["macro_f1"]),
            "sst2_precision": safe_float(metrics_by_task["sst2"]["precision"]),
            "sst2_recall": safe_float(metrics_by_task["sst2"]["recall"]),

            "qqp_eval_loss": safe_float(metrics_by_task["qqp"]["eval_loss"]),
            "qqp_accuracy": safe_float(metrics_by_task["qqp"]["accuracy"]),
            "qqp_macro_f1": safe_float(metrics_by_task["qqp"]["macro_f1"]),
            "qqp_precision": safe_float(metrics_by_task["qqp"]["precision"]),
            "qqp_recall": safe_float(metrics_by_task["qqp"]["recall"]),

            "stsb_eval_loss": safe_float(metrics_by_task["stsb"]["eval_loss"]),
            "stsb_pearson": safe_float(metrics_by_task["stsb"]["pearson"]),
            "stsb_spearman": safe_float(metrics_by_task["stsb"]["spearman"]),

            "overall_score": safe_float(overall_metric),
            "time_per_epoch": safe_float(time.time() - epoch_start_time),
            "trainable_params": int(trainable_params),
            "total_params": int(total_params),
            "model_name": MODEL_NAME,
            "dataset_name": "sst2+qqp+stsb",
            "setting": SETTING,
            "best_metric_so_far": safe_float(best_metric_so_far),
            "patience_counter": int(patience_counter),
            "is_new_best": bool(is_new_best),
            "lora_r": LORA_R,
            "lora_alpha": LORA_ALPHA,
            "lora_dropout": LORA_DROPOUT,
        }

        history.append(row)
        save_history(history)

        save_checkpoint(
            epoch=epoch,
            model=model,
            tokenizer=tokenizer,
            optimizer=optimizer,
            scheduler=scheduler,
            history=history,
            best_metric_so_far=best_metric_so_far,
            patience_counter=patience_counter,
        )

        print("\nValidation results:")
        print(json.dumps(row, indent=2, ensure_ascii=False, default=str))

        if patience_counter >= EARLY_STOPPING_PATIENCE:
            print("\nEarly stopping triggered.")
            print(f"Overall validation score did not improve for {EARLY_STOPPING_PATIENCE} consecutive epochs.")
            break

        epoch += 1

    save_model_bundle(
        model,
        tokenizer,
        FINAL_MODEL_DIR,
        extra_info={"final_epoch": epoch, "best_metric_so_far": best_metric_so_far},
    )
    save_history(history)

    print("\nTraining completed.")
    print(f"History CSV : {LOG_CSV_PATH}")
    print(f"History JSON: {LOG_JSON_PATH}")
    print(f"Best model  : {BEST_MODEL_DIR}")
    print(f"Final model : {FINAL_MODEL_DIR}")
    print(f"Checkpoints : {CHECKPOINT_DIR}")


if __name__ == "__main__":
    main()
# Out:
# Overwriting /content/drive/MyDrive/mtl_runs/minilm_mtl_lora.py

# %%
# !python /content/drive/MyDrive/mtl_runs/minilm_mtl_lora.py
# Out:
# ====================================================================================================
# MODEL_NAME: microsoft/MiniLM-L12-H384-uncased
# SETTING   : centralized_mtl_lora
# TASKS     : ['sst2', 'qqp', 'stsb']
# DEVICE    : cuda
# RUN_DIR   : /content/drive/MyDrive/mtl_runs/minilm_mtl_lora_sst2_qqp_stsb
# Training will continue until early stopping patience=3 is met.
# No fixed max_epochs is used.
# ====================================================================================================
# config.json: 100% 385/385 [00:00<00:00, 1.79MB/s]
# tokenizer_config.json: 100% 2.00/2.00 [00:00<00:00, 12.8kB/s]
# vocab.txt: 232kB [00:00, 95.4MB/s]
# special_tokens_map.json: 100% 112/112 [00:00<00:00, 236kB/s]
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# README.md: 35.3kB [00:00, 90.3MB/s]
# sst2/train-00000-of-00001.parquet: 100% 3.11M/3.11M [00:02<00:00, 1.48MB/s]
# sst2/validation-00000-of-00001.parquet: 100% 72.8k/72.8k [00:00<00:00, 178kB/s]
# sst2/test-00000-of-00001.parquet: 100% 148k/148k [00:00<00:00, 361kB/s]
# Generating train split: 100% 67349/67349 [00:00<00:00, 1034505.90 examples/s]
# Generating validation split: 100% 872/872 [00:00<00:00, 325047.38 examples/s]
# Generating test split: 100% 1821/1821 [00:00<00:00, 586532.61 examples/s]
# Map: 100% 67349/67349 [00:03<00:00, 18782.30 examples/s]
# Map: 100% 872/872 [00:00<00:00, 13297.82 examples/s]
# Map: 100% 1821/1821 [00:00<00:00, 13624.99 examples/s]
# qqp/train-00000-of-00001.parquet: 100% 33.6M/33.6M [00:01<00:00, 33.2MB/s]
# qqp/validation-00000-of-00001.parquet: 100% 3.73M/3.73M [00:00<00:00, 6.11MB/s]
# qqp/test-00000-of-00001.parquet: 100% 36.7M/36.7M [00:00<00:00, 60.1MB/s]
# Generating train split: 100% 363846/363846 [00:00<00:00, 1087037.26 examples/s]
# Generating validation split: 100% 40430/40430 [00:00<00:00, 589945.52 examples/s]
# Generating test split: 100% 390965/390965 [00:00<00:00, 1003092.21 examples/s]
# Map: 100% 363846/363846 [00:42<00:00, 8593.35 examples/s]
# Map: 100% 40430/40430 [00:04<00:00, 9806.94 examples/s]
# Map: 100% 390965/390965 [00:46<00:00, 8473.96 examples/s]
# stsb/train-00000-of-00001.parquet: 100% 502k/502k [00:01<00:00, 415kB/s]
# stsb/validation-00000-of-00001.parquet: 100% 151k/151k [00:00<00:00, 367kB/s]
# stsb/test-00000-of-00001.parquet: 100% 114k/114k [00:00<00:00, 279kB/s]
# Generating train split: 100% 5749/5749 [00:00<00:00, 637085.62 examples/s]
# Generating validation split: 100% 1500/1500 [00:00<00:00, 329051.05 examples/s]
# Generating test split: 100% 1379/1379 [00:00<00:00, 342610.19 examples/s]
# Map: 100% 5749/5749 [00:00<00:00, 11701.80 examples/s]
# Map: 100% 1500/1500 [00:00<00:00, 10678.65 examples/s]
# Map: 100% 1379/1379 [00:00<00:00, 12025.23 examples/s]
# pytorch_model.bin: 100% 133M/133M [00:01<00:00, 82.9MB/s]
# Loading weights: 100% 199/199 [00:00<00:00, 1599.57it/s, Materializing param=pooler.dense.weight]
# model.safetensors:   0% 0.00/133M [00:00<?, ?B/s]Trainable params: 223,109
# Total params    : 33,583,109
# sst2 -> train: 67349, validation: 872, train_batches: 4210, val_batches: 55
# qqp -> train: 363846, validation: 40430, train_batches: 22741, val_batches: 2527
# stsb -> train: 5749, validation: 1500, train_batches: 360, val_batches: 94
# model.safetensors:   6% 8.38M/133M [00:01<00:02, 42.3MB/s]Resuming from checkpoint: /content/drive/MyDrive/mtl_runs/minilm_mtl_lora_sst2_qqp_stsb/checkpoints/epoch_14
# model.safetensors: 100% 133M/133M [00:01<00:00, 81.7MB/s]
#
# ====================================================================================================
# Epoch 15 started
# ====================================================================================================
# Epoch 15 | Shared Step 50/22741 | sst2_loss=0.155576 | qqp_loss=0.384163 | stsb_loss=0.105759
# Epoch 15 | Shared Step 100/22741 | sst2_loss=0.146770 | qqp_loss=0.383461 | stsb_loss=0.099719
# Epoch 15 | Shared Step 150/22741 | sst2_loss=0.154084 | qqp_loss=0.379551 | stsb_loss=0.106050
# Epoch 15 | Shared Step 200/22741 | sst2_loss=0.153605 | qqp_loss=0.385897 | stsb_loss=0.107224
# Epoch 15 | Shared Step 250/22741 | sst2_loss=0.153488 | qqp_loss=0.378159 | stsb_loss=0.108732
# Epoch 15 | Shared Step 300/22741 | sst2_loss=0.150087 | qqp_loss=0.376987 | stsb_loss=0.107907
# Epoch 15 | Shared Step 350/22741 | sst2_loss=0.143414 | qqp_loss=0.380564 | stsb_loss=0.108750
# Epoch 15 | Shared Step 400/22741 | sst2_loss=0.146886 | qqp_loss=0.381493 | stsb_loss=0.108383
# Epoch 15 | Shared Step 450/22741 | sst2_loss=0.148313 | qqp_loss=0.381432 | stsb_loss=0.108235
# Epoch 15 | Shared Step 500/22741 | sst2_loss=0.147027 | qqp_loss=0.379972 | stsb_loss=0.107884
# Epoch 15 | Shared Step 550/22741 | sst2_loss=0.148657 | qqp_loss=0.382566 | stsb_loss=0.108873
# Epoch 15 | Shared Step 600/22741 | sst2_loss=0.146883 | qqp_loss=0.382997 | stsb_loss=0.109291
# Epoch 15 | Shared Step 650/22741 | sst2_loss=0.146002 | qqp_loss=0.380419 | stsb_loss=0.108812
# Epoch 15 | Shared Step 700/22741 | sst2_loss=0.147473 | qqp_loss=0.383446 | stsb_loss=0.109782
# Epoch 15 | Shared Step 750/22741 | sst2_loss=0.147270 | qqp_loss=0.384568 | stsb_loss=0.110154
# Epoch 15 | Shared Step 800/22741 | sst2_loss=0.147622 | qqp_loss=0.383548 | stsb_loss=0.110763
# Epoch 15 | Shared Step 850/22741 | sst2_loss=0.148217 | qqp_loss=0.383195 | stsb_loss=0.110479
# Epoch 15 | Shared Step 900/22741 | sst2_loss=0.147658 | qqp_loss=0.381433 | stsb_loss=0.110876
# Epoch 15 | Shared Step 950/22741 | sst2_loss=0.148097 | qqp_loss=0.381941 | stsb_loss=0.110843
# Epoch 15 | Shared Step 1000/22741 | sst2_loss=0.148193 | qqp_loss=0.380045 | stsb_loss=0.110318
# Epoch 15 | Shared Step 1050/22741 | sst2_loss=0.148562 | qqp_loss=0.378114 | stsb_loss=0.109646
# Epoch 15 | Shared Step 1100/22741 | sst2_loss=0.149153 | qqp_loss=0.378372 | stsb_loss=0.109321
# Epoch 15 | Shared Step 1150/22741 | sst2_loss=0.148735 | qqp_loss=0.378997 | stsb_loss=0.109407
# Epoch 15 | Shared Step 1200/22741 | sst2_loss=0.148465 | qqp_loss=0.378831 | stsb_loss=0.109152
# Epoch 15 | Shared Step 1250/22741 | sst2_loss=0.148797 | qqp_loss=0.377962 | stsb_loss=0.109280
# Epoch 15 | Shared Step 1300/22741 | sst2_loss=0.149493 | qqp_loss=0.378666 | stsb_loss=0.109514
# Epoch 15 | Shared Step 1350/22741 | sst2_loss=0.150380 | qqp_loss=0.377955 | stsb_loss=0.109900
# Epoch 15 | Shared Step 1400/22741 | sst2_loss=0.150145 | qqp_loss=0.377452 | stsb_loss=0.109812
# Epoch 15 | Shared Step 1450/22741 | sst2_loss=0.150395 | qqp_loss=0.377814 | stsb_loss=0.110006
# Epoch 15 | Shared Step 1500/22741 | sst2_loss=0.150039 | qqp_loss=0.377196 | stsb_loss=0.110209
# Epoch 15 | Shared Step 1550/22741 | sst2_loss=0.150679 | qqp_loss=0.377371 | stsb_loss=0.110022
# Epoch 15 | Shared Step 1600/22741 | sst2_loss=0.150596 | qqp_loss=0.377876 | stsb_loss=0.110489
# Epoch 15 | Shared Step 1650/22741 | sst2_loss=0.149835 | qqp_loss=0.378907 | stsb_loss=0.110658
# Epoch 15 | Shared Step 1700/22741 | sst2_loss=0.150504 | qqp_loss=0.378793 | stsb_loss=0.110563
# Epoch 15 | Shared Step 1750/22741 | sst2_loss=0.150657 | qqp_loss=0.379333 | stsb_loss=0.110545
# Epoch 15 | Shared Step 1800/22741 | sst2_loss=0.150822 | qqp_loss=0.378511 | stsb_loss=0.110465
# Epoch 15 | Shared Step 1850/22741 | sst2_loss=0.150762 | qqp_loss=0.378267 | stsb_loss=0.110545
# Epoch 15 | Shared Step 1900/22741 | sst2_loss=0.150572 | qqp_loss=0.378753 | stsb_loss=0.110352
# Epoch 15 | Shared Step 1950/22741 | sst2_loss=0.151268 | qqp_loss=0.379729 | stsb_loss=0.110670
# Epoch 15 | Shared Step 2000/22741 | sst2_loss=0.151572 | qqp_loss=0.379743 | stsb_loss=0.110764
# Epoch 15 | Shared Step 2050/22741 | sst2_loss=0.151655 | qqp_loss=0.379476 | stsb_loss=0.110640
# Epoch 15 | Shared Step 2100/22741 | sst2_loss=0.151580 | qqp_loss=0.380181 | stsb_loss=0.110371
# Epoch 15 | Shared Step 2150/22741 | sst2_loss=0.152577 | qqp_loss=0.381161 | stsb_loss=0.110215
# Epoch 15 | Shared Step 2200/22741 | sst2_loss=0.153359 | qqp_loss=0.381452 | stsb_loss=0.110111
# Epoch 15 | Shared Step 2250/22741 | sst2_loss=0.154148 | qqp_loss=0.381711 | stsb_loss=0.110170
# Epoch 15 | Shared Step 2300/22741 | sst2_loss=0.154763 | qqp_loss=0.381623 | stsb_loss=0.109995
# Epoch 15 | Shared Step 2350/22741 | sst2_loss=0.154762 | qqp_loss=0.381306 | stsb_loss=0.109972
# Epoch 15 | Shared Step 2400/22741 | sst2_loss=0.154577 | qqp_loss=0.381619 | stsb_loss=0.110075
# Epoch 15 | Shared Step 2450/22741 | sst2_loss=0.154501 | qqp_loss=0.382166 | stsb_loss=0.110179
# Epoch 15 | Shared Step 2500/22741 | sst2_loss=0.154789 | qqp_loss=0.382329 | stsb_loss=0.110225
# Epoch 15 | Shared Step 2550/22741 | sst2_loss=0.154551 | qqp_loss=0.382298 | stsb_loss=0.110065
# Epoch 15 | Shared Step 2600/22741 | sst2_loss=0.154274 | qqp_loss=0.382458 | stsb_loss=0.109952
# Epoch 15 | Shared Step 2650/22741 | sst2_loss=0.154356 | qqp_loss=0.382548 | stsb_loss=0.109838
# Epoch 15 | Shared Step 2700/22741 | sst2_loss=0.154617 | qqp_loss=0.382218 | stsb_loss=0.110110
# Epoch 15 | Shared Step 2750/22741 | sst2_loss=0.154596 | qqp_loss=0.382416 | stsb_loss=0.110350
# Epoch 15 | Shared Step 2800/22741 | sst2_loss=0.154952 | qqp_loss=0.382243 | stsb_loss=0.110460
# Epoch 15 | Shared Step 2850/22741 | sst2_loss=0.154769 | qqp_loss=0.381620 | stsb_loss=0.110624
# Epoch 15 | Shared Step 2900/22741 | sst2_loss=0.155014 | qqp_loss=0.381972 | stsb_loss=0.110677
# Epoch 15 | Shared Step 2950/22741 | sst2_loss=0.155292 | qqp_loss=0.381865 | stsb_loss=0.110609
# Epoch 15 | Shared Step 3000/22741 | sst2_loss=0.155615 | qqp_loss=0.381928 | stsb_loss=0.110430
# Epoch 15 | Shared Step 3050/22741 | sst2_loss=0.155560 | qqp_loss=0.381630 | stsb_loss=0.110452
# Epoch 15 | Shared Step 3100/22741 | sst2_loss=0.155830 | qqp_loss=0.381934 | stsb_loss=0.110428
# Epoch 15 | Shared Step 3150/22741 | sst2_loss=0.155617 | qqp_loss=0.381892 | stsb_loss=0.110501
# Epoch 15 | Shared Step 3200/22741 | sst2_loss=0.155535 | qqp_loss=0.381836 | stsb_loss=0.110595
# Epoch 15 | Shared Step 3250/22741 | sst2_loss=0.155871 | qqp_loss=0.381943 | stsb_loss=0.110529
# Epoch 15 | Shared Step 3300/22741 | sst2_loss=0.155749 | qqp_loss=0.382032 | stsb_loss=0.110586
# Epoch 15 | Shared Step 3350/22741 | sst2_loss=0.155674 | qqp_loss=0.381863 | stsb_loss=0.110528
# Epoch 15 | Shared Step 3400/22741 | sst2_loss=0.156066 | qqp_loss=0.381813 | stsb_loss=0.110535
# Epoch 15 | Shared Step 3450/22741 | sst2_loss=0.156214 | qqp_loss=0.381881 | stsb_loss=0.110562
# Epoch 15 | Shared Step 3500/22741 | sst2_loss=0.156183 | qqp_loss=0.381989 | stsb_loss=0.110629
# Epoch 15 | Shared Step 3550/22741 | sst2_loss=0.156565 | qqp_loss=0.382126 | stsb_loss=0.110576
# Epoch 15 | Shared Step 3600/22741 | sst2_loss=0.156775 | qqp_loss=0.382245 | stsb_loss=0.110646
# Epoch 15 | Shared Step 3650/22741 | sst2_loss=0.156452 | qqp_loss=0.382069 | stsb_loss=0.110744
# Epoch 15 | Shared Step 3700/22741 | sst2_loss=0.156733 | qqp_loss=0.382272 | stsb_loss=0.110770
# Epoch 15 | Shared Step 3750/22741 | sst2_loss=0.156875 | qqp_loss=0.382154 | stsb_loss=0.110730
# Epoch 15 | Shared Step 3800/22741 | sst2_loss=0.156947 | qqp_loss=0.382043 | stsb_loss=0.110841
# Epoch 15 | Shared Step 3850/22741 | sst2_loss=0.157258 | qqp_loss=0.381858 | stsb_loss=0.110931
# Epoch 15 | Shared Step 3900/22741 | sst2_loss=0.157179 | qqp_loss=0.381577 | stsb_loss=0.110944
# Epoch 15 | Shared Step 3950/22741 | sst2_loss=0.157184 | qqp_loss=0.381636 | stsb_loss=0.110964
# Epoch 15 | Shared Step 4000/22741 | sst2_loss=0.157302 | qqp_loss=0.381661 | stsb_loss=0.110879
# Epoch 15 | Shared Step 4050/22741 | sst2_loss=0.157446 | qqp_loss=0.381810 | stsb_loss=0.110897
# Epoch 15 | Shared Step 4100/22741 | sst2_loss=0.157138 | qqp_loss=0.381926 | stsb_loss=0.110780
# Epoch 15 | Shared Step 4150/22741 | sst2_loss=0.157363 | qqp_loss=0.381959 | stsb_loss=0.110772
# Epoch 15 | Shared Step 4200/22741 | sst2_loss=0.157168 | qqp_loss=0.382082 | stsb_loss=0.110773
# Epoch 15 | Shared Step 4250/22741 | sst2_loss=0.157247 | qqp_loss=0.381877 | stsb_loss=0.110809
# Epoch 15 | Shared Step 4300/22741 | sst2_loss=0.157037 | qqp_loss=0.382091 | stsb_loss=0.110893
# Epoch 15 | Shared Step 4350/22741 | sst2_loss=0.156977 | qqp_loss=0.381930 | stsb_loss=0.110776
# Epoch 15 | Shared Step 4400/22741 | sst2_loss=0.157075 | qqp_loss=0.382085 | stsb_loss=0.110712
# Epoch 15 | Shared Step 4450/22741 | sst2_loss=0.157108 | qqp_loss=0.382165 | stsb_loss=0.110705
# Epoch 15 | Shared Step 4500/22741 | sst2_loss=0.157031 | qqp_loss=0.382060 | stsb_loss=0.110726
# Epoch 15 | Shared Step 4550/22741 | sst2_loss=0.156681 | qqp_loss=0.381979 | stsb_loss=0.110744
# Epoch 15 | Shared Step 4600/22741 | sst2_loss=0.156473 | qqp_loss=0.382201 | stsb_loss=0.110742
# Epoch 15 | Shared Step 4650/22741 | sst2_loss=0.156363 | qqp_loss=0.382669 | stsb_loss=0.110805
# Epoch 15 | Shared Step 4700/22741 | sst2_loss=0.156210 | qqp_loss=0.382867 | stsb_loss=0.110790
# Epoch 15 | Shared Step 4750/22741 | sst2_loss=0.156127 | qqp_loss=0.382745 | stsb_loss=0.110878
# Epoch 15 | Shared Step 4800/22741 | sst2_loss=0.155919 | qqp_loss=0.382528 | stsb_loss=0.110759
# Epoch 15 | Shared Step 4850/22741 | sst2_loss=0.155831 | qqp_loss=0.382746 | stsb_loss=0.110744
# Epoch 15 | Shared Step 4900/22741 | sst2_loss=0.155938 | qqp_loss=0.382956 | stsb_loss=0.110896
# Epoch 15 | Shared Step 4950/22741 | sst2_loss=0.156066 | qqp_loss=0.383230 | stsb_loss=0.110998
# Epoch 15 | Shared Step 5000/22741 | sst2_loss=0.155902 | qqp_loss=0.383159 | stsb_loss=0.111034
# Epoch 15 | Shared Step 5050/22741 | sst2_loss=0.155846 | qqp_loss=0.383248 | stsb_loss=0.111156
# Epoch 15 | Shared Step 5100/22741 | sst2_loss=0.155639 | qqp_loss=0.383040 | stsb_loss=0.111088
# Epoch 15 | Shared Step 5150/22741 | sst2_loss=0.155831 | qqp_loss=0.382824 | stsb_loss=0.111027
# Epoch 15 | Shared Step 5200/22741 | sst2_loss=0.155791 | qqp_loss=0.382796 | stsb_loss=0.110952
# Epoch 15 | Shared Step 5250/22741 | sst2_loss=0.155569 | qqp_loss=0.382820 | stsb_loss=0.111035
# Epoch 15 | Shared Step 5300/22741 | sst2_loss=0.155513 | qqp_loss=0.383026 | stsb_loss=0.111160
# Epoch 15 | Shared Step 5350/22741 | sst2_loss=0.155642 | qqp_loss=0.383026 | stsb_loss=0.111232
# Epoch 15 | Shared Step 5400/22741 | sst2_loss=0.155588 | qqp_loss=0.382858 | stsb_loss=0.111257
# Epoch 15 | Shared Step 5450/22741 | sst2_loss=0.155545 | qqp_loss=0.382784 | stsb_loss=0.111163
# Epoch 15 | Shared Step 5500/22741 | sst2_loss=0.155304 | qqp_loss=0.383018 | stsb_loss=0.111150
# Epoch 15 | Shared Step 5550/22741 | sst2_loss=0.155340 | qqp_loss=0.383348 | stsb_loss=0.111146
# Epoch 15 | Shared Step 5600/22741 | sst2_loss=0.155425 | qqp_loss=0.383495 | stsb_loss=0.111189
# Epoch 15 | Shared Step 5650/22741 | sst2_loss=0.155422 | qqp_loss=0.383542 | stsb_loss=0.111090
# Epoch 15 | Shared Step 5700/22741 | sst2_loss=0.155219 | qqp_loss=0.383616 | stsb_loss=0.111080
# Epoch 15 | Shared Step 5750/22741 | sst2_loss=0.155280 | qqp_loss=0.383476 | stsb_loss=0.111073
# Epoch 15 | Shared Step 5800/22741 | sst2_loss=0.155064 | qqp_loss=0.383527 | stsb_loss=0.111024
# Epoch 15 | Shared Step 5850/22741 | sst2_loss=0.154624 | qqp_loss=0.383589 | stsb_loss=0.110962
# Epoch 15 | Shared Step 5900/22741 | sst2_loss=0.154580 | qqp_loss=0.383792 | stsb_loss=0.110946
# Epoch 15 | Shared Step 5950/22741 | sst2_loss=0.154964 | qqp_loss=0.383773 | stsb_loss=0.110900
# Epoch 15 | Shared Step 6000/22741 | sst2_loss=0.154988 | qqp_loss=0.383821 | stsb_loss=0.110907
# Epoch 15 | Shared Step 6050/22741 | sst2_loss=0.154948 | qqp_loss=0.383814 | stsb_loss=0.110873
# Epoch 15 | Shared Step 6100/22741 | sst2_loss=0.154785 | qqp_loss=0.383718 | stsb_loss=0.110895
# Epoch 15 | Shared Step 6150/22741 | sst2_loss=0.155208 | qqp_loss=0.383560 | stsb_loss=0.110725
# Epoch 15 | Shared Step 6200/22741 | sst2_loss=0.155177 | qqp_loss=0.383307 | stsb_loss=0.110748
# Epoch 15 | Shared Step 6250/22741 | sst2_loss=0.155111 | qqp_loss=0.383196 | stsb_loss=0.110765
# Epoch 15 | Shared Step 6300/22741 | sst2_loss=0.155113 | qqp_loss=0.383140 | stsb_loss=0.110786
# Epoch 15 | Shared Step 6350/22741 | sst2_loss=0.155357 | qqp_loss=0.383157 | stsb_loss=0.110833
# Epoch 15 | Shared Step 6400/22741 | sst2_loss=0.155531 | qqp_loss=0.383257 | stsb_loss=0.110826
# Epoch 15 | Shared Step 6450/22741 | sst2_loss=0.155736 | qqp_loss=0.383329 | stsb_loss=0.110897
# Epoch 15 | Shared Step 6500/22741 | sst2_loss=0.155884 | qqp_loss=0.383370 | stsb_loss=0.110765
# Epoch 15 | Shared Step 6550/22741 | sst2_loss=0.155756 | qqp_loss=0.383463 | stsb_loss=0.110794
# Epoch 15 | Shared Step 6600/22741 | sst2_loss=0.155814 | qqp_loss=0.383436 | stsb_loss=0.110709
# Epoch 15 | Shared Step 6650/22741 | sst2_loss=0.155779 | qqp_loss=0.383247 | stsb_loss=0.110748
# Epoch 15 | Shared Step 6700/22741 | sst2_loss=0.155899 | qqp_loss=0.383269 | stsb_loss=0.110744
# Epoch 15 | Shared Step 6750/22741 | sst2_loss=0.155918 | qqp_loss=0.383294 | stsb_loss=0.110765
# Epoch 15 | Shared Step 6800/22741 | sst2_loss=0.155810 | qqp_loss=0.383088 | stsb_loss=0.110790
# Epoch 15 | Shared Step 6850/22741 | sst2_loss=0.155805 | qqp_loss=0.383105 | stsb_loss=0.110686
# Epoch 15 | Shared Step 6900/22741 | sst2_loss=0.155805 | qqp_loss=0.382999 | stsb_loss=0.110678
# Epoch 15 | Shared Step 6950/22741 | sst2_loss=0.155745 | qqp_loss=0.383134 | stsb_loss=0.110673
# Epoch 15 | Shared Step 7000/22741 | sst2_loss=0.155823 | qqp_loss=0.383463 | stsb_loss=0.110727
# Epoch 15 | Shared Step 7050/22741 | sst2_loss=0.155790 | qqp_loss=0.383392 | stsb_loss=0.110723
# Epoch 15 | Shared Step 7100/22741 | sst2_loss=0.155673 | qqp_loss=0.383439 | stsb_loss=0.110692
# Epoch 15 | Shared Step 7150/22741 | sst2_loss=0.155816 | qqp_loss=0.383336 | stsb_loss=0.110728
# Epoch 15 | Shared Step 7200/22741 | sst2_loss=0.155844 | qqp_loss=0.383319 | stsb_loss=0.110751
# Epoch 15 | Shared Step 7250/22741 | sst2_loss=0.155993 | qqp_loss=0.383762 | stsb_loss=0.110710
# Epoch 15 | Shared Step 7300/22741 | sst2_loss=0.155889 | qqp_loss=0.383882 | stsb_loss=0.110654
# Epoch 15 | Shared Step 7350/22741 | sst2_loss=0.155842 | qqp_loss=0.383831 | stsb_loss=0.110671
# Epoch 15 | Shared Step 7400/22741 | sst2_loss=0.155923 | qqp_loss=0.383822 | stsb_loss=0.110614
# Epoch 15 | Shared Step 7450/22741 | sst2_loss=0.156024 | qqp_loss=0.383785 | stsb_loss=0.110618
# Epoch 15 | Shared Step 7500/22741 | sst2_loss=0.156051 | qqp_loss=0.383715 | stsb_loss=0.110586
# Epoch 15 | Shared Step 7550/22741 | sst2_loss=0.155956 | qqp_loss=0.383887 | stsb_loss=0.110535
# Epoch 15 | Shared Step 7600/22741 | sst2_loss=0.156037 | qqp_loss=0.383981 | stsb_loss=0.110543
# Epoch 15 | Shared Step 7650/22741 | sst2_loss=0.156159 | qqp_loss=0.384087 | stsb_loss=0.110507
# Epoch 15 | Shared Step 7700/22741 | sst2_loss=0.156018 | qqp_loss=0.384030 | stsb_loss=0.110496
# Epoch 15 | Shared Step 7750/22741 | sst2_loss=0.156124 | qqp_loss=0.383957 | stsb_loss=0.110545
# Epoch 15 | Shared Step 7800/22741 | sst2_loss=0.156145 | qqp_loss=0.383932 | stsb_loss=0.110546
# Epoch 15 | Shared Step 7850/22741 | sst2_loss=0.156049 | qqp_loss=0.383886 | stsb_loss=0.110593
# Epoch 15 | Shared Step 7900/22741 | sst2_loss=0.156237 | qqp_loss=0.383656 | stsb_loss=0.110619
# Epoch 15 | Shared Step 7950/22741 | sst2_loss=0.156391 | qqp_loss=0.383806 | stsb_loss=0.110538
# Epoch 15 | Shared Step 8000/22741 | sst2_loss=0.156329 | qqp_loss=0.383914 | stsb_loss=0.110587
# Epoch 15 | Shared Step 8050/22741 | sst2_loss=0.156604 | qqp_loss=0.383769 | stsb_loss=0.110565
# Epoch 15 | Shared Step 8100/22741 | sst2_loss=0.156532 | qqp_loss=0.383627 | stsb_loss=0.110639
# Epoch 15 | Shared Step 8150/22741 | sst2_loss=0.156535 | qqp_loss=0.383614 | stsb_loss=0.110742
# Epoch 15 | Shared Step 8200/22741 | sst2_loss=0.156576 | qqp_loss=0.383455 | stsb_loss=0.110810
# Epoch 15 | Shared Step 8250/22741 | sst2_loss=0.156458 | qqp_loss=0.383646 | stsb_loss=0.110826
# Epoch 15 | Shared Step 8300/22741 | sst2_loss=0.156619 | qqp_loss=0.383899 | stsb_loss=0.110759
# Epoch 15 | Shared Step 8350/22741 | sst2_loss=0.156569 | qqp_loss=0.383919 | stsb_loss=0.110806
# Epoch 15 | Shared Step 8400/22741 | sst2_loss=0.156493 | qqp_loss=0.384011 | stsb_loss=0.110840
# Epoch 15 | Shared Step 8450/22741 | sst2_loss=0.156346 | qqp_loss=0.384002 | stsb_loss=0.110800
# Epoch 15 | Shared Step 8500/22741 | sst2_loss=0.156392 | qqp_loss=0.383915 | stsb_loss=0.110765
# Epoch 15 | Shared Step 8550/22741 | sst2_loss=0.156372 | qqp_loss=0.384078 | stsb_loss=0.110813
# Epoch 15 | Shared Step 8600/22741 | sst2_loss=0.156368 | qqp_loss=0.384238 | stsb_loss=0.110782
# Epoch 15 | Shared Step 8650/22741 | sst2_loss=0.156295 | qqp_loss=0.384269 | stsb_loss=0.110772
# Epoch 15 | Shared Step 8700/22741 | sst2_loss=0.156132 | qqp_loss=0.384270 | stsb_loss=0.110768
# Epoch 15 | Shared Step 8750/22741 | sst2_loss=0.155998 | qqp_loss=0.384231 | stsb_loss=0.110752
# Epoch 15 | Shared Step 8800/22741 | sst2_loss=0.155889 | qqp_loss=0.384164 | stsb_loss=0.110773
# Epoch 15 | Shared Step 8850/22741 | sst2_loss=0.155732 | qqp_loss=0.384137 | stsb_loss=0.110801
# Epoch 15 | Shared Step 8900/22741 | sst2_loss=0.155655 | qqp_loss=0.384239 | stsb_loss=0.110794
# Epoch 15 | Shared Step 8950/22741 | sst2_loss=0.155620 | qqp_loss=0.384143 | stsb_loss=0.110869
# Epoch 15 | Shared Step 9000/22741 | sst2_loss=0.155581 | qqp_loss=0.384062 | stsb_loss=0.110849
# Epoch 15 | Shared Step 9050/22741 | sst2_loss=0.155412 | qqp_loss=0.384035 | stsb_loss=0.110786
# Epoch 15 | Shared Step 9100/22741 | sst2_loss=0.155580 | qqp_loss=0.383972 | stsb_loss=0.110764
# Epoch 15 | Shared Step 9150/22741 | sst2_loss=0.155484 | qqp_loss=0.383939 | stsb_loss=0.110857
# Epoch 15 | Shared Step 9200/22741 | sst2_loss=0.155434 | qqp_loss=0.383831 | stsb_loss=0.110908
# Epoch 15 | Shared Step 9250/22741 | sst2_loss=0.155434 | qqp_loss=0.383663 | stsb_loss=0.110910
# Epoch 15 | Shared Step 9300/22741 | sst2_loss=0.155345 | qqp_loss=0.383754 | stsb_loss=0.110916
# Epoch 15 | Shared Step 9350/22741 | sst2_loss=0.155323 | qqp_loss=0.383719 | stsb_loss=0.110902
# Epoch 15 | Shared Step 9400/22741 | sst2_loss=0.155431 | qqp_loss=0.383820 | stsb_loss=0.110889
# Epoch 15 | Shared Step 9450/22741 | sst2_loss=0.155413 | qqp_loss=0.383740 | stsb_loss=0.110897
# Epoch 15 | Shared Step 9500/22741 | sst2_loss=0.155352 | qqp_loss=0.383779 | stsb_loss=0.110899
# Epoch 15 | Shared Step 9550/22741 | sst2_loss=0.155333 | qqp_loss=0.383803 | stsb_loss=0.110907
# Epoch 15 | Shared Step 9600/22741 | sst2_loss=0.155267 | qqp_loss=0.383718 | stsb_loss=0.110966
# Epoch 15 | Shared Step 9650/22741 | sst2_loss=0.155303 | qqp_loss=0.383718 | stsb_loss=0.111007
# Epoch 15 | Shared Step 9700/22741 | sst2_loss=0.155321 | qqp_loss=0.383609 | stsb_loss=0.111076
# Epoch 15 | Shared Step 9750/22741 | sst2_loss=0.155377 | qqp_loss=0.383554 | stsb_loss=0.111051
# Epoch 15 | Shared Step 9800/22741 | sst2_loss=0.155406 | qqp_loss=0.383545 | stsb_loss=0.111107
# Epoch 15 | Shared Step 9850/22741 | sst2_loss=0.155318 | qqp_loss=0.383620 | stsb_loss=0.111104
# Epoch 15 | Shared Step 9900/22741 | sst2_loss=0.155309 | qqp_loss=0.383639 | stsb_loss=0.111099
# Epoch 15 | Shared Step 9950/22741 | sst2_loss=0.155379 | qqp_loss=0.383527 | stsb_loss=0.111122
# Epoch 15 | Shared Step 10000/22741 | sst2_loss=0.155362 | qqp_loss=0.383443 | stsb_loss=0.111166
# Epoch 15 | Shared Step 10050/22741 | sst2_loss=0.155258 | qqp_loss=0.383369 | stsb_loss=0.111133
# Epoch 15 | Shared Step 10100/22741 | sst2_loss=0.155127 | qqp_loss=0.383489 | stsb_loss=0.111098
# Epoch 15 | Shared Step 10150/22741 | sst2_loss=0.155208 | qqp_loss=0.383624 | stsb_loss=0.111149
# Epoch 15 | Shared Step 10200/22741 | sst2_loss=0.155293 | qqp_loss=0.383656 | stsb_loss=0.111113
# Epoch 15 | Shared Step 10250/22741 | sst2_loss=0.155329 | qqp_loss=0.383640 | stsb_loss=0.111228
# Epoch 15 | Shared Step 10300/22741 | sst2_loss=0.155355 | qqp_loss=0.383554 | stsb_loss=0.111257
# Epoch 15 | Shared Step 10350/22741 | sst2_loss=0.155433 | qqp_loss=0.383581 | stsb_loss=0.111238
# Epoch 15 | Shared Step 10400/22741 | sst2_loss=0.155496 | qqp_loss=0.383584 | stsb_loss=0.111213
# Epoch 15 | Shared Step 10450/22741 | sst2_loss=0.155347 | qqp_loss=0.383738 | stsb_loss=0.111196
# Epoch 15 | Shared Step 10500/22741 | sst2_loss=0.155304 | qqp_loss=0.383715 | stsb_loss=0.111204
# Epoch 15 | Shared Step 10550/22741 | sst2_loss=0.155440 | qqp_loss=0.383711 | stsb_loss=0.111152
# Epoch 15 | Shared Step 10600/22741 | sst2_loss=0.155533 | qqp_loss=0.383740 | stsb_loss=0.111147
# Epoch 15 | Shared Step 10650/22741 | sst2_loss=0.155677 | qqp_loss=0.383712 | stsb_loss=0.111118
# Epoch 15 | Shared Step 10700/22741 | sst2_loss=0.155774 | qqp_loss=0.383653 | stsb_loss=0.111108
# Epoch 15 | Shared Step 10750/22741 | sst2_loss=0.155675 | qqp_loss=0.383648 | stsb_loss=0.111129
# Epoch 15 | Shared Step 10800/22741 | sst2_loss=0.155620 | qqp_loss=0.383858 | stsb_loss=0.111091
# Epoch 15 | Shared Step 10850/22741 | sst2_loss=0.155552 | qqp_loss=0.383876 | stsb_loss=0.111081
# Epoch 15 | Shared Step 10900/22741 | sst2_loss=0.155600 | qqp_loss=0.383825 | stsb_loss=0.111093
# Epoch 15 | Shared Step 10950/22741 | sst2_loss=0.155555 | qqp_loss=0.383807 | stsb_loss=0.111110
# Epoch 15 | Shared Step 11000/22741 | sst2_loss=0.155495 | qqp_loss=0.383822 | stsb_loss=0.111129
# Epoch 15 | Shared Step 11050/22741 | sst2_loss=0.155335 | qqp_loss=0.383786 | stsb_loss=0.111109
# Epoch 15 | Shared Step 11100/22741 | sst2_loss=0.155430 | qqp_loss=0.383771 | stsb_loss=0.111107
# Epoch 15 | Shared Step 11150/22741 | sst2_loss=0.155260 | qqp_loss=0.383813 | stsb_loss=0.111125
# Epoch 15 | Shared Step 11200/22741 | sst2_loss=0.155303 | qqp_loss=0.383776 | stsb_loss=0.111145
# Epoch 15 | Shared Step 11250/22741 | sst2_loss=0.155161 | qqp_loss=0.383734 | stsb_loss=0.111102
# Epoch 15 | Shared Step 11300/22741 | sst2_loss=0.155166 | qqp_loss=0.383762 | stsb_loss=0.111065
# Epoch 15 | Shared Step 11350/22741 | sst2_loss=0.155220 | qqp_loss=0.383732 | stsb_loss=0.111031
# Epoch 15 | Shared Step 11400/22741 | sst2_loss=0.155188 | qqp_loss=0.383832 | stsb_loss=0.111046
# Epoch 15 | Shared Step 11450/22741 | sst2_loss=0.155297 | qqp_loss=0.383856 | stsb_loss=0.111046
# Epoch 15 | Shared Step 11500/22741 | sst2_loss=0.155409 | qqp_loss=0.383766 | stsb_loss=0.111039
# Epoch 15 | Shared Step 11550/22741 | sst2_loss=0.155449 | qqp_loss=0.383807 | stsb_loss=0.110979
# Epoch 15 | Shared Step 11600/22741 | sst2_loss=0.155456 | qqp_loss=0.383866 | stsb_loss=0.110939
# Epoch 15 | Shared Step 11650/22741 | sst2_loss=0.155499 | qqp_loss=0.383757 | stsb_loss=0.110952
# Epoch 15 | Shared Step 11700/22741 | sst2_loss=0.155458 | qqp_loss=0.383768 | stsb_loss=0.110952
# Epoch 15 | Shared Step 11750/22741 | sst2_loss=0.155379 | qqp_loss=0.383696 | stsb_loss=0.110976
# Epoch 15 | Shared Step 11800/22741 | sst2_loss=0.155470 | qqp_loss=0.383720 | stsb_loss=0.110936
# Epoch 15 | Shared Step 11850/22741 | sst2_loss=0.155604 | qqp_loss=0.383646 | stsb_loss=0.110954
# Epoch 15 | Shared Step 11900/22741 | sst2_loss=0.155421 | qqp_loss=0.383597 | stsb_loss=0.110936
# Epoch 15 | Shared Step 11950/22741 | sst2_loss=0.155423 | qqp_loss=0.383505 | stsb_loss=0.110925
# Epoch 15 | Shared Step 12000/22741 | sst2_loss=0.155519 | qqp_loss=0.383566 | stsb_loss=0.110989
# Epoch 15 | Shared Step 12050/22741 | sst2_loss=0.155468 | qqp_loss=0.383512 | stsb_loss=0.111109
# Epoch 15 | Shared Step 12100/22741 | sst2_loss=0.155525 | qqp_loss=0.383602 | stsb_loss=0.111089
# Epoch 15 | Shared Step 12150/22741 | sst2_loss=0.155565 | qqp_loss=0.383582 | stsb_loss=0.111100
# Epoch 15 | Shared Step 12200/22741 | sst2_loss=0.155566 | qqp_loss=0.383573 | stsb_loss=0.111132
# Epoch 15 | Shared Step 12250/22741 | sst2_loss=0.155724 | qqp_loss=0.383683 | stsb_loss=0.111125
# Epoch 15 | Shared Step 12300/22741 | sst2_loss=0.155722 | qqp_loss=0.383575 | stsb_loss=0.111083
# Epoch 15 | Shared Step 12350/22741 | sst2_loss=0.155722 | qqp_loss=0.383527 | stsb_loss=0.111027
# Epoch 15 | Shared Step 12400/22741 | sst2_loss=0.155718 | qqp_loss=0.383464 | stsb_loss=0.111001
# Epoch 15 | Shared Step 12450/22741 | sst2_loss=0.155666 | qqp_loss=0.383406 | stsb_loss=0.111096
# Epoch 15 | Shared Step 12500/22741 | sst2_loss=0.155801 | qqp_loss=0.383315 | stsb_loss=0.111059
# Epoch 15 | Shared Step 12550/22741 | sst2_loss=0.155827 | qqp_loss=0.383141 | stsb_loss=0.111091
# Epoch 15 | Shared Step 12600/22741 | sst2_loss=0.155845 | qqp_loss=0.383022 | stsb_loss=0.111076
# Epoch 15 | Shared Step 12650/22741 | sst2_loss=0.155711 | qqp_loss=0.382964 | stsb_loss=0.111017
# Epoch 15 | Shared Step 12700/22741 | sst2_loss=0.155674 | qqp_loss=0.382998 | stsb_loss=0.111001
# Epoch 15 | Shared Step 12750/22741 | sst2_loss=0.155608 | qqp_loss=0.383000 | stsb_loss=0.110984
# Epoch 15 | Shared Step 12800/22741 | sst2_loss=0.155564 | qqp_loss=0.383009 | stsb_loss=0.110994
# Epoch 15 | Shared Step 12850/22741 | sst2_loss=0.155565 | qqp_loss=0.383046 | stsb_loss=0.111008
# Epoch 15 | Shared Step 12900/22741 | sst2_loss=0.155462 | qqp_loss=0.382941 | stsb_loss=0.110945
# Epoch 15 | Shared Step 12950/22741 | sst2_loss=0.155417 | qqp_loss=0.382971 | stsb_loss=0.110899
# Epoch 15 | Shared Step 13000/22741 | sst2_loss=0.155308 | qqp_loss=0.383016 | stsb_loss=0.110891
# Epoch 15 | Shared Step 13050/22741 | sst2_loss=0.155239 | qqp_loss=0.382822 | stsb_loss=0.110862
# Epoch 15 | Shared Step 13100/22741 | sst2_loss=0.155119 | qqp_loss=0.382867 | stsb_loss=0.110829
# Epoch 15 | Shared Step 13150/22741 | sst2_loss=0.155061 | qqp_loss=0.382819 | stsb_loss=0.110844
# Epoch 15 | Shared Step 13200/22741 | sst2_loss=0.155041 | qqp_loss=0.382898 | stsb_loss=0.110795
# Epoch 15 | Shared Step 13250/22741 | sst2_loss=0.154999 | qqp_loss=0.382984 | stsb_loss=0.110798
# Epoch 15 | Shared Step 13300/22741 | sst2_loss=0.155028 | qqp_loss=0.382951 | stsb_loss=0.110810
# Epoch 15 | Shared Step 13350/22741 | sst2_loss=0.154984 | qqp_loss=0.382926 | stsb_loss=0.110771
# Epoch 15 | Shared Step 13400/22741 | sst2_loss=0.154938 | qqp_loss=0.382899 | stsb_loss=0.110758
# Epoch 15 | Shared Step 13450/22741 | sst2_loss=0.155030 | qqp_loss=0.383028 | stsb_loss=0.110719
# Epoch 15 | Shared Step 13500/22741 | sst2_loss=0.155039 | qqp_loss=0.383086 | stsb_loss=0.110705
# Epoch 15 | Shared Step 13550/22741 | sst2_loss=0.154951 | qqp_loss=0.382928 | stsb_loss=0.110728
# Epoch 15 | Shared Step 13600/22741 | sst2_loss=0.154923 | qqp_loss=0.382909 | stsb_loss=0.110749
# Epoch 15 | Shared Step 13650/22741 | sst2_loss=0.155006 | qqp_loss=0.382880 | stsb_loss=0.110738
# Epoch 15 | Shared Step 13700/22741 | sst2_loss=0.154968 | qqp_loss=0.382817 | stsb_loss=0.110678
# Epoch 15 | Shared Step 13750/22741 | sst2_loss=0.154956 | qqp_loss=0.382822 | stsb_loss=0.110664
# Epoch 15 | Shared Step 13800/22741 | sst2_loss=0.154845 | qqp_loss=0.382738 | stsb_loss=0.110637
# Epoch 15 | Shared Step 13850/22741 | sst2_loss=0.154785 | qqp_loss=0.382720 | stsb_loss=0.110634
# Epoch 15 | Shared Step 13900/22741 | sst2_loss=0.154803 | qqp_loss=0.382638 | stsb_loss=0.110667
# Epoch 15 | Shared Step 13950/22741 | sst2_loss=0.154820 | qqp_loss=0.382786 | stsb_loss=0.110669
# Epoch 15 | Shared Step 14000/22741 | sst2_loss=0.154837 | qqp_loss=0.382905 | stsb_loss=0.110650
# Epoch 15 | Shared Step 14050/22741 | sst2_loss=0.154791 | qqp_loss=0.382888 | stsb_loss=0.110655
# Epoch 15 | Shared Step 14100/22741 | sst2_loss=0.154750 | qqp_loss=0.383030 | stsb_loss=0.110672
# Epoch 15 | Shared Step 14150/22741 | sst2_loss=0.154838 | qqp_loss=0.383071 | stsb_loss=0.110658
# Epoch 15 | Shared Step 14200/22741 | sst2_loss=0.154803 | qqp_loss=0.383078 | stsb_loss=0.110700
# Epoch 15 | Shared Step 14250/22741 | sst2_loss=0.154710 | qqp_loss=0.383099 | stsb_loss=0.110687
# Epoch 15 | Shared Step 14300/22741 | sst2_loss=0.154558 | qqp_loss=0.383154 | stsb_loss=0.110684
# Epoch 15 | Shared Step 14350/22741 | sst2_loss=0.154664 | qqp_loss=0.383022 | stsb_loss=0.110653
# Epoch 15 | Shared Step 14400/22741 | sst2_loss=0.154634 | qqp_loss=0.382898 | stsb_loss=0.110643
# Epoch 15 | Shared Step 14450/22741 | sst2_loss=0.154717 | qqp_loss=0.382988 | stsb_loss=0.110629
# Epoch 15 | Shared Step 14500/22741 | sst2_loss=0.154709 | qqp_loss=0.382958 | stsb_loss=0.110629
# Epoch 15 | Shared Step 14550/22741 | sst2_loss=0.154754 | qqp_loss=0.382866 | stsb_loss=0.110641
# Epoch 15 | Shared Step 14600/22741 | sst2_loss=0.154912 | qqp_loss=0.382850 | stsb_loss=0.110629
# Epoch 15 | Shared Step 14650/22741 | sst2_loss=0.154832 | qqp_loss=0.382745 | stsb_loss=0.110624
# Epoch 15 | Shared Step 14700/22741 | sst2_loss=0.154943 | qqp_loss=0.382710 | stsb_loss=0.110658
# Epoch 15 | Shared Step 14750/22741 | sst2_loss=0.154890 | qqp_loss=0.382684 | stsb_loss=0.110680
# Epoch 15 | Shared Step 14800/22741 | sst2_loss=0.154921 | qqp_loss=0.382596 | stsb_loss=0.110667
# Epoch 15 | Shared Step 14850/22741 | sst2_loss=0.155101 | qqp_loss=0.382645 | stsb_loss=0.110658
# Epoch 15 | Shared Step 14900/22741 | sst2_loss=0.155065 | qqp_loss=0.382516 | stsb_loss=0.110652
# Epoch 15 | Shared Step 14950/22741 | sst2_loss=0.154990 | qqp_loss=0.382532 | stsb_loss=0.110654
# Epoch 15 | Shared Step 15000/22741 | sst2_loss=0.154976 | qqp_loss=0.382513 | stsb_loss=0.110680
# Epoch 15 | Shared Step 15050/22741 | sst2_loss=0.154887 | qqp_loss=0.382506 | stsb_loss=0.110643
# Epoch 15 | Shared Step 15100/22741 | sst2_loss=0.154811 | qqp_loss=0.382487 | stsb_loss=0.110628
# Epoch 15 | Shared Step 15150/22741 | sst2_loss=0.154796 | qqp_loss=0.382532 | stsb_loss=0.110611
# Epoch 15 | Shared Step 15200/22741 | sst2_loss=0.154791 | qqp_loss=0.382539 | stsb_loss=0.110616
# Epoch 15 | Shared Step 15250/22741 | sst2_loss=0.154727 | qqp_loss=0.382616 | stsb_loss=0.110613
# Epoch 15 | Shared Step 15300/22741 | sst2_loss=0.154810 | qqp_loss=0.382666 | stsb_loss=0.110638
# Epoch 15 | Shared Step 15350/22741 | sst2_loss=0.154729 | qqp_loss=0.382694 | stsb_loss=0.110662
# Epoch 15 | Shared Step 15400/22741 | sst2_loss=0.154718 | qqp_loss=0.382641 | stsb_loss=0.110639
# Epoch 15 | Shared Step 15450/22741 | sst2_loss=0.154620 | qqp_loss=0.382733 | stsb_loss=0.110629
# Epoch 15 | Shared Step 15500/22741 | sst2_loss=0.154594 | qqp_loss=0.382784 | stsb_loss=0.110603
# Epoch 15 | Shared Step 15550/22741 | sst2_loss=0.154599 | qqp_loss=0.382741 | stsb_loss=0.110585
# Epoch 15 | Shared Step 15600/22741 | sst2_loss=0.154573 | qqp_loss=0.382758 | stsb_loss=0.110547
# Epoch 15 | Shared Step 15650/22741 | sst2_loss=0.154609 | qqp_loss=0.382834 | stsb_loss=0.110572
# Epoch 15 | Shared Step 15700/22741 | sst2_loss=0.154605 | qqp_loss=0.382881 | stsb_loss=0.110572
# Epoch 15 | Shared Step 15750/22741 | sst2_loss=0.154619 | qqp_loss=0.382937 | stsb_loss=0.110553
# Epoch 15 | Shared Step 15800/22741 | sst2_loss=0.154631 | qqp_loss=0.383039 | stsb_loss=0.110526
# Epoch 15 | Shared Step 15850/22741 | sst2_loss=0.154605 | qqp_loss=0.383030 | stsb_loss=0.110504
# Epoch 15 | Shared Step 15900/22741 | sst2_loss=0.154660 | qqp_loss=0.383038 | stsb_loss=0.110488
# Epoch 15 | Shared Step 15950/22741 | sst2_loss=0.154620 | qqp_loss=0.383030 | stsb_loss=0.110458
# Epoch 15 | Shared Step 16000/22741 | sst2_loss=0.154650 | qqp_loss=0.383012 | stsb_loss=0.110424
# Epoch 15 | Shared Step 16050/22741 | sst2_loss=0.154687 | qqp_loss=0.382993 | stsb_loss=0.110409
# Epoch 15 | Shared Step 16100/22741 | sst2_loss=0.154593 | qqp_loss=0.383049 | stsb_loss=0.110428
# Epoch 15 | Shared Step 16150/22741 | sst2_loss=0.154629 | qqp_loss=0.383116 | stsb_loss=0.110441
# Epoch 15 | Shared Step 16200/22741 | sst2_loss=0.154648 | qqp_loss=0.383129 | stsb_loss=0.110443
# Epoch 15 | Shared Step 16250/22741 | sst2_loss=0.154628 | qqp_loss=0.383175 | stsb_loss=0.110434
# Epoch 15 | Shared Step 16300/22741 | sst2_loss=0.154590 | qqp_loss=0.383207 | stsb_loss=0.110429
# Epoch 15 | Shared Step 16350/22741 | sst2_loss=0.154626 | qqp_loss=0.383246 | stsb_loss=0.110437
# Epoch 15 | Shared Step 16400/22741 | sst2_loss=0.154578 | qqp_loss=0.383201 | stsb_loss=0.110424
# Epoch 15 | Shared Step 16450/22741 | sst2_loss=0.154644 | qqp_loss=0.383229 | stsb_loss=0.110433
# Epoch 15 | Shared Step 16500/22741 | sst2_loss=0.154659 | qqp_loss=0.383240 | stsb_loss=0.110428
# Epoch 15 | Shared Step 16550/22741 | sst2_loss=0.154542 | qqp_loss=0.383229 | stsb_loss=0.110459
# Epoch 15 | Shared Step 16600/22741 | sst2_loss=0.154568 | qqp_loss=0.383304 | stsb_loss=0.110434
# Epoch 15 | Shared Step 16650/22741 | sst2_loss=0.154563 | qqp_loss=0.383337 | stsb_loss=0.110443
# Epoch 15 | Shared Step 16700/22741 | sst2_loss=0.154608 | qqp_loss=0.383376 | stsb_loss=0.110436
# Epoch 15 | Shared Step 16750/22741 | sst2_loss=0.154592 | qqp_loss=0.383375 | stsb_loss=0.110469
# Epoch 15 | Shared Step 16800/22741 | sst2_loss=0.154567 | qqp_loss=0.383366 | stsb_loss=0.110486
# Epoch 15 | Shared Step 16850/22741 | sst2_loss=0.154471 | qqp_loss=0.383404 | stsb_loss=0.110473
# Epoch 15 | Shared Step 16900/22741 | sst2_loss=0.154450 | qqp_loss=0.383317 | stsb_loss=0.110485
# Epoch 15 | Shared Step 16950/22741 | sst2_loss=0.154419 | qqp_loss=0.383325 | stsb_loss=0.110439
# Epoch 15 | Shared Step 17000/22741 | sst2_loss=0.154389 | qqp_loss=0.383357 | stsb_loss=0.110405
# Epoch 15 | Shared Step 17050/22741 | sst2_loss=0.154392 | qqp_loss=0.383355 | stsb_loss=0.110394
# Epoch 15 | Shared Step 17100/22741 | sst2_loss=0.154368 | qqp_loss=0.383275 | stsb_loss=0.110393
# Epoch 15 | Shared Step 17150/22741 | sst2_loss=0.154302 | qqp_loss=0.383216 | stsb_loss=0.110403
# Epoch 15 | Shared Step 17200/22741 | sst2_loss=0.154259 | qqp_loss=0.383234 | stsb_loss=0.110388
# Epoch 15 | Shared Step 17250/22741 | sst2_loss=0.154156 | qqp_loss=0.383223 | stsb_loss=0.110379
# Epoch 15 | Shared Step 17300/22741 | sst2_loss=0.154078 | qqp_loss=0.383265 | stsb_loss=0.110368
# Epoch 15 | Shared Step 17350/22741 | sst2_loss=0.154021 | qqp_loss=0.383276 | stsb_loss=0.110331
# Epoch 15 | Shared Step 17400/22741 | sst2_loss=0.154017 | qqp_loss=0.383277 | stsb_loss=0.110347
# Epoch 15 | Shared Step 17450/22741 | sst2_loss=0.153939 | qqp_loss=0.383287 | stsb_loss=0.110369
# Epoch 15 | Shared Step 17500/22741 | sst2_loss=0.153951 | qqp_loss=0.383346 | stsb_loss=0.110361
# Epoch 15 | Shared Step 17550/22741 | sst2_loss=0.153926 | qqp_loss=0.383370 | stsb_loss=0.110391
# Epoch 15 | Shared Step 17600/22741 | sst2_loss=0.153920 | qqp_loss=0.383408 | stsb_loss=0.110420
# Epoch 15 | Shared Step 17650/22741 | sst2_loss=0.153944 | qqp_loss=0.383481 | stsb_loss=0.110410
# Epoch 15 | Shared Step 17700/22741 | sst2_loss=0.153937 | qqp_loss=0.383457 | stsb_loss=0.110403
# Epoch 15 | Shared Step 17750/22741 | sst2_loss=0.153902 | qqp_loss=0.383510 | stsb_loss=0.110408
# Epoch 15 | Shared Step 17800/22741 | sst2_loss=0.153959 | qqp_loss=0.383445 | stsb_loss=0.110397
# Epoch 15 | Shared Step 17850/22741 | sst2_loss=0.153996 | qqp_loss=0.383415 | stsb_loss=0.110430
# Epoch 15 | Shared Step 17900/22741 | sst2_loss=0.153959 | qqp_loss=0.383406 | stsb_loss=0.110428
# Epoch 15 | Shared Step 17950/22741 | sst2_loss=0.153951 | qqp_loss=0.383477 | stsb_loss=0.110401
# Epoch 15 | Shared Step 18000/22741 | sst2_loss=0.153913 | qqp_loss=0.383536 | stsb_loss=0.110419
# Epoch 15 | Shared Step 18050/22741 | sst2_loss=0.153854 | qqp_loss=0.383489 | stsb_loss=0.110427
# Epoch 15 | Shared Step 18100/22741 | sst2_loss=0.153862 | qqp_loss=0.383417 | stsb_loss=0.110417
# Epoch 15 | Shared Step 18150/22741 | sst2_loss=0.153841 | qqp_loss=0.383327 | stsb_loss=0.110407
# Epoch 15 | Shared Step 18200/22741 | sst2_loss=0.153812 | qqp_loss=0.383325 | stsb_loss=0.110406
# Epoch 15 | Shared Step 18250/22741 | sst2_loss=0.153759 | qqp_loss=0.383368 | stsb_loss=0.110427
# Epoch 15 | Shared Step 18300/22741 | sst2_loss=0.153764 | qqp_loss=0.383356 | stsb_loss=0.110419
# Epoch 15 | Shared Step 18350/22741 | sst2_loss=0.153771 | qqp_loss=0.383432 | stsb_loss=0.110438
# Epoch 15 | Shared Step 18400/22741 | sst2_loss=0.153803 | qqp_loss=0.383475 | stsb_loss=0.110441
# Epoch 15 | Shared Step 18450/22741 | sst2_loss=0.153778 | qqp_loss=0.383433 | stsb_loss=0.110408
# Epoch 15 | Shared Step 18500/22741 | sst2_loss=0.153655 | qqp_loss=0.383463 | stsb_loss=0.110394
# Epoch 15 | Shared Step 18550/22741 | sst2_loss=0.153689 | qqp_loss=0.383519 | stsb_loss=0.110446
# Epoch 15 | Shared Step 18600/22741 | sst2_loss=0.153691 | qqp_loss=0.383571 | stsb_loss=0.110442
# Epoch 15 | Shared Step 18650/22741 | sst2_loss=0.153679 | qqp_loss=0.383580 | stsb_loss=0.110443
# Epoch 15 | Shared Step 18700/22741 | sst2_loss=0.153653 | qqp_loss=0.383511 | stsb_loss=0.110436
# Epoch 15 | Shared Step 18750/22741 | sst2_loss=0.153722 | qqp_loss=0.383525 | stsb_loss=0.110405
# Epoch 15 | Shared Step 18800/22741 | sst2_loss=0.153764 | qqp_loss=0.383503 | stsb_loss=0.110434
# Epoch 15 | Shared Step 18850/22741 | sst2_loss=0.153761 | qqp_loss=0.383572 | stsb_loss=0.110386
# Epoch 15 | Shared Step 18900/22741 | sst2_loss=0.153784 | qqp_loss=0.383595 | stsb_loss=0.110371
# Epoch 15 | Shared Step 18950/22741 | sst2_loss=0.153720 | qqp_loss=0.383621 | stsb_loss=0.110373
# Epoch 15 | Shared Step 19000/22741 | sst2_loss=0.153830 | qqp_loss=0.383602 | stsb_loss=0.110366
# Epoch 15 | Shared Step 19050/22741 | sst2_loss=0.153949 | qqp_loss=0.383534 | stsb_loss=0.110379
# Epoch 15 | Shared Step 19100/22741 | sst2_loss=0.154045 | qqp_loss=0.383433 | stsb_loss=0.110353
# Epoch 15 | Shared Step 19150/22741 | sst2_loss=0.154090 | qqp_loss=0.383457 | stsb_loss=0.110380
# Epoch 15 | Shared Step 19200/22741 | sst2_loss=0.154102 | qqp_loss=0.383411 | stsb_loss=0.110350
# Epoch 15 | Shared Step 19250/22741 | sst2_loss=0.154102 | qqp_loss=0.383444 | stsb_loss=0.110353
# Epoch 15 | Shared Step 19300/22741 | sst2_loss=0.154079 | qqp_loss=0.383497 | stsb_loss=0.110340
# Epoch 15 | Shared Step 19350/22741 | sst2_loss=0.154052 | qqp_loss=0.383501 | stsb_loss=0.110321
# Epoch 15 | Shared Step 19400/22741 | sst2_loss=0.153998 | qqp_loss=0.383588 | stsb_loss=0.110303
# Epoch 15 | Shared Step 19450/22741 | sst2_loss=0.154028 | qqp_loss=0.383518 | stsb_loss=0.110281
# Epoch 15 | Shared Step 19500/22741 | sst2_loss=0.153995 | qqp_loss=0.383582 | stsb_loss=0.110276
# Epoch 15 | Shared Step 19550/22741 | sst2_loss=0.154010 | qqp_loss=0.383594 | stsb_loss=0.110255
# Epoch 15 | Shared Step 19600/22741 | sst2_loss=0.153925 | qqp_loss=0.383504 | stsb_loss=0.110266
# Epoch 15 | Shared Step 19650/22741 | sst2_loss=0.153882 | qqp_loss=0.383531 | stsb_loss=0.110259
# Epoch 15 | Shared Step 19700/22741 | sst2_loss=0.153874 | qqp_loss=0.383436 | stsb_loss=0.110269
# Epoch 15 | Shared Step 19750/22741 | sst2_loss=0.153906 | qqp_loss=0.383385 | stsb_loss=0.110245
# Epoch 15 | Shared Step 19800/22741 | sst2_loss=0.153974 | qqp_loss=0.383400 | stsb_loss=0.110239
# Epoch 15 | Shared Step 19850/22741 | sst2_loss=0.153964 | qqp_loss=0.383344 | stsb_loss=0.110209
# Epoch 15 | Shared Step 19900/22741 | sst2_loss=0.153964 | qqp_loss=0.383249 | stsb_loss=0.110227
# Epoch 15 | Shared Step 19950/22741 | sst2_loss=0.153995 | qqp_loss=0.383208 | stsb_loss=0.110220
# Epoch 15 | Shared Step 20000/22741 | sst2_loss=0.154015 | qqp_loss=0.383157 | stsb_loss=0.110248
# Epoch 15 | Shared Step 20050/22741 | sst2_loss=0.153997 | qqp_loss=0.383082 | stsb_loss=0.110236
# Epoch 15 | Shared Step 20100/22741 | sst2_loss=0.154007 | qqp_loss=0.383083 | stsb_loss=0.110275
# Epoch 15 | Shared Step 20150/22741 | sst2_loss=0.154034 | qqp_loss=0.383083 | stsb_loss=0.110282
# Epoch 15 | Shared Step 20200/22741 | sst2_loss=0.153993 | qqp_loss=0.382970 | stsb_loss=0.110230
# Epoch 15 | Shared Step 20250/22741 | sst2_loss=0.154029 | qqp_loss=0.383067 | stsb_loss=0.110191
# Epoch 15 | Shared Step 20300/22741 | sst2_loss=0.154006 | qqp_loss=0.383038 | stsb_loss=0.110198
# Epoch 15 | Shared Step 20350/22741 | sst2_loss=0.154017 | qqp_loss=0.383023 | stsb_loss=0.110212
# Epoch 15 | Shared Step 20400/22741 | sst2_loss=0.154110 | qqp_loss=0.383074 | stsb_loss=0.110224
# Epoch 15 | Shared Step 20450/22741 | sst2_loss=0.154111 | qqp_loss=0.383050 | stsb_loss=0.110216
# Epoch 15 | Shared Step 20500/22741 | sst2_loss=0.154045 | qqp_loss=0.383069 | stsb_loss=0.110218
# Epoch 15 | Shared Step 20550/22741 | sst2_loss=0.154054 | qqp_loss=0.383105 | stsb_loss=0.110195
# Epoch 15 | Shared Step 20600/22741 | sst2_loss=0.154096 | qqp_loss=0.383126 | stsb_loss=0.110181
# Epoch 15 | Shared Step 20650/22741 | sst2_loss=0.154068 | qqp_loss=0.383178 | stsb_loss=0.110146
# Epoch 15 | Shared Step 20700/22741 | sst2_loss=0.154134 | qqp_loss=0.383210 | stsb_loss=0.110135
# Epoch 15 | Shared Step 20750/22741 | sst2_loss=0.154056 | qqp_loss=0.383172 | stsb_loss=0.110123
# Epoch 15 | Shared Step 20800/22741 | sst2_loss=0.154045 | qqp_loss=0.383186 | stsb_loss=0.110121
# Epoch 15 | Shared Step 20850/22741 | sst2_loss=0.154010 | qqp_loss=0.383188 | stsb_loss=0.110125
# Epoch 15 | Shared Step 20900/22741 | sst2_loss=0.154062 | qqp_loss=0.383118 | stsb_loss=0.110104
# Epoch 15 | Shared Step 20950/22741 | sst2_loss=0.154012 | qqp_loss=0.383075 | stsb_loss=0.110117
# Epoch 15 | Shared Step 21000/22741 | sst2_loss=0.154050 | qqp_loss=0.383073 | stsb_loss=0.110102
# Epoch 15 | Shared Step 21050/22741 | sst2_loss=0.154027 | qqp_loss=0.383039 | stsb_loss=0.110129
# Epoch 15 | Shared Step 21100/22741 | sst2_loss=0.154067 | qqp_loss=0.383023 | stsb_loss=0.110118
# Epoch 15 | Shared Step 21150/22741 | sst2_loss=0.154082 | qqp_loss=0.383038 | stsb_loss=0.110129
# Epoch 15 | Shared Step 21200/22741 | sst2_loss=0.154063 | qqp_loss=0.383145 | stsb_loss=0.110118
# Epoch 15 | Shared Step 21250/22741 | sst2_loss=0.154043 | qqp_loss=0.383201 | stsb_loss=0.110109
# Epoch 15 | Shared Step 21300/22741 | sst2_loss=0.153967 | qqp_loss=0.383201 | stsb_loss=0.110097
# Epoch 15 | Shared Step 21350/22741 | sst2_loss=0.153914 | qqp_loss=0.383177 | stsb_loss=0.110087
# Epoch 15 | Shared Step 21400/22741 | sst2_loss=0.153813 | qqp_loss=0.383187 | stsb_loss=0.110094
# Epoch 15 | Shared Step 21450/22741 | sst2_loss=0.153843 | qqp_loss=0.383242 | stsb_loss=0.110116
# Epoch 15 | Shared Step 21500/22741 | sst2_loss=0.153810 | qqp_loss=0.383297 | stsb_loss=0.110120
# Epoch 15 | Shared Step 21550/22741 | sst2_loss=0.153784 | qqp_loss=0.383326 | stsb_loss=0.110119
# Epoch 15 | Shared Step 21600/22741 | sst2_loss=0.153778 | qqp_loss=0.383343 | stsb_loss=0.110103
# Epoch 15 | Shared Step 21650/22741 | sst2_loss=0.153731 | qqp_loss=0.383324 | stsb_loss=0.110088
# Epoch 15 | Shared Step 21700/22741 | sst2_loss=0.153684 | qqp_loss=0.383295 | stsb_loss=0.110056
# Epoch 15 | Shared Step 21750/22741 | sst2_loss=0.153695 | qqp_loss=0.383220 | stsb_loss=0.110055
# Epoch 15 | Shared Step 21800/22741 | sst2_loss=0.153726 | qqp_loss=0.383248 | stsb_loss=0.110064
# Epoch 15 | Shared Step 21850/22741 | sst2_loss=0.153688 | qqp_loss=0.383219 | stsb_loss=0.110059
# Epoch 15 | Shared Step 21900/22741 | sst2_loss=0.153709 | qqp_loss=0.383135 | stsb_loss=0.110073
# Epoch 15 | Shared Step 21950/22741 | sst2_loss=0.153656 | qqp_loss=0.383131 | stsb_loss=0.110085
# Epoch 15 | Shared Step 22000/22741 | sst2_loss=0.153682 | qqp_loss=0.383156 | stsb_loss=0.110064
# Epoch 15 | Shared Step 22050/22741 | sst2_loss=0.153668 | qqp_loss=0.383138 | stsb_loss=0.110045
# Epoch 15 | Shared Step 22100/22741 | sst2_loss=0.153640 | qqp_loss=0.383080 | stsb_loss=0.110026
# Epoch 15 | Shared Step 22150/22741 | sst2_loss=0.153648 | qqp_loss=0.383102 | stsb_loss=0.110038
# Epoch 15 | Shared Step 22200/22741 | sst2_loss=0.153628 | qqp_loss=0.383194 | stsb_loss=0.110031
# Epoch 15 | Shared Step 22250/22741 | sst2_loss=0.153633 | qqp_loss=0.383173 | stsb_loss=0.110013
# Epoch 15 | Shared Step 22300/22741 | sst2_loss=0.153616 | qqp_loss=0.383176 | stsb_loss=0.110018
# Epoch 15 | Shared Step 22350/22741 | sst2_loss=0.153613 | qqp_loss=0.383172 | stsb_loss=0.110023
# Epoch 15 | Shared Step 22400/22741 | sst2_loss=0.153633 | qqp_loss=0.383084 | stsb_loss=0.110026
# Epoch 15 | Shared Step 22450/22741 | sst2_loss=0.153598 | qqp_loss=0.383165 | stsb_loss=0.110003
# Epoch 15 | Shared Step 22500/22741 | sst2_loss=0.153587 | qqp_loss=0.383225 | stsb_loss=0.110006
# Epoch 15 | Shared Step 22550/22741 | sst2_loss=0.153576 | qqp_loss=0.383204 | stsb_loss=0.110025
# Epoch 15 | Shared Step 22600/22741 | sst2_loss=0.153622 | qqp_loss=0.383141 | stsb_loss=0.110030
# Epoch 15 | Shared Step 22650/22741 | sst2_loss=0.153602 | qqp_loss=0.383130 | stsb_loss=0.110016
# Epoch 15 | Shared Step 22700/22741 | sst2_loss=0.153525 | qqp_loss=0.383079 | stsb_loss=0.110014
# Epoch 15 | Shared Step 22741/22741 | sst2_loss=0.153515 | qqp_loss=0.383108 | stsb_loss=0.109997
#
# Validation results:
# {
#   "epoch": 15,
#   "train_loss_overall": 0.21554013967452182,
#   "train_loss_sst2": 0.15351501885529173,
#   "train_loss_qqp": 0.38310837462891073,
#   "train_loss_stsb": 0.10999702553936311,
#   "sst2_eval_loss": 0.2845134756189178,
#   "sst2_accuracy": 0.908256880733945,
#   "sst2_macro_f1": 0.9082259829923381,
#   "sst2_precision": 0.9082259829923381,
# ...
# Epoch 19 | Shared Step 15450/22741 | sst2_loss=0.146424 | qqp_loss=0.377687 | stsb_loss=0.103845
# Epoch 19 | Shared Step 15500/22741 | sst2_loss=0.146384 | qqp_loss=0.377647 | stsb_loss=0.103866
# Epoch 19 | Shared Step 15550/22741 | sst2_loss=0.146427 | qqp_loss=0.377744 | stsb_loss=0.103909
# Epoch 19 | Shared Step 15600/22741 | sst2_loss=0.146403 | qqp_loss=0.377866 | stsb_loss=0.103909
# Epoch 19 | Shared Step 15650/22741 | sst2_loss=0.146380 | qqp_loss=0.377842 | stsb_loss=0.103927
# Epoch 19 | Shared Step 15700/22741 | sst2_loss=0.146350 | qqp_loss=0.377831 | stsb_loss=0.103943
# Epoch 19 | Shared Step 15750/22741 | sst2_loss=0.146417 | qqp_loss=0.377847 | stsb_loss=0.103920
# Epoch 19 | Shared Step 15800/22741 | sst2_loss=0.146389 | qqp_loss=0.377694 | stsb_loss=0.103914
# Epoch 19 | Shared Step 15850/22741 | sst2_loss=0.146356 | qqp_loss=0.377662 | stsb_loss=0.103917
# Epoch 19 | Shared Step 15900/22741 | sst2_loss=0.146348 | qqp_loss=0.377679 | stsb_loss=0.103896
# Epoch 19 | Shared Step 15950/22741 | sst2_loss=0.146208 | qqp_loss=0.377651 | stsb_loss=0.103873
# Epoch 19 | Shared Step 16000/22741 | sst2_loss=0.146235 | qqp_loss=0.377623 | stsb_loss=0.103886
# Epoch 19 | Shared Step 16050/22741 | sst2_loss=0.146184 | qqp_loss=0.377588 | stsb_loss=0.103881
# Epoch 19 | Shared Step 16100/22741 | sst2_loss=0.146182 | qqp_loss=0.377656 | stsb_loss=0.103896
# Epoch 19 | Shared Step 16150/22741 | sst2_loss=0.146201 | qqp_loss=0.377654 | stsb_loss=0.103884
# Epoch 19 | Shared Step 16200/22741 | sst2_loss=0.146118 | qqp_loss=0.377718 | stsb_loss=0.103880
# Epoch 19 | Shared Step 16250/22741 | sst2_loss=0.146138 | qqp_loss=0.377751 | stsb_loss=0.103881
# Epoch 19 | Shared Step 16300/22741 | sst2_loss=0.146129 | qqp_loss=0.377652 | stsb_loss=0.103896
# Epoch 19 | Shared Step 16350/22741 | sst2_loss=0.146216 | qqp_loss=0.377589 | stsb_loss=0.103900
# Epoch 19 | Shared Step 16400/22741 | sst2_loss=0.146246 | qqp_loss=0.377624 | stsb_loss=0.103900
# Epoch 19 | Shared Step 16450/22741 | sst2_loss=0.146165 | qqp_loss=0.377750 | stsb_loss=0.103923
# Epoch 19 | Shared Step 16500/22741 | sst2_loss=0.146246 | qqp_loss=0.377776 | stsb_loss=0.103923
# Epoch 19 | Shared Step 16550/22741 | sst2_loss=0.146185 | qqp_loss=0.377797 | stsb_loss=0.103917
# Epoch 19 | Shared Step 16600/22741 | sst2_loss=0.146161 | qqp_loss=0.377839 | stsb_loss=0.103906
# Epoch 19 | Shared Step 16650/22741 | sst2_loss=0.146137 | qqp_loss=0.377898 | stsb_loss=0.103945
# Epoch 19 | Shared Step 16700/22741 | sst2_loss=0.146145 | qqp_loss=0.377867 | stsb_loss=0.103897
# Epoch 19 | Shared Step 16750/22741 | sst2_loss=0.146105 | qqp_loss=0.377890 | stsb_loss=0.103874
# Epoch 19 | Shared Step 16800/22741 | sst2_loss=0.146089 | qqp_loss=0.377884 | stsb_loss=0.103863
# Epoch 19 | Shared Step 16850/22741 | sst2_loss=0.146115 | qqp_loss=0.377791 | stsb_loss=0.103854
# Epoch 19 | Shared Step 16900/22741 | sst2_loss=0.146075 | qqp_loss=0.377675 | stsb_loss=0.103849
# Epoch 19 | Shared Step 16950/22741 | sst2_loss=0.146149 | qqp_loss=0.377686 | stsb_loss=0.103796
# Epoch 19 | Shared Step 17000/22741 | sst2_loss=0.146111 | qqp_loss=0.377744 | stsb_loss=0.103824
# Epoch 19 | Shared Step 17050/22741 | sst2_loss=0.146114 | qqp_loss=0.377697 | stsb_loss=0.103797
# Epoch 19 | Shared Step 17100/22741 | sst2_loss=0.146100 | qqp_loss=0.377667 | stsb_loss=0.103818
# Epoch 19 | Shared Step 17150/22741 | sst2_loss=0.146136 | qqp_loss=0.377713 | stsb_loss=0.103790
# Epoch 19 | Shared Step 17200/22741 | sst2_loss=0.146106 | qqp_loss=0.377686 | stsb_loss=0.103769
# Epoch 19 | Shared Step 17250/22741 | sst2_loss=0.146116 | qqp_loss=0.377638 | stsb_loss=0.103758
# Epoch 19 | Shared Step 17300/22741 | sst2_loss=0.146085 | qqp_loss=0.377734 | stsb_loss=0.103796
# Epoch 19 | Shared Step 17350/22741 | sst2_loss=0.146053 | qqp_loss=0.377723 | stsb_loss=0.103813
# Epoch 19 | Shared Step 17400/22741 | sst2_loss=0.145983 | qqp_loss=0.377901 | stsb_loss=0.103783
# Epoch 19 | Shared Step 17450/22741 | sst2_loss=0.145969 | qqp_loss=0.377955 | stsb_loss=0.103763
# Epoch 19 | Shared Step 17500/22741 | sst2_loss=0.145933 | qqp_loss=0.377945 | stsb_loss=0.103769
# Epoch 19 | Shared Step 17550/22741 | sst2_loss=0.145928 | qqp_loss=0.377902 | stsb_loss=0.103742
# Epoch 19 | Shared Step 17600/22741 | sst2_loss=0.145976 | qqp_loss=0.377978 | stsb_loss=0.103720
# Epoch 19 | Shared Step 17650/22741 | sst2_loss=0.145950 | qqp_loss=0.377928 | stsb_loss=0.103704
# Epoch 19 | Shared Step 17700/22741 | sst2_loss=0.145935 | qqp_loss=0.377932 | stsb_loss=0.103691
# Epoch 19 | Shared Step 17750/22741 | sst2_loss=0.145923 | qqp_loss=0.377877 | stsb_loss=0.103705
# Epoch 19 | Shared Step 17800/22741 | sst2_loss=0.145886 | qqp_loss=0.377801 | stsb_loss=0.103694
# Epoch 19 | Shared Step 17850/22741 | sst2_loss=0.145974 | qqp_loss=0.377762 | stsb_loss=0.103685
# Epoch 19 | Shared Step 17900/22741 | sst2_loss=0.145970 | qqp_loss=0.377812 | stsb_loss=0.103716
# Epoch 19 | Shared Step 17950/22741 | sst2_loss=0.145972 | qqp_loss=0.377807 | stsb_loss=0.103703
# Epoch 19 | Shared Step 18000/22741 | sst2_loss=0.146060 | qqp_loss=0.377764 | stsb_loss=0.103699
# Epoch 19 | Shared Step 18050/22741 | sst2_loss=0.146084 | qqp_loss=0.377753 | stsb_loss=0.103680
# Epoch 19 | Shared Step 18100/22741 | sst2_loss=0.146087 | qqp_loss=0.377656 | stsb_loss=0.103704
# Epoch 19 | Shared Step 18150/22741 | sst2_loss=0.146117 | qqp_loss=0.377674 | stsb_loss=0.103705
# Epoch 19 | Shared Step 18200/22741 | sst2_loss=0.146088 | qqp_loss=0.377677 | stsb_loss=0.103678
# Epoch 19 | Shared Step 18250/22741 | sst2_loss=0.146054 | qqp_loss=0.377655 | stsb_loss=0.103677
# Epoch 19 | Shared Step 18300/22741 | sst2_loss=0.146018 | qqp_loss=0.377664 | stsb_loss=0.103649
# Epoch 19 | Shared Step 18350/22741 | sst2_loss=0.146017 | qqp_loss=0.377683 | stsb_loss=0.103660
# Epoch 19 | Shared Step 18400/22741 | sst2_loss=0.145973 | qqp_loss=0.377639 | stsb_loss=0.103707
# Epoch 19 | Shared Step 18450/22741 | sst2_loss=0.145964 | qqp_loss=0.377634 | stsb_loss=0.103721
# Epoch 19 | Shared Step 18500/22741 | sst2_loss=0.145955 | qqp_loss=0.377620 | stsb_loss=0.103719
# Epoch 19 | Shared Step 18550/22741 | sst2_loss=0.146007 | qqp_loss=0.377658 | stsb_loss=0.103744
# Epoch 19 | Shared Step 18600/22741 | sst2_loss=0.145923 | qqp_loss=0.377742 | stsb_loss=0.103718
# Epoch 19 | Shared Step 18650/22741 | sst2_loss=0.145891 | qqp_loss=0.377820 | stsb_loss=0.103701
# Epoch 19 | Shared Step 18700/22741 | sst2_loss=0.145919 | qqp_loss=0.377857 | stsb_loss=0.103714
# Epoch 19 | Shared Step 18750/22741 | sst2_loss=0.145938 | qqp_loss=0.377885 | stsb_loss=0.103694
# Epoch 19 | Shared Step 18800/22741 | sst2_loss=0.145957 | qqp_loss=0.377902 | stsb_loss=0.103671
# Epoch 19 | Shared Step 18850/22741 | sst2_loss=0.145997 | qqp_loss=0.377910 | stsb_loss=0.103671
# Epoch 19 | Shared Step 18900/22741 | sst2_loss=0.145991 | qqp_loss=0.377913 | stsb_loss=0.103661
# Epoch 19 | Shared Step 18950/22741 | sst2_loss=0.145994 | qqp_loss=0.377908 | stsb_loss=0.103648
# Epoch 19 | Shared Step 19000/22741 | sst2_loss=0.145983 | qqp_loss=0.377961 | stsb_loss=0.103610
# Epoch 19 | Shared Step 19050/22741 | sst2_loss=0.145904 | qqp_loss=0.377965 | stsb_loss=0.103611
# Epoch 19 | Shared Step 19100/22741 | sst2_loss=0.145850 | qqp_loss=0.377876 | stsb_loss=0.103611
# Epoch 19 | Shared Step 19150/22741 | sst2_loss=0.145878 | qqp_loss=0.377810 | stsb_loss=0.103590
# Epoch 19 | Shared Step 19200/22741 | sst2_loss=0.145876 | qqp_loss=0.377893 | stsb_loss=0.103609
# Epoch 19 | Shared Step 19250/22741 | sst2_loss=0.145897 | qqp_loss=0.377866 | stsb_loss=0.103599
# Epoch 19 | Shared Step 19300/22741 | sst2_loss=0.145909 | qqp_loss=0.377919 | stsb_loss=0.103616
# Epoch 19 | Shared Step 19350/22741 | sst2_loss=0.145951 | qqp_loss=0.377981 | stsb_loss=0.103630
# Epoch 19 | Shared Step 19400/22741 | sst2_loss=0.145925 | qqp_loss=0.377983 | stsb_loss=0.103618
# Epoch 19 | Shared Step 19450/22741 | sst2_loss=0.145993 | qqp_loss=0.377863 | stsb_loss=0.103633
# Epoch 19 | Shared Step 19500/22741 | sst2_loss=0.145984 | qqp_loss=0.377854 | stsb_loss=0.103621
# Epoch 19 | Shared Step 19550/22741 | sst2_loss=0.145925 | qqp_loss=0.377938 | stsb_loss=0.103624
# Epoch 19 | Shared Step 19600/22741 | sst2_loss=0.145924 | qqp_loss=0.377983 | stsb_loss=0.103572
# Epoch 19 | Shared Step 19650/22741 | sst2_loss=0.145977 | qqp_loss=0.378017 | stsb_loss=0.103597
# Epoch 19 | Shared Step 19700/22741 | sst2_loss=0.146021 | qqp_loss=0.377999 | stsb_loss=0.103580
# Epoch 19 | Shared Step 19750/22741 | sst2_loss=0.146057 | qqp_loss=0.377963 | stsb_loss=0.103567
# Epoch 19 | Shared Step 19800/22741 | sst2_loss=0.146068 | qqp_loss=0.377896 | stsb_loss=0.103551
# Epoch 19 | Shared Step 19850/22741 | sst2_loss=0.146037 | qqp_loss=0.377954 | stsb_loss=0.103540
# Epoch 19 | Shared Step 19900/22741 | sst2_loss=0.145990 | qqp_loss=0.377977 | stsb_loss=0.103549
# Epoch 19 | Shared Step 19950/22741 | sst2_loss=0.145987 | qqp_loss=0.377983 | stsb_loss=0.103538
# Epoch 19 | Shared Step 20000/22741 | sst2_loss=0.145971 | qqp_loss=0.377935 | stsb_loss=0.103530
# Epoch 19 | Shared Step 20050/22741 | sst2_loss=0.146030 | qqp_loss=0.377879 | stsb_loss=0.103505
# Epoch 19 | Shared Step 20100/22741 | sst2_loss=0.146009 | qqp_loss=0.377852 | stsb_loss=0.103489
# Epoch 19 | Shared Step 20150/22741 | sst2_loss=0.145971 | qqp_loss=0.377817 | stsb_loss=0.103479
# Epoch 19 | Shared Step 20200/22741 | sst2_loss=0.145933 | qqp_loss=0.377757 | stsb_loss=0.103461
# Epoch 19 | Shared Step 20250/22741 | sst2_loss=0.145979 | qqp_loss=0.377655 | stsb_loss=0.103453
# Epoch 19 | Shared Step 20300/22741 | sst2_loss=0.145945 | qqp_loss=0.377731 | stsb_loss=0.103429
# Epoch 19 | Shared Step 20350/22741 | sst2_loss=0.145953 | qqp_loss=0.377764 | stsb_loss=0.103394
# Epoch 19 | Shared Step 20400/22741 | sst2_loss=0.145868 | qqp_loss=0.377765 | stsb_loss=0.103361
# Epoch 19 | Shared Step 20450/22741 | sst2_loss=0.145893 | qqp_loss=0.377742 | stsb_loss=0.103359
# Epoch 19 | Shared Step 20500/22741 | sst2_loss=0.145881 | qqp_loss=0.377630 | stsb_loss=0.103355
# Epoch 19 | Shared Step 20550/22741 | sst2_loss=0.145933 | qqp_loss=0.377637 | stsb_loss=0.103353
# Epoch 19 | Shared Step 20600/22741 | sst2_loss=0.146007 | qqp_loss=0.377676 | stsb_loss=0.103374
# Epoch 19 | Shared Step 20650/22741 | sst2_loss=0.145944 | qqp_loss=0.377613 | stsb_loss=0.103396
# Epoch 19 | Shared Step 20700/22741 | sst2_loss=0.145967 | qqp_loss=0.377636 | stsb_loss=0.103392
# Epoch 19 | Shared Step 20750/22741 | sst2_loss=0.145949 | qqp_loss=0.377641 | stsb_loss=0.103411
# Epoch 19 | Shared Step 20800/22741 | sst2_loss=0.145899 | qqp_loss=0.377624 | stsb_loss=0.103373
# Epoch 19 | Shared Step 20850/22741 | sst2_loss=0.145878 | qqp_loss=0.377579 | stsb_loss=0.103402
# Epoch 19 | Shared Step 20900/22741 | sst2_loss=0.145831 | qqp_loss=0.377647 | stsb_loss=0.103401
# Epoch 19 | Shared Step 20950/22741 | sst2_loss=0.145806 | qqp_loss=0.377583 | stsb_loss=0.103409
# Epoch 19 | Shared Step 21000/22741 | sst2_loss=0.145807 | qqp_loss=0.377617 | stsb_loss=0.103420
# Epoch 19 | Shared Step 21050/22741 | sst2_loss=0.145836 | qqp_loss=0.377581 | stsb_loss=0.103399
# Epoch 19 | Shared Step 21100/22741 | sst2_loss=0.145810 | qqp_loss=0.377597 | stsb_loss=0.103388
# Epoch 19 | Shared Step 21150/22741 | sst2_loss=0.145872 | qqp_loss=0.377648 | stsb_loss=0.103380
# Epoch 19 | Shared Step 21200/22741 | sst2_loss=0.145839 | qqp_loss=0.377670 | stsb_loss=0.103382
# Epoch 19 | Shared Step 21250/22741 | sst2_loss=0.145856 | qqp_loss=0.377732 | stsb_loss=0.103366
# Epoch 19 | Shared Step 21300/22741 | sst2_loss=0.145854 | qqp_loss=0.377718 | stsb_loss=0.103381
# Epoch 19 | Shared Step 21350/22741 | sst2_loss=0.145903 | qqp_loss=0.377636 | stsb_loss=0.103363
# Epoch 19 | Shared Step 21400/22741 | sst2_loss=0.145891 | qqp_loss=0.377657 | stsb_loss=0.103379
# Epoch 19 | Shared Step 21450/22741 | sst2_loss=0.145830 | qqp_loss=0.377599 | stsb_loss=0.103355
# Epoch 19 | Shared Step 21500/22741 | sst2_loss=0.145864 | qqp_loss=0.377521 | stsb_loss=0.103348
# Epoch 19 | Shared Step 21550/22741 | sst2_loss=0.145855 | qqp_loss=0.377476 | stsb_loss=0.103338
# Epoch 19 | Shared Step 21600/22741 | sst2_loss=0.145815 | qqp_loss=0.377452 | stsb_loss=0.103342
# Epoch 19 | Shared Step 21650/22741 | sst2_loss=0.145768 | qqp_loss=0.377472 | stsb_loss=0.103332
# Epoch 19 | Shared Step 21700/22741 | sst2_loss=0.145757 | qqp_loss=0.377444 | stsb_loss=0.103339
# Epoch 19 | Shared Step 21750/22741 | sst2_loss=0.145744 | qqp_loss=0.377464 | stsb_loss=0.103327
# Epoch 19 | Shared Step 21800/22741 | sst2_loss=0.145740 | qqp_loss=0.377531 | stsb_loss=0.103331
# Epoch 19 | Shared Step 21850/22741 | sst2_loss=0.145739 | qqp_loss=0.377472 | stsb_loss=0.103332
# Epoch 19 | Shared Step 21900/22741 | sst2_loss=0.145781 | qqp_loss=0.377533 | stsb_loss=0.103331
# Epoch 19 | Shared Step 21950/22741 | sst2_loss=0.145768 | qqp_loss=0.377490 | stsb_loss=0.103335
# Epoch 19 | Shared Step 22000/22741 | sst2_loss=0.145707 | qqp_loss=0.377524 | stsb_loss=0.103335
# Epoch 19 | Shared Step 22050/22741 | sst2_loss=0.145773 | qqp_loss=0.377569 | stsb_loss=0.103316
# Epoch 19 | Shared Step 22100/22741 | sst2_loss=0.145802 | qqp_loss=0.377653 | stsb_loss=0.103305
# Epoch 19 | Shared Step 22150/22741 | sst2_loss=0.145821 | qqp_loss=0.377675 | stsb_loss=0.103292
# Epoch 19 | Shared Step 22200/22741 | sst2_loss=0.145824 | qqp_loss=0.377686 | stsb_loss=0.103299
# Epoch 19 | Shared Step 22250/22741 | sst2_loss=0.145854 | qqp_loss=0.377622 | stsb_loss=0.103308
# Epoch 19 | Shared Step 22300/22741 | sst2_loss=0.145865 | qqp_loss=0.377585 | stsb_loss=0.103322
# Epoch 19 | Shared Step 22350/22741 | sst2_loss=0.145920 | qqp_loss=0.377595 | stsb_loss=0.103317
# Epoch 19 | Shared Step 22400/22741 | sst2_loss=0.145883 | qqp_loss=0.377625 | stsb_loss=0.103328
# Epoch 19 | Shared Step 22450/22741 | sst2_loss=0.145880 | qqp_loss=0.377693 | stsb_loss=0.103321
# Epoch 19 | Shared Step 22500/22741 | sst2_loss=0.145872 | qqp_loss=0.377687 | stsb_loss=0.103303
# Epoch 19 | Shared Step 22550/22741 | sst2_loss=0.145837 | qqp_loss=0.377710 | stsb_loss=0.103295
# Epoch 19 | Shared Step 22600/22741 | sst2_loss=0.145824 | qqp_loss=0.377711 | stsb_loss=0.103279
# Epoch 19 | Shared Step 22650/22741 | sst2_loss=0.145845 | qqp_loss=0.377754 | stsb_loss=0.103283
# Epoch 19 | Shared Step 22700/22741 | sst2_loss=0.145785 | qqp_loss=0.377717 | stsb_loss=0.103263
# Epoch 19 | Shared Step 22741/22741 | sst2_loss=0.145752 | qqp_loss=0.377689 | stsb_loss=0.103252
#
# Validation results:
# {
#   "epoch": 19,
#   "train_loss_overall": 0.20889791410504607,
#   "train_loss_sst2": 0.14575241417529658,
#   "train_loss_qqp": 0.37768911879460054,
#   "train_loss_stsb": 0.10325220934524107,
#   "sst2_eval_loss": 0.3005448548292572,
#   "sst2_accuracy": 0.9128440366972477,
#   "sst2_macro_f1": 0.9127779649595686,
#   "sst2_precision": 0.9130636325326591,
#   "sst2_recall": 0.9126462911509641,
#   "qqp_eval_loss": 0.3683661040984504,
#   "qqp_accuracy": 0.8279495424189958,
#   "qqp_macro_f1": 0.8179888596847227,
#   "qqp_precision": 0.8141276498477968,
#   "qqp_recall": 0.8235195874050503,
#   "stsb_eval_loss": 0.74565335965537,
#   "stsb_pearson": 0.8276308634236357,
#   "stsb_spearman": 0.8273503524106132,
#   "overall_score": 0.8560947290111226,
#   "time_per_epoch": 3281.340704679489,
#   "trainable_params": 223109,
#   "total_params": 33583109,
#   "model_name": "microsoft/MiniLM-L12-H384-uncased",
#   "dataset_name": "sst2+qqp+stsb",
#   "setting": "centralized_mtl_lora",
#   "best_metric_so_far": 0.8564021239386861,
#   "patience_counter": 3,
#   "is_new_best": false,
#   "lora_r": 8,
#   "lora_alpha": 16,
#   "lora_dropout": 0.1
# }
#
# Early stopping triggered.
# Overall validation score did not improve for 3 consecutive epochs.
#
# Training completed.
# History CSV : /content/drive/MyDrive/mtl_runs/minilm_mtl_lora_sst2_qqp_stsb/history.csv
# History JSON: /content/drive/MyDrive/mtl_runs/minilm_mtl_lora_sst2_qqp_stsb/history.json
# Best model  : /content/drive/MyDrive/mtl_runs/minilm_mtl_lora_sst2_qqp_stsb/best_model
# Final model : /content/drive/MyDrive/mtl_runs/minilm_mtl_lora_sst2_qqp_stsb/final_model
# Checkpoints : /content/drive/MyDrive/mtl_runs/minilm_mtl_lora_sst2_qqp_stsb/checkpoints
